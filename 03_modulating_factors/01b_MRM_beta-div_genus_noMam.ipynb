# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Functions</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checks</a></span></li></ul></li><li><span><a href="#Dist-matrices" data-toc-modified-id="Dist-matrices-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Dist matrices</a></span><ul class="toc-item"><li><span><a href="#Tree" data-toc-modified-id="Tree-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Tree</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#Digestive-tract" data-toc-modified-id="Digestive-tract-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Digestive tract</a></span></li><li><span><a href="#Habitat" data-toc-modified-id="Habitat-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Habitat</a></span></li><li><span><a href="#Geographic-distance" data-toc-modified-id="Geographic-distance-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Geographic distance</a></span></li><li><span><a href="#Sampling-details" data-toc-modified-id="Sampling-details-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Sampling details</a></span></li></ul></li><li><span><a href="#Ordering-matrices" data-toc-modified-id="Ordering-matrices-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Ordering matrices</a></span></li><li><span><a href="#MRM" data-toc-modified-id="MRM-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>MRM</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#One-per-species" data-toc-modified-id="One-per-species-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>One per species</a></span><ul class="toc-item"><li><span><a href="#w-unifrac" data-toc-modified-id="w-unifrac-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>w-unifrac</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.1.1"><span class="toc-item-num">7.2.1.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.1.2"><span class="toc-item-num">7.2.1.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#uw-unifrac" data-toc-modified-id="uw-unifrac-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>uw-unifrac</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.2.1"><span class="toc-item-num">7.2.2.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.2.2"><span class="toc-item-num">7.2.2.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#Bray-Curtis" data-toc-modified-id="Bray-Curtis-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Bray-Curtis</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.3.1"><span class="toc-item-num">7.2.3.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.3.2"><span class="toc-item-num">7.2.3.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#Jaccard" data-toc-modified-id="Jaccard-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>Jaccard</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.4.1"><span class="toc-item-num">7.2.4.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.4.2"><span class="toc-item-num">7.2.4.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Plotting-associations" data-toc-modified-id="Plotting-associations-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting associations</a></span><ul class="toc-item"><li><span><a href="#w-unifrac" data-toc-modified-id="w-unifrac-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>w-unifrac</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li></ul></li><li><span><a href="#Bray" data-toc-modified-id="Bray-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Bray</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#digestive-system" data-toc-modified-id="digestive-system-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>digestive system</a></span></li></ul></li><li><span><a href="#Jaccard" data-toc-modified-id="Jaccard-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Jaccard</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Diet</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Goal
#
# * Multiple regression on matrices for arch-16S dataset
# * Using beta-diversity calculated on OTUs aggregated at the genus level

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/'

# microbiome
## 16S-arch phyloseq object (one sample per species)
physeq_arch_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_SpecD.RDS'
## 16S-arch phyloseq object (one sample per individual)
physeq_arch_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_IndD.RDS'

# diversity
beta_div_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/diversity-qiime2/beta_div_genus.RDS'

# host tree
host_tree_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch.nwk'
host_tree_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch_IndD.nwk'

# params
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(phyloseq)
library(data.table)
library(tidytable)
library(ape)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt

# %%
df.dims()
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/

# %% [markdown]
# ## Functions

# %%
#' rescaling distance matrix
rescale_dist_mtx = function(m){
    m = m %>% as.matrix
    labs = m %>% colnames
    n_row = m %>% nrow
    n_col = m %>% ncol
    x = m %>% as.vector 
    x = scales::rescale(x) 
    m = matrix(x, nrow=n_row, ncol=n_col)
    colnames(m) = labs
    rownames(m) = labs
    m = m %>% as.dist
    return(m)
}

# %%
#' Ordering distance matrixes
#' d = distance matrix (dist class)
#' x = vector to order dist. obj. by
dist_mtx_order = function(d, x){
    m = d %>% as.matrix
    d = as.dist(m[x,x])
    return(d)
}

# %% [markdown]
# # Load

# %%
# phyloseq
physeq_arch_SpecD = readRDS(physeq_arch_SpecD_file) %>%
    subset_samples(class != 'Mammalia') %>%
    filter_taxa(function(x) sum(x) > 0, TRUE)
physeq_arch_SpecD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 450 taxa and 39 samples ]
# sample_data() Sample Data:       [ 39 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 450 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 450 tips and 449 internal nodes ]

# %%
# phyloseq
physeq_arch_IndD = readRDS(physeq_arch_IndD_file) %>%
    subset_samples(class != 'Mammalia') %>%
    filter_taxa(function(x) sum(x) > 0, TRUE)
physeq_arch_IndD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 569 taxa and 52 samples ]
# sample_data() Sample Data:       [ 52 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 569 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 569 tips and 568 internal nodes ]

# %%
# beta diversity
beta_d = readRDS(beta_div_file)
beta_d %>% length
# Out:
# [1] 4

# %%
# host tree
host_tree = read.tree(host_tree_IndD_file)
to_rm = setdiff(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
host_tree = ape::drop.tip(host_tree, to_rm)
host_tree
# Out:
# Phylogenetic tree with 52 tips and 51 internal nodes.
#
# Tip labels:
# 	X60_European_Chub, X179_Roach, X330_Ide, X327_Silver_Bream, X326_Silver_Bream, F14_Common_Bream, ...
# Node labels:
# 	, @_20_@, @_17_@, @_14_@, @_9_@, @_15_@, ...
#
# Rooted; includes branch lengths.

# %%
# metadata (IndD)
meta = physeq_arch_IndD %>% sample_data %>% as.matrix %>% as.data.table
meta
# Out:
#    SampleID            host_subject_id host_german_name host_common_name
# 1  F14_Common_Bream    F14             Brachse          Common.Bream
# 2  X116_Common_Kestrel 116             Turmfalke        Common.Kestrel
# ⋮  ⋮                   ⋮               ⋮                ⋮
# 51 F157a_European_Toad F157a           Erdkroete        European.Toad
# 52 X405_Nile_Crocodile 405             Nilkrokodil      Nile.Crocodile
#    scientific_name      scientific_name_subspecies host_taxid class
# 1  Abramis_brama        NA                          38527     Actinopterygii
# 2  Falco_tinnunculus    NA                         100819     Aves
# ⋮  ⋮                    ⋮                          ⋮          ⋮
# 51 Bufo_bufo            NA                           8384     Amphibia
# 52 Crocodylus_niloticus NA                           8501     Reptilia
#    order         family       ⋯ CH4_kJ.d_mean CH4_kJ.d_sd i.CH4_L.d_mean
# 1  Cypriniformes Cyprinidae   ⋯ NA            NA          NA
# 2  Falconiformes Falconidae   ⋯ NA            NA          NA
# ⋮  ⋮             ⋮            ⋱ ⋮             ⋮           ⋮
# 51 Anura         Bufonidae    ⋯ NA            NA          NA
# 52 Crocodilia    Crocodylidae ⋯ NA            NA          NA
#    i.CH4_L.d_sd i.CH4_L.kgBM_mean i.CH4_L.kgBM_sd i.CH4_g.d_mean i.CH4_g.d_sd
# 1  NA           NA                NA              NA             NA
# 2  NA           NA                NA              NA             NA
# ⋮  ⋮            ⋮                 ⋮               ⋮              ⋮
# 51 NA           NA                NA              NA             NA
# 52 NA           NA                NA              NA             NA
#    i.CH4_kJ.d_mean i.CH4_kJ.d_sd
# 1  NA              NA
# 2  NA              NA
# ⋮  ⋮               ⋮
# 51 NA              NA
# 52 NA              NA

# %% [markdown]
# ## Checks

# %%
# overlap of sampleIDs
overlap(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
# Out:
# intersect(x,y): 52
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 52

# %%
# filtering host tree
to_rm = setdiff(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
to_rm %>% length
host_tree = ape::drop.tip(host_tree, to_rm)
host_tree
# Out:
# [1] 0
# Phylogenetic tree with 52 tips and 51 internal nodes.
#
# Tip labels:
# 	X60_European_Chub, X179_Roach, X330_Ide, X327_Silver_Bream, X326_Silver_Bream, F14_Common_Bream, ...
# Node labels:
# 	, @_20_@, @_17_@, @_14_@, @_9_@, @_15_@, ...
#
# Rooted; includes branch lengths.

# %% [markdown]
# # Dist matrices
#
# * Creating distance matrices

# %% [markdown]
# ## Tree

# %%
host_tree_d = host_tree %>% cophenetic %>% as.dist %>% rescale_dist_mtx 
p.dims(12,4)
plot(hclust(host_tree_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Diet

# %%
dietD = meta %>%
    dt_select(SampleID, diet_vertebrate, diet_invertebrate, diet_fruit,
              diet_flowers_nectar_pollen, diet_leaves_branches_bark_buds, diet_seeds,
             diet_grass_waterplants, diet_roots_tubers) %>%
    dt_mutate(diet_invertebrate = gsub(' .+', '', diet_invertebrate) %>% as.factor) %>%
    as.data.frame

rownames(dietD) = dietD$SampleID
dietD$SampleID = NULL

cn = colnames(dietD)
dietD = dietD %>% 
    apply(1, function(x) ifelse(x=='yes', 1, 0)) %>%
    t %>% as.data.frame
colnames(dietD) = cn

# status
dietD
# Out:
#                     diet_vertebrate diet_invertebrate diet_fruit
# F14_Common_Bream    0               1                 0
# X116_Common_Kestrel 1               1                 0
# ⋮                   ⋮               ⋮                 ⋮
# F157a_European_Toad 0               1                 0
# X405_Nile_Crocodile 1               0                 0
#                     diet_flowers_nectar_pollen diet_leaves_branches_bark_buds
# F14_Common_Bream    0                          0
# X116_Common_Kestrel 0                          0
# ⋮                   ⋮                          ⋮
# F157a_European_Toad 0                          0
# X405_Nile_Crocodile 0                          0
#                     diet_seeds diet_grass_waterplants diet_roots_tubers
# F14_Common_Bream    0          1                      0
# X116_Common_Kestrel 0          0                      0
# ⋮                   ⋮          ⋮                      ⋮
# F157a_European_Toad 0          0                      0
# X405_Nile_Crocodile 0          0                      0

# %%
# distance
dietD_d = vegan::vegdist(dietD, metric='jaccard')

p.dims(12,5)
plot(hclust(dietD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Digestive tract

# %%
dtD = meta %>%
    dt_select(SampleID, 
              digestive_system, digestive_system_detail, 
              ruminant, pseudoruminants) %>%
    dt_mutate(digestive_system = gsub('_', ' ', digestive_system),
              digestive_system = gsub('fermentation activity foregut', 'forgut', digestive_system),
              digestive_system_detail = gsub('^_', '', digestive_system_detail),
              digestive_system_detail = gsub('_', ' ', digestive_system_detail),
              digestive_system_detail = gsub(' +', ' ', digestive_system_detail)) %>%
    dt_mutate(digestive_system = digestive_system %>% as.factor,
              digestive_system_detail = digestive_system_detail %>% as.factor,
              ruminant = ruminant %>% as.factor,
              pseudoruminants = pseudoruminants %>% as.factor) %>%
    as.data.frame

rownames(dtD) = dtD$SampleID
dtD$SampleID = NULL

dtD %>% summary
dtD
# Out:
#        digestive_system digestive_system_detail ruminant pseudoruminants
#  hindgut       : 1      caecum :15              no:52    no:52
#  simple        :35      hindgut: 2
#  simple hindgut:16      simple :35
#                     digestive_system digestive_system_detail ruminant
# F14_Common_Bream    simple           simple                  no
# X116_Common_Kestrel simple           simple                  no
# ⋮                   ⋮                ⋮                       ⋮
# F157a_European_Toad simple           simple                  no
# X405_Nile_Crocodile simple           simple                  no
#                     pseudoruminants
# F14_Common_Bream    no
# X116_Common_Kestrel no
# ⋮                   ⋮
# F157a_European_Toad no
# X405_Nile_Crocodile no

# %%
dtD_d = cluster::daisy(dtD, metric='gower')

p.dims(12,5)
plot(hclust(dtD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Habitat

# %%
habitatD = meta %>%
    dt_select(SampleID, habitat, habitat_detail, habitat_detail_1, habitat_detail_2) %>%
    dt_mutate_across(everything.(), function(x) as.factor(gsub(' habitat$', '', x))) %>%
    as.data.frame

rownames(habitatD) = habitatD$SampleID
habitatD$SampleID = NULL

habitatD %>% summary
habitatD
# Out:
#           habitat         habitat_detail      habitat_detail_1
#  anthropogenic: 2   anthropogenic: 2     anthropogenic: 2
#  aquatic      : 8   freshwater   : 8     forest       : 6
#  terrestrial  :42   grassland    : 7     freshwater   : 8
#                     terrestrial  :29     meadow       : 1
#                     woodland     : 6     steppe       : 6
#                                          terrestrial  :29
#       habitat_detail_2
#  anthropogenic: 2
#  flood meadow : 1
#  forest       : 6
#  freshwater   : 8
#  steppe       : 6
#  terrestrial  :29
#                     habitat     habitat_detail habitat_detail_1
# F14_Common_Bream    aquatic     freshwater     freshwater
# X116_Common_Kestrel terrestrial terrestrial    terrestrial
# ⋮                   ⋮           ⋮              ⋮
# F157a_European_Toad terrestrial terrestrial    terrestrial
# X405_Nile_Crocodile terrestrial woodland       forest
#                     habitat_detail_2
# F14_Common_Bream    freshwater
# X116_Common_Kestrel terrestrial
# ⋮                   ⋮
# F157a_European_Toad terrestrial
# X405_Nile_Crocodile forest

# %%
habitatD_d = cluster::daisy(habitatD, metric='gower') 

p.dims(12,5)
plot(hclust(habitatD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Geographic distance

# %%
geo = meta %>% 
    dt_select(SampleID, latitude, longitude) %>%
    dt_mutate(latitude = latitude %>% as.Num,
           longitude = longitude %>% as.Num) %>%
    as.data.frame

rownames(geo) = geo$SampleID

geo$latitude %>% summary %>% print
geo$longitude %>% summary %>% print
geo
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -35.63   47.50   48.21   45.14   48.33   54.52
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   8.637  15.750  16.373  18.866  16.417 138.504
#                     SampleID            latitude  longitude
# F14_Common_Bream    F14_Common_Bream    48.20833  16.37306
# X116_Common_Kestrel X116_Common_Kestrel 47.50000  19.05000
# ⋮                   ⋮                   ⋮         ⋮
# F157a_European_Toad F157a_European_Toad  48.33333 15.75000
# X405_Nile_Crocodile X405_Nile_Crocodile -23.23125 30.49255

# %%
.pairwise_distGeo = function(x, y){
    d = geosphere::distGeo(x[c('longitude', 'latitude')],
                           y[,c('longitude', 'latitude')])
    return(d)
}

pairwise_distGeo = function(df){
    x = df[,c('longitude', 'latitude')]
    geo_d = apply(x, 1, .pairwise_distGeo, y=x)
    rescale_dist_mtx(as.dist(geo_d))
}

geo_d = pairwise_distGeo(geo)

p.dims(12,5)
plot(hclust(geo_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Sampling details

# %%
samp = meta %>% 
    dt_select(SampleID, sampling_method, captive_wild, wild_domesticated) %>%
    dt_mutate_across(everything.(), as.factor) %>%
    as.data.frame

rownames(samp) = samp$SampleID
samp$SampleID = NULL

samp %>% summary
samp
# Out:
#        sampling_method  captive_wild    wild_domesticated
#  feces sampling:35     captive: 5    domesticated: 1
#  gut section   :11     wild   :47    wild        :51
#  swab          : 6
#                     sampling_method captive_wild wild_domesticated
# F14_Common_Bream    feces sampling  wild         wild
# X116_Common_Kestrel gut section     wild         wild
# ⋮                   ⋮               ⋮            ⋮
# F157a_European_Toad feces sampling  wild         wild
# X405_Nile_Crocodile feces sampling  wild         wild

# %%
# distance matrix
samp_d = cluster::daisy(samp, metric='gower') 

p.dims(12, 5)
plot(hclust(samp_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# # Ordering matrices

# %%
# checking overlap 
X = labels(beta_d$weighted_unifrac)
overlap(X, labels(host_tree_d))
# Out:
# intersect(x,y): 52
# setdiff(x,y): 133
# setdiff(y,x): 0
# union(x,y): 185

# %%
# ordering by host tree labels
X = labels(host_tree_d)

beta_d = lapply(beta_d, dist_mtx_order, x=X)

host_tree_d_o = dist_mtx_order(host_tree_d, X)
dietD_d_o = dist_mtx_order(dietD_d, X)
habitatD_d_o = dist_mtx_order(habitatD_d, X)
geo_d_o = dist_mtx_order(geo_d, X)
samp_d_o = dist_mtx_order(samp_d, X)
dtD_d_o = dist_mtx_order(dtD_d, X)

# %%
# checking sizes of beta-div matrices
beta_d %>% lapply(function(x) x %>% as.matrix %>% dim)
# Out:
# $bray_curtis
# [1] 52 52
#
# $jaccard
# [1] 52 52
#
# $unweighted_unifrac
# [1] 52 52
#
# $weighted_unifrac
# [1] 52 52

# %% [markdown]
# # MRM

# %%
# number of permutated SpecD datasetst
nperm_datasets = 100
# number of permutations per MRM analysis
nperm = 1000

# %% [markdown]
# ## Functions

# %%
#' randomly selecting one per group
#' L : list of distance matrixes used for MRM
#' df_grps : data.frame (sample, group)
one_per_group = function(L, df_grps, ...){
    # get subsample
    colnames(df_grps) = c('Sample', 'Group')
    df_grps = df_grps %>%
        group_by(Group) %>%
        sample_n(1)
    # subsetting all matrices
    lapply(L, function(x) dist_mtx_order(x, df_grps$Sample))
}

# %%
#' MRM on one subsample rep
#' i : rep number
#' L : list of list of distance matrices generated by `one_per_group()`
# nperm : nperm function for MRM
# f : MRM fomulat
mrm_each = function(i, L, f, nperm=99){
    m = L[[i]]
    f = as.formula(f)
    x = ecodist::MRM(f, nperm=nperm, mrank=TRUE)
    # coefficients
    df = x$coef %>% as.data.frame
    colnames(df) = c('coef', 'coef_pval')
    df$variable = rownames(df)
    df$R2 = x$r.squared[1]
    df$pval = x$r.squared[2]
    df$F = x$F.test[1]
    df$rep = i
    return(df)
}

# %%
# renaming output
rename_df = data.frame(old_name = c('m$diet', 'm$digest', 'm$geo', 'm$habitat', 'm$host_phy', 'm$samp'),
                       new_name = c('Diet', 'Digestive\nsystem', 'Geography', 'Habitat', 'Phylogeny', 'Technical'))
rename_df
# Out:
#   old_name   new_name
# 1 m$diet     Diet
# 2 m$digest   Digestive\nsystem
# ⋮ ⋮          ⋮
# 5 m$host_phy Phylogeny
# 6 m$samp     Technical

# %% [markdown]
# ## One per species

# %%
# grouping samples by species
df_grps = meta %>% 
    dt_filter(SampleID %in% labels(dietD_d_o)) %>%
    dt_select(SampleID, scientific_name)
df_grps
# Out:
#    SampleID            scientific_name
# 1  F14_Common_Bream    Abramis_brama
# 2  X116_Common_Kestrel Falco_tinnunculus
# ⋮  ⋮                   ⋮
# 51 F157a_European_Toad Bufo_bufo
# 52 X405_Nile_Crocodile Crocodylus_niloticus

# %% [markdown]
# ### w-unifrac

# %%
# creating subsample permutations of the distance matrices
L = list(beta = beta_d$weighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef        coef_pval variable   R2         pval  F        rep
# Int        382.7999872 0.432     Int        0.06050936 0.285 7.879069 1
# m$host_phy   0.2642076 0.066     m$host_phy 0.06050936 0.285 7.879069 1
# ⋮          ⋮           ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.03464186 0.727     m$geo      0.05041047 0.357 6.49426  100
# m$samp99   -0.16744710 0.095     m$samp     0.05041047 0.357 6.49426  100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.172827   Min.   :0.0190   Min.   :0.04151   Min.   :0.1580
#  1st Qu.:-0.059522   1st Qu.:0.2213   1st Qu.:0.04813   1st Qu.:0.2858
#  Median :-0.012090   Median :0.4985   Median :0.05065   Median :0.3375
#  Mean   : 0.004378   Mean   :0.5039   Mean   :0.05373   Mean   :0.3217
#  3rd Qu.: 0.063118   3rd Qu.:0.7670   3rd Qu.:0.05928   3rd Qu.:0.3730
#  Max.   : 0.296836   Max.   :1.0000   Max.   :0.07186   Max.   :0.5050
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.83
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef        coef_pval variable   R2         pval  F        rep
# Int        378.1581455 0.450     Int        0.06033005 0.178 9.437906 1
# m$host_phy   0.2639023 0.057     m$host_phy 0.06033005 0.178 9.437906 1
# ⋮          ⋮           ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.03112632 0.744     m$geo      0.04834534 0.232 7.467798 100
# m$samp99   -0.16664334 0.083     m$samp     0.04834534 0.232 7.467798 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef              coef_pval            R2               pval
#  Min.   :-0.1723691   Min.   :0.0190   Min.   :0.04015   Min.   :0.1050
#  1st Qu.:-0.0981369   1st Qu.:0.1658   1st Qu.:0.04583   1st Qu.:0.1847
#  Median :-0.0216055   Median :0.3245   Median :0.04921   Median :0.2355
#  Mean   : 0.0009648   Mean   :0.4369   Mean   :0.05261   Mean   :0.2264
#  3rd Qu.: 0.0836113   3rd Qu.:0.7610   3rd Qu.:0.05920   3rd Qu.:0.2642
#  Max.   : 0.2970589   Max.   :0.9850   Max.   :0.07147   Max.   :0.3520
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.84
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### uw-unifrac

# %%
# creating multiple distance matrices
m = list(beta = beta_d$unweighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(m, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        381.49774134 0.468     Int        0.0257793  0.654 3.237119 1
# m$host_phy   0.06815358 0.521     m$host_phy 0.0257793  0.654 3.237119 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99     0.01752223  0.846     m$geo      0.03268916 0.549 4.134115 100
# m$samp99   -0.18067201  0.053     m$samp     0.03268916 0.549 4.134115 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.200492   Min.   :0.0270   Min.   :0.02256   Min.   :0.3120
#  1st Qu.:-0.014640   1st Qu.:0.4813   1st Qu.:0.03008   1st Qu.:0.4103
#  Median : 0.021214   Median :0.6885   Median :0.03191   Median :0.5310
#  Mean   :-0.004785   Mean   :0.6125   Mean   :0.03299   Mean   :0.5074
#  3rd Qu.: 0.042876   3rd Qu.:0.8360   3rd Qu.:0.03823   3rd Qu.:0.5810
#  Max.   : 0.133506   Max.   :1.0000   Max.   :0.04320   Max.   :0.6920
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 1.00
# 6 m$samp     0.64

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        378.25825109 0.463     Int        0.02569819 0.499 3.877272 1
# m$host_phy   0.06823605 0.558     m$host_phy 0.02569819 0.499 3.877272 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99     0.01841643  0.841     m$geo      0.03256808 0.385 4.948677 100
# m$samp99   -0.18054296  0.044     m$samp     0.03256808 0.385 4.948677 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, R2, pval, rep) %>%
    summary
# Out:
#       coef                R2               pval             rep
#  Min.   :-0.19986   Min.   :0.02255   Min.   :0.2230   Min.   :  1.00
#  1st Qu.:-0.02903   1st Qu.:0.02934   1st Qu.:0.3205   1st Qu.: 25.75
#  Median : 0.02135   Median :0.03115   Median :0.3960   Median : 50.50
#  Mean   :-0.01025   Mean   :0.03210   Mean   :0.3848   Mean   : 50.50
#  3rd Qu.: 0.04552   3rd Qu.:0.03683   3rd Qu.:0.4405   3rd Qu.: 75.25
#  Max.   : 0.12297   Max.   :0.04021   Max.   :0.5610   Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 1.00
# 5 m$samp     0.64

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### Bray-Curtis

# %%
# creating multiple distance matrices
L = list(beta = beta_d$bray_curtis,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        342.5284372  0.605     Int        0.09443605 0.087 12.75744 1
# m$host_phy   0.1946577  0.114     m$host_phy 0.09443605 0.087 12.75744 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99     0.003201787 0.968     m$geo      0.07868474 0.129 10.44785 100
# m$samp99   -0.199611628 0.055     m$samp     0.07868474 0.129 10.44785 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.249750   Min.   :0.0120   Min.   :0.07774   Min.   :0.02000
#  1st Qu.:-0.007543   1st Qu.:0.1303   1st Qu.:0.08733   1st Qu.:0.04400
#  Median : 0.019228   Median :0.5725   Median :0.09260   Median :0.06400
#  Mean   : 0.015522   Mean   :0.5241   Mean   :0.09289   Mean   :0.06978
#  3rd Qu.: 0.066283   3rd Qu.:0.8812   3rd Qu.:0.09806   3rd Qu.:0.09400
#  Max.   : 0.305428   Max.   :1.0000   Max.   :0.11264   Max.   :0.13800
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.79
# 6 m$samp     0.20

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        361.1509304  0.515     Int        0.09177842 0.032 14.85477 1
# m$host_phy   0.1932265  0.125     m$host_phy 0.09177842 0.032 14.85477 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99     0.007419619 0.941     m$geo      0.07574773 0.074 12.04749 100
# m$samp99   -0.197385478 0.043     m$samp     0.07574773 0.074 12.04749 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.24933   Min.   :0.0110   Min.   :0.07415   Min.   :0.01200
#  1st Qu.:-0.02743   1st Qu.:0.0755   1st Qu.:0.08544   1st Qu.:0.02475
#  Median : 0.01453   Median :0.3260   Median :0.09114   Median :0.04000
#  Mean   : 0.01164   Mean   :0.4628   Mean   :0.09116   Mean   :0.04189
#  3rd Qu.: 0.08266   3rd Qu.:0.8662   3rd Qu.:0.09694   3rd Qu.:0.05600
#  Max.   : 0.30588   Max.   :1.0000   Max.   :0.11248   Max.   :0.08700
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.81
# 5 m$samp     0.23

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### Jaccard

# %%
# creating multiple distance matrices
L = list(beta = beta_d$jaccard,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef        coef_pval variable   R2        pval  F        rep
# Int        318.6481410 0.703     Int        0.1709621 0.002 25.22726 1
# m$host_phy   0.4058515 0.001     m$host_phy 0.1709621 0.002 25.22726 1
# ⋮          ⋮           ⋮         ⋮          ⋮         ⋮     ⋮        ⋮
# m$geo99     0.0160137  0.86      m$geo      0.1581018 0.003 22.97324 100
# m$samp99   -0.2195569  0.02      m$samp     0.1581018 0.003 22.97324 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval             R2              pval
#  Min.   :-0.238886   Min.   :0.00100   Min.   :0.1226   Min.   :0.00200
#  1st Qu.:-0.052434   1st Qu.:0.03075   1st Qu.:0.1432   1st Qu.:0.00300
#  Median : 0.007836   Median :0.46050   Median :0.1524   Median :0.00500
#  Mean   : 0.022254   Mean   :0.46904   Mean   :0.1518   Mean   :0.00629
#  3rd Qu.: 0.058723   3rd Qu.:0.85125   3rd Qu.:0.1609   3rd Qu.:0.00800
#  Max.   : 0.437880   Max.   :0.99800   Max.   :0.1856   Max.   :0.02300
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.01
# 6 m$samp     0.06

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef        coef_pval variable   R2        pval  F        rep
# Int        304.1303775 0.779     Int        0.1693303 0.001 29.96564 1
# m$host_phy   0.4062211 0.002     m$host_phy 0.1693303 0.001 29.96564 1
# ⋮          ⋮           ⋮         ⋮          ⋮         ⋮     ⋮        ⋮
# m$geo99     0.01661011 0.869     m$geo      0.1580479 0.001 27.59425 100
# m$samp99   -0.21947078 0.013     m$samp     0.1580479 0.001 27.59425 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2              pval
#  Min.   :-0.23911   Min.   :0.0010   Min.   :0.1219   Min.   :0.00100
#  1st Qu.:-0.08299   1st Qu.:0.0260   1st Qu.:0.1428   1st Qu.:0.00200
#  Median : 0.01162   Median :0.3105   Median :0.1514   Median :0.00300
#  Mean   : 0.02769   Mean   :0.3948   Mean   :0.1513   Mean   :0.00318
#  3rd Qu.: 0.06731   3rd Qu.:0.7953   3rd Qu.:0.1601   3rd Qu.:0.00400
#  Max.   : 0.43835   Max.   :1.0000   Max.   :0.1830   Max.   :0.00900
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.01
# 5 m$samp     0.03

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# # Plotting associations

# %%
# converting distance matrix
x_y_df = function(rep, L, x_var){
    x = L[[rep]][[x_var]] %>% as.vector
    y = L[[rep]]$beta %>% as.vector
    df = data.frame(x=x,y=y)
    df$rep=rep
    df$point = 1:nrow(df)
    return(df)
}

# %% [markdown]
# ## w-unifrac

# %%
# creating multiple distance matrices
L = list(beta = beta_d$weighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#     point x_sd x        y_sd      y
# 1   1     0    1        0.0000000 0.6129921
# 2   2     0    1        0.4069214 1.3668839
# ⋮   ⋮     ⋮    ⋮        ⋮         ⋮
# 740 740   0    0.642411 0         1.5549510
# 741 741   0    0.141821 0         0.5809307

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='w-unifrac') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Bray

# %%
# creating multiple distance matrices
L = list(beta = beta_d$bray,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#     point x_sd x        y_sd       y
# 1   1     0    1        0.00000000 1.0000
# 2   2     0    1        0.01267464 0.9912
# ⋮   ⋮     ⋮    ⋮        ⋮          ⋮
# 740 740   0    0.642411 0          0.756
# 741 741   0    0.141821 0          0.968

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#     point x         y
# 1   1     0.3333333 1.0000
# 2   2     0.6000000 0.9912
# ⋮   ⋮     ⋮         ⋮
# 740 740   0.6000000 0.756
# 741 741   0.3333333 0.968

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='diet', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### digestive system

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='digest')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#     point x   y
# 1   1     0.5 1.0000
# 2   2     0.5 0.9912
# ⋮   ⋮     ⋮   ⋮
# 740 740   0   0.756
# 741 741   0   0.968

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='digestive system', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Jaccard

# %%
# creating multiple distance matrices
L = list(beta = beta_d$jaccard,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#     point x        y
# 1   1     1        1.000000
# 2   2     1        0.970881
# ⋮   ⋮     ⋮        ⋮
# 740 740   0.642411 0.7777778
# 741 741   0.141821 0.7500000

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='jaccard') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#     point x         y
# 1   1     0.3333333 1.000000
# 2   2     0.6000000 0.970881
# ⋮   ⋮     ⋮         ⋮
# 740 740   0.6000000 0.7777778
# 741 741   0.3333333 0.7500000

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='Diet', y='jaccard') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.6 ape_5.3           tidytable_0.4.1   data.table_1.12.8
# [5] phyloseq_1.30.0   ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.46.0      jsonlite_1.6        splines_3.6.2
#  [4] foreach_1.4.7       assertthat_0.2.1    sp_1.4-2
#  [7] stats4_3.6.2        pillar_1.4.3        lattice_0.20-38
# [10] glue_1.3.1          uuid_0.1-2          digest_0.6.23
# [13] XVector_0.26.0      colorspace_1.4-1    htmltools_0.4.0
# [16] Matrix_1.2-18       plyr_1.8.5          pkgconfig_2.0.3
# [19] zlibbioc_1.32.0     purrr_0.3.3         scales_1.1.1
# [22] tibble_2.1.3        mgcv_1.8-31         farver_2.0.3
# [25] IRanges_2.20.0      ellipsis_0.3.0      withr_2.1.2
# [28] repr_1.0.2          BiocGenerics_0.32.0 lazyeval_0.2.2
# [31] survival_3.1-8      magrittr_1.5        crayon_1.3.4
# [34] evaluate_0.14       doParallel_1.0.15   nlme_3.1-143
# [37] MASS_7.3-51.5       vegan_2.5-6         tools_3.6.2
# [40] geosphere_1.5-10    lifecycle_0.1.0     stringr_1.4.0
# [43] Rhdf5lib_1.8.0      S4Vectors_0.24.0    munsell_0.5.0
# [46] cluster_2.1.0       Biostrings_2.54.0   ade4_1.7-13
# [49] compiler_3.6.2      rlang_0.4.6         rhdf5_2.30.0
# [52] grid_3.6.2          pbdZMQ_0.3-3        iterators_1.0.12
# [55] IRkernel_1.1        biomformat_1.14.0   igraph_1.2.4.2
# [58] base64enc_0.1-3     labeling_0.3        gtable_0.3.0
# [61] codetools_0.2-16    multtest_2.42.0     reshape2_1.4.3
# [64] R6_2.4.1            knitr_1.26          permute_0.9-5
# [67] stringi_1.4.5       parallel_3.6.2      IRdisplay_0.7.0
# [70] Rcpp_1.0.3          vctrs_0.3.1         tidyselect_1.1.0
# [73] xfun_0.12
