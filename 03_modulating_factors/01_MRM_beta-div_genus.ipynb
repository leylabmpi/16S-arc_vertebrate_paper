# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Functions</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checks</a></span></li></ul></li><li><span><a href="#Dist-matrices" data-toc-modified-id="Dist-matrices-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Dist matrices</a></span><ul class="toc-item"><li><span><a href="#Tree" data-toc-modified-id="Tree-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Tree</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#Digestive-tract" data-toc-modified-id="Digestive-tract-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Digestive tract</a></span></li><li><span><a href="#Habitat" data-toc-modified-id="Habitat-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Habitat</a></span></li><li><span><a href="#Geographic-distance" data-toc-modified-id="Geographic-distance-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Geographic distance</a></span></li><li><span><a href="#Sampling-details" data-toc-modified-id="Sampling-details-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Sampling details</a></span></li></ul></li><li><span><a href="#Ordering-matrices" data-toc-modified-id="Ordering-matrices-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Ordering matrices</a></span></li><li><span><a href="#MRM" data-toc-modified-id="MRM-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>MRM</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#One-per-species" data-toc-modified-id="One-per-species-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>One per species</a></span><ul class="toc-item"><li><span><a href="#w-unifrac" data-toc-modified-id="w-unifrac-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>w-unifrac</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.1.1"><span class="toc-item-num">7.2.1.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.1.2"><span class="toc-item-num">7.2.1.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#uw-unifrac" data-toc-modified-id="uw-unifrac-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>uw-unifrac</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.2.1"><span class="toc-item-num">7.2.2.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.2.2"><span class="toc-item-num">7.2.2.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#Bray-Curtis" data-toc-modified-id="Bray-Curtis-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Bray-Curtis</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.3.1"><span class="toc-item-num">7.2.3.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.3.2"><span class="toc-item-num">7.2.3.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#Jaccard" data-toc-modified-id="Jaccard-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>Jaccard</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.4.1"><span class="toc-item-num">7.2.4.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.4.2"><span class="toc-item-num">7.2.4.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li></ul></li><li><span><a href="#Summary-plot" data-toc-modified-id="Summary-plot-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Summary plot</a></span><ul class="toc-item"><li><span><a href="#Model2" data-toc-modified-id="Model2-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Model2</a></span></li></ul></li></ul></li><li><span><a href="#Plotting-associations" data-toc-modified-id="Plotting-associations-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting associations</a></span><ul class="toc-item"><li><span><a href="#w-unifrac" data-toc-modified-id="w-unifrac-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>w-unifrac</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li></ul></li><li><span><a href="#Bray" data-toc-modified-id="Bray-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Bray</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#digestive-system" data-toc-modified-id="digestive-system-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>digestive system</a></span></li></ul></li><li><span><a href="#Jaccard" data-toc-modified-id="Jaccard-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Jaccard</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Diet</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Goal
#
# * Multiple regression on matrices for arch-16S dataset
# * Using beta-diversity calculated on OTUs aggregated at the genus level

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/'

# microbiome
## 16S-arch phyloseq object (one sample per species)
physeq_arch_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_SpecD.RDS'
## 16S-arch phyloseq object (one sample per individual)
physeq_arch_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_IndD.RDS'

# diversity
beta_div_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/diversity-qiime2/beta_div_genus.RDS'

# host tree
host_tree_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch.nwk'
host_tree_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch_IndD.nwk'

# params
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(phyloseq)
library(data.table)
library(tidytable)
library(ape)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt

# %%
df.dims()
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/

# %% [markdown]
# ## Functions

# %%
#' rescaling distance matrix
rescale_dist_mtx = function(m){
    m = m %>% as.matrix
    labs = m %>% colnames
    n_row = m %>% nrow
    n_col = m %>% ncol
    x = m %>% as.vector 
    x = scales::rescale(x) 
    m = matrix(x, nrow=n_row, ncol=n_col)
    colnames(m) = labs
    rownames(m) = labs
    m = m %>% as.dist
    return(m)
}

# %%
#' Ordering distance matrixes
#' d = distance matrix (dist class)
#' x = vector to order dist. obj. by
dist_mtx_order = function(d, x){
    m = d %>% as.matrix
    d = as.dist(m[x,x])
    return(d)
}

# %% [markdown]
# # Load

# %%
# phyloseq
physeq_arch_SpecD = readRDS(physeq_arch_SpecD_file)
physeq_arch_SpecD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1151 taxa and 110 samples ]
# sample_data() Sample Data:       [ 110 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 1151 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1151 tips and 1150 internal nodes ]

# %%
# phyloseq
physeq_arch_IndD = readRDS(physeq_arch_IndD_file)
physeq_arch_IndD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1891 taxa and 185 samples ]
# sample_data() Sample Data:       [ 185 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 1891 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1891 tips and 1888 internal nodes ]

# %%
# beta diversity
beta_d = readRDS(beta_div_file)
beta_d %>% length
# Out:
# [1] 4

# %%
# host tree
host_tree = read.tree(host_tree_IndD_file)
host_tree
# Out:
# Phylogenetic tree with 185 tips and 184 internal nodes.
#
# Tip labels:
# 	X60_European_Chub, X179_Roach, X330_Ide, X327_Silver_Bream, X326_Silver_Bream, F14_Common_Bream, ...
# Node labels:
# 	, @_20_@, @_17_@, @_14_@, @_9_@, @_15_@, ...
#
# Rooted; includes branch lengths.

# %%
# metadata (IndD)
meta = physeq_arch_IndD %>% sample_data %>% as.matrix %>% as.data.table
meta
# Out:
#     SampleID         host_subject_id host_german_name host_common_name
# 1   F14_Common_Bream F14             Brachse          Common.Bream
# 2   F35_Red_Deer     F35             Rothirsch        Red.Deer
# ⋮   ⋮                ⋮               ⋮                ⋮
# 184 X431_Quagga      431             Steppenzebra     Quagga
# 185 X67_European_Roe 67              Reh              European.Roe
#     scientific_name     scientific_name_subspecies host_taxid class
# 1   Abramis_brama       NA                           38527    Actinopterygii
# 2   Cervus_elaphus      NA                            9860    Mammalia
# ⋮   ⋮                   ⋮                          ⋮          ⋮
# 184 Equus_quagga        NA                           89252    Mammalia
# 185 Capreolus_capreolus NA                            9858    Mammalia
#     order          family     ⋯ CH4_kJ.d_mean CH4_kJ.d_sd i.CH4_L.d_mean
# 1   Cypriniformes  Cyprinidae ⋯ NA            NA          NA
# ...

# %% [markdown]
# ## Checks

# %%
# overlap of sampleIDs
overlap(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
# Out:
# intersect(x,y): 185
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 185

# %% [markdown]
# # Dist matrices
#
# * Creating distance matrices

# %% [markdown]
# ## Tree

# %%
host_tree_d = host_tree %>% cophenetic %>% as.dist %>% rescale_dist_mtx 
p.dims(12,4)
plot(hclust(host_tree_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Diet

# %%
dietD = meta %>%
    dt_select(SampleID, diet_vertebrate, diet_invertebrate, diet_fruit,
              diet_flowers_nectar_pollen, diet_leaves_branches_bark_buds, diet_seeds,
             diet_grass_waterplants, diet_roots_tubers) %>%
    dt_mutate(diet_invertebrate = gsub(' .+', '', diet_invertebrate) %>% as.factor) %>%
    as.data.frame

rownames(dietD) = dietD$SampleID
dietD$SampleID = NULL

cn = colnames(dietD)
dietD = dietD %>% 
    apply(1, function(x) ifelse(x=='yes', 1, 0)) %>%
    t %>% as.data.frame
colnames(dietD) = cn

# status
dietD
# Out:
#                  diet_vertebrate diet_invertebrate diet_fruit
# F14_Common_Bream 0               1                 0
# F35_Red_Deer     0               0                 1
# ⋮                ⋮               ⋮                 ⋮
# X431_Quagga      0               0                 0
# X67_European_Roe 0               0                 1
#                  diet_flowers_nectar_pollen diet_leaves_branches_bark_buds
# F14_Common_Bream 0                          0
# F35_Red_Deer     0                          1
# ⋮                ⋮                          ⋮
# X431_Quagga      0                          0
# X67_European_Roe 0                          1
#                  diet_seeds diet_grass_waterplants diet_roots_tubers
# F14_Common_Bream 0          1                      0
# F35_Red_Deer     1          1                      1
# ⋮                ⋮          ⋮                      ⋮
# X431_Quagga      1          1                      0
# ...

# %%
# distance
dietD_d = vegan::vegdist(dietD, metric='jaccard')

p.dims(12,5)
plot(hclust(dietD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Digestive tract

# %%
dtD = meta %>%
    dt_select(SampleID, 
              digestive_system, digestive_system_detail, 
              ruminant, pseudoruminants) %>%
    dt_mutate(digestive_system = gsub('_', ' ', digestive_system),
              digestive_system = gsub('fermentation activity foregut', 'forgut', digestive_system),
              digestive_system_detail = gsub('^_', '', digestive_system_detail),
              digestive_system_detail = gsub('_', ' ', digestive_system_detail),
              digestive_system_detail = gsub(' +', ' ', digestive_system_detail)) %>%
    dt_mutate(digestive_system = digestive_system %>% as.factor,
              digestive_system_detail = digestive_system_detail %>% as.factor,
              ruminant = ruminant %>% as.factor,
              pseudoruminants = pseudoruminants %>% as.factor) %>%
    as.data.frame

rownames(dtD) = dtD$SampleID
dtD$SampleID = NULL

dtD %>% summary
dtD
# Out:
#        digestive_system                  digestive_system_detail ruminant
#  foregut       :55      caecum                       :35         no :144
#  forgut        : 1      colocecal fermentation       : 2         yes: 41
#  hindgut       :29      colon                        :18
#  simple        :72      fermentation activity foregut: 3
#  simple foregut: 2      foregut                      :55
#  simple hindgut:26      hindgut                      : 6
#                         simple                       :66
#       pseudoruminants
#  no           :170
#  ruminant_like: 10
#  yes          :  5
#                  digestive_system digestive_system_detail ruminant
# F14_Common_Bream simple           simple                  no
# F35_Red_Deer     foregut          foregut                 yes
# ⋮                ⋮                ⋮                       ⋮
# X431_Quagga      hindgut          colon                   no
# X67_European_Roe foregut          foregut                 yes
# ...

# %%
dtD_d = cluster::daisy(dtD, metric='gower')

p.dims(12,5)
plot(hclust(dtD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Habitat

# %%
habitatD = meta %>%
    dt_select(SampleID, habitat, habitat_detail, habitat_detail_1, habitat_detail_2) %>%
    dt_mutate_across(everything.(), function(x) as.factor(gsub(' habitat$', '', x))) %>%
    as.data.frame

rownames(habitatD) = habitatD$SampleID
habitatD$SampleID = NULL

habitatD %>% summary
habitatD
# Out:
#           habitat          habitat_detail      habitat_detail_1
#  anthropogenic:  7   anthropogenic: 7     terrestrial  :87
#  aquatic      : 12   cultivated   : 3     forest       :40
#  terrestrial  :166   freshwater   : 8     meadow       :14
#                      grassland    :36     steppe       :14
#                      saline water : 4     freshwater   : 8
#                      terrestrial  :87     anthropogenic: 7
#                      woodland     :40     (Other)      :15
#       habitat_detail_2
#  terrestrial  :87
#  forest       :40
#  flood meadow :14
#  steppe       :14
#  freshwater   : 8
#  anthropogenic: 7
#  (Other)      :15
#                  habitat     habitat_detail habitat_detail_1 habitat_detail_2
# F14_Common_Bream aquatic     freshwater     freshwater       freshwater
# F35_Red_Deer     terrestrial grassland      meadow           flood meadow
# ⋮                ⋮           ⋮              ⋮                ⋮
# ...

# %%
habitatD_d = cluster::daisy(habitatD, metric='gower') 

p.dims(12,5)
plot(hclust(habitatD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Geographic distance

# %%
geo = meta %>% 
    dt_select(SampleID, latitude, longitude) %>%
    dt_mutate(latitude = latitude %>% as.Num,
           longitude = longitude %>% as.Num) %>%
    as.data.frame

rownames(geo) = geo$SampleID

geo$latitude %>% summary %>% print
geo$longitude %>% summary %>% print
geo
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -35.83   20.32   47.50   32.81   48.21   55.29
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -84.10   15.75   16.37   28.69   30.49  138.68
#                  SampleID         latitude longitude
# F14_Common_Bream F14_Common_Bream 48.20833 16.37306
# F35_Red_Deer     F35_Red_Deer     48.20833 16.37306
# ⋮                ⋮                ⋮        ⋮
# X431_Quagga      X431_Quagga      47.22400 15.81200
# X67_European_Roe X67_European_Roe 48.20833 16.37306

# %%
.pairwise_distGeo = function(x, y){
    d = geosphere::distGeo(x[c('longitude', 'latitude')],
                           y[,c('longitude', 'latitude')])
    return(d)
}

pairwise_distGeo = function(df){
    x = df[,c('longitude', 'latitude')]
    geo_d = apply(x, 1, .pairwise_distGeo, y=x)
    rescale_dist_mtx(as.dist(geo_d))
}

geo_d = pairwise_distGeo(geo)

p.dims(12,5)
plot(hclust(geo_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Sampling details

# %%
samp = meta %>% 
    dt_select(SampleID, sampling_method, captive_wild, wild_domesticated) %>%
    dt_mutate_across(everything.(), as.factor) %>%
    as.data.frame

rownames(samp) = samp$SampleID
samp$SampleID = NULL

samp %>% summary
samp
# Out:
#              sampling_method  captive_wild    wild_domesticated
#  dried feces sampling:  8    captive: 44   domesticated: 13
#  feces sampling      :154    wild   :141   wild        :172
#  gut section         : 14
#  swab                :  9
#                  sampling_method captive_wild wild_domesticated
# F14_Common_Bream feces sampling  wild         wild
# F35_Red_Deer     feces sampling  wild         wild
# ⋮                ⋮               ⋮            ⋮
# X431_Quagga      feces sampling  captive      wild
# X67_European_Roe feces sampling  wild         wild

# %%
# distance matrix
samp_d = cluster::daisy(samp, metric='gower') 

p.dims(12, 5)
plot(hclust(samp_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# # Ordering matrices

# %%
# checking overlap 
X = labels(beta_d$weighted_unifrac)
overlap(X, labels(host_tree_d))
# Out:
# intersect(x,y): 185
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 185

# %%
# ordering by host tree labels
X = labels(host_tree_d)

beta_d = lapply(beta_d, dist_mtx_order, x=X)

host_tree_d_o = dist_mtx_order(host_tree_d, X)
dietD_d_o = dist_mtx_order(dietD_d, X)
habitatD_d_o = dist_mtx_order(habitatD_d, X)
geo_d_o = dist_mtx_order(geo_d, X)
samp_d_o = dist_mtx_order(samp_d, X)
dtD_d_o = dist_mtx_order(dtD_d, X)

# %%
# checking sizes of beta-div matrices
beta_d %>% lapply(function(x) x %>% as.matrix %>% dim)
# Out:
# $bray_curtis
# [1] 185 185
#
# $jaccard
# [1] 185 185
#
# $unweighted_unifrac
# [1] 185 185
#
# $weighted_unifrac
# [1] 185 185

# %% [markdown]
# # MRM

# %%
# number of permutated SpecD datasetst
nperm_datasets = 100
# number of permutations per MRM analysis
nperm = 1000

# %% [markdown]
# ## Functions

# %%
#' randomly selecting one per group
#' L : list of distance matrixes used for MRM
#' df_grps : data.frame (sample, group)
one_per_group = function(L, df_grps, ...){
    # get subsample
    colnames(df_grps) = c('Sample', 'Group')
    df_grps = df_grps %>%
        group_by(Group) %>%
        sample_n(1)
    # subsetting all matrices
    lapply(L, function(x) dist_mtx_order(x, df_grps$Sample))
}

# %%
#' MRM on one subsample rep
#' i : rep number
#' L : list of list of distance matrices generated by `one_per_group()`
# nperm : nperm function for MRM
# f : MRM fomulat
mrm_each = function(i, L, f, nperm=99){
    m = L[[i]]
    f = as.formula(f)
    x = ecodist::MRM(f, nperm=nperm, mrank=TRUE)
    # coefficients
    df = x$coef %>% as.data.frame
    colnames(df) = c('coef', 'coef_pval')
    df$variable = rownames(df)
    df$R2 = x$r.squared[1]
    df$pval = x$r.squared[2]
    df$F = x$F.test[1]
    df$rep = i
    return(df)
}

# %%
# renaming output
rename_df = data.frame(old_name = c('m$diet', 'm$digest', 'm$geo', 'm$habitat', 'm$host_phy', 'm$samp'),
                       new_name = c('Diet', 'Digestive\nsystem', 'Geography', 'Habitat', 'Phylogeny', 'Technical'))
rename_df
# Out:
#   old_name   new_name
# 1 m$diet     Diet
# 2 m$digest   Digestive\nsystem
# ⋮ ⋮          ⋮
# 5 m$host_phy Phylogeny
# 6 m$samp     Technical

# %%
# lists to store all models
mrm_model1 = list()
mrm_model2 = list()

# %% [markdown]
# ## One per species

# %%
# grouping samples by species
df_grps = meta %>% 
    dt_filter(SampleID %in% labels(dietD_d_o)) %>%
    dt_select(SampleID, scientific_name)
df_grps
# Out:
#     SampleID         scientific_name
# 1   F14_Common_Bream Abramis_brama
# 2   F35_Red_Deer     Cervus_elaphus
# ⋮   ⋮                ⋮
# 184 X431_Quagga      Equus_quagga
# 185 X67_European_Roe Capreolus_capreolus

# %% [markdown]
# ### w-unifrac

# %%
# creating subsample permutations of the distance matrices
L = list(beta = beta_d$weighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2.797513e+03 0.730     Int        0.01519184 0.488 15.39534 1
# m$host_phy 7.574208e-02 0.192     m$host_phy 0.01519184 0.488 15.39534 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.03540771  0.544     m$geo      0.03683676 0.044 38.16911 100
# m$samp99   -0.08364974  0.194     m$samp     0.03683676 0.044 38.16911 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef              coef_pval            R2               pval
#  Min.   :-1.244e-01   Min.   :0.0030   Min.   :0.01453   Min.   :0.0240
#  1st Qu.:-5.169e-02   1st Qu.:0.1500   1st Qu.:0.02116   1st Qu.:0.1130
#  Median : 7.774e-05   Median :0.4360   Median :0.02584   Median :0.1950
#  Mean   : 6.337e-03   Mean   :0.4572   Mean   :0.02676   Mean   :0.2097
#  3rd Qu.: 4.309e-02   3rd Qu.:0.7785   3rd Qu.:0.03108   3rd Qu.:0.2898
#  Max.   : 1.845e-01   Max.   :0.9980   Max.   :0.04748   Max.   :0.5190
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.15
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model1[['w-unifrac']] = mrm_res

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2.913877e+03 0.600     Int        0.01269628 0.455 15.40317 1
# m$host_phy 7.048225e-02 0.234     m$host_phy 0.01269628 0.455 15.40317 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.03480272  0.571     m$geo      0.03681408 0.048 45.7813  100
# m$samp99   -0.08362379  0.194     m$samp     0.03681408 0.048 45.7813  100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.122529   Min.   :0.0040   Min.   :0.01071   Min.   :0.0180
#  1st Qu.:-0.068551   1st Qu.:0.1140   1st Qu.:0.01889   1st Qu.:0.0870
#  Median :-0.001269   Median :0.3425   Median :0.02363   Median :0.1730
#  Mean   : 0.001706   Mean   :0.4028   Mean   :0.02502   Mean   :0.1904
#  3rd Qu.: 0.028006   3rd Qu.:0.6953   3rd Qu.:0.03005   3rd Qu.:0.2695
#  Max.   : 0.180791   Max.   :1.0000   Max.   :0.04624   Max.   :0.5470
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.0
# 2 m$geo      1.0
# 3 m$habitat  1.0
# 4 m$host_phy 0.3
# 5 m$samp     1.0

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model2[['w-unifrac']] = mrm_res

# %% [markdown]
# ### uw-unifrac

# %%
# creating multiple distance matrices
m = list(beta = beta_d$unweighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(m, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2768.2395269 0.810     Int        0.03201851 0.002 33.01145 1
# m$host_phy    0.1399953 0.002     m$host_phy 0.03201851 0.002 33.01145 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.03897443  0.349     m$geo      0.03935514 0.002 40.88548 100
# m$samp99   -0.11882228  0.005     m$samp     0.03935514 0.002 40.88548 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.135811   Min.   :0.0010   Min.   :0.02166   Min.   :0.00100
#  1st Qu.:-0.051923   1st Qu.:0.0070   1st Qu.:0.02991   1st Qu.:0.00100
#  Median : 0.008355   Median :0.0600   Median :0.03322   Median :0.00200
#  Mean   : 0.009374   Mean   :0.2597   Mean   :0.03323   Mean   :0.00241
#  3rd Qu.: 0.071840   3rd Qu.:0.4940   3rd Qu.:0.03646   3rd Qu.:0.00300
#  Max.   : 0.149000   Max.   :0.9960   Max.   :0.04573   Max.   :0.01200
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.03
# 2 m$digest   0.95
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.00
# 6 m$samp     0.12

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model1[['uw-unifrac']] = mrm_res

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2673.1721394 0.923     Int        0.03004227 0.001 37.09917 1
# m$host_phy    0.1443582 0.001     m$host_phy 0.03004227 0.001 37.09917 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.04414646  0.298     m$geo      0.03675407 0.001 45.70383 100
# m$samp99   -0.11967411  0.004     m$samp     0.03675407 0.001 45.70383 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, R2, pval, rep) %>%
    summary
# Out:
#       coef                R2               pval              rep
#  Min.   :-0.13743   Min.   :0.02098   Min.   :0.00100   Min.   :  1.00
#  1st Qu.:-0.02196   1st Qu.:0.02833   1st Qu.:0.00100   1st Qu.: 25.75
#  Median : 0.02412   Median :0.03104   Median :0.00200   Median : 50.50
#  Mean   : 0.01777   Mean   :0.03116   Mean   :0.00223   Mean   : 50.50
#  3rd Qu.: 0.06037   3rd Qu.:0.03373   3rd Qu.:0.00300   3rd Qu.: 75.25
#  Max.   : 0.15438   Max.   :0.04408   Max.   :0.01100   Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.14
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.00
# 5 m$samp     0.07

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model2[['uw-unifrac']] = mrm_res

# %% [markdown]
# ### Bray-Curtis

# %%
# creating multiple distance matrices
L = list(beta = beta_d$bray_curtis,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2093.8012642 0.999     Int        0.08445167 0.001 92.05715 1
# m$host_phy    0.2295048 0.001     m$host_phy 0.08445167 0.001 92.05715 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.06351897  0.206     m$geo      0.06503265 0.001 69.41695 100
# m$samp99   -0.03037274  0.586     m$samp     0.06503265 0.001 69.41695 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.09690   Min.   :0.0010   Min.   :0.05412   Min.   :0.00100
#  1st Qu.:-0.04283   1st Qu.:0.0050   1st Qu.:0.06805   1st Qu.:0.00100
#  Median : 0.01789   Median :0.1090   Median :0.07439   Median :0.00100
#  Mean   : 0.04650   Mean   :0.2200   Mean   :0.07374   Mean   :0.00106
#  3rd Qu.: 0.11165   3rd Qu.:0.3947   3rd Qu.:0.07902   3rd Qu.:0.00100
#  Max.   : 0.26924   Max.   :0.9360   Max.   :0.09359   Max.   :0.00300
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.15
# 2 m$digest   0.17
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.00
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model1[['bray-curtis']] = mrm_res

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2334.9697680 0.986     Int        0.07381815 0.001 95.46654 1
# m$host_phy    0.2186434 0.001     m$host_phy 0.07381815 0.001 95.46654 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.05310554  0.278     m$geo      0.0567716  0.001 72.0939  100
# m$samp99   -0.03008256  0.578     m$samp     0.0567716  0.001 72.0939  100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.08282   Min.   :0.0010   Min.   :0.04115   Min.   :0.0010
#  1st Qu.:-0.04442   1st Qu.:0.0010   1st Qu.:0.05797   1st Qu.:0.0010
#  Median :-0.02430   Median :0.2550   Median :0.06514   Median :0.0010
#  Mean   : 0.04154   Mean   :0.2671   Mean   :0.06434   Mean   :0.0011
#  3rd Qu.: 0.13091   3rd Qu.:0.4545   3rd Qu.:0.07136   3rd Qu.:0.0010
#  Max.   : 0.26218   Max.   :0.9830   Max.   :0.08814   Max.   :0.0040
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0
# 2 m$geo      1
# 3 m$habitat  1
# 4 m$host_phy 0
# 5 m$samp     1

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model2[['bray-curtis']] = mrm_res

# %% [markdown]
# ### Jaccard

# %%
# creating multiple distance matrices
L = list(beta = beta_d$jaccard,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2246.8906563 0.978     Int        0.08413999 0.001 91.68618 1
# m$host_phy    0.2609761 0.001     m$host_phy 0.08413999 0.001 91.68618 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.008543113 0.877     m$geo      0.08086309 0.001 87.80124 100
# m$samp99   -0.066780134 0.272     m$samp     0.08086309 0.001 87.80124 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.13220   Min.   :0.0010   Min.   :0.07039   Min.   :0.00100
#  1st Qu.:-0.02758   1st Qu.:0.0840   1st Qu.:0.08355   1st Qu.:0.00100
#  Median : 0.01733   Median :0.3550   Median :0.08987   Median :0.00100
#  Mean   : 0.04196   Mean   :0.3974   Mean   :0.08943   Mean   :0.00105
#  3rd Qu.: 0.05544   3rd Qu.:0.6770   3rd Qu.:0.09507   3rd Qu.:0.00100
#  Max.   : 0.30871   Max.   :0.9990   Max.   :0.10436   Max.   :0.00200
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.92
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.00
# 6 m$samp     0.92

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model1[['jaccard']] = mrm_res

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2322.5875321 0.964     Int        0.08308011 0.001 108.53   1
# m$host_phy    0.2574542 0.001     m$host_phy 0.08308011 0.001 108.53   1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.006461511 0.91      m$geo      0.08058203 0.001 104.9807 100
# m$samp99   -0.066450224 0.25      m$samp     0.08058203 0.001 104.9807 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.132039   Min.   :0.0010   Min.   :0.06839   Min.   :0.00100
#  1st Qu.:-0.036545   1st Qu.:0.0200   1st Qu.:0.08313   1st Qu.:0.00100
#  Median : 0.009204   Median :0.1525   Median :0.08822   Median :0.00100
#  Mean   : 0.046618   Mean   :0.3264   Mean   :0.08833   Mean   :0.00108
#  3rd Qu.: 0.068265   3rd Qu.:0.6248   3rd Qu.:0.09384   3rd Qu.:0.00100
#  Max.   : 0.307408   Max.   :0.9930   Max.   :0.10369   Max.   :0.00200
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.53
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.00
# 5 m$samp     0.93

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %%
mrm_model2[['jaccard']] = mrm_res

# %% [markdown]
# ## Summary plot

# %% [markdown]
# ### Model2

# %%
mrm_model2 %>% names
# Out:
# [1] "w-unifrac"   "uw-unifrac"  "bray-curtis" "jaccard"

# %%
mrm_res = mrm_model2 %>%
    data.table::rbindlist(use.names=TRUE, idcol='Measure') %>%
    as_tibble %>%
    mutate(Measure = case_when(
             Measure == 'w-unifrac' ~ 'Weighted\nUniFrac',
             Measure == 'uw-unifrac' ~ 'Unweighted\nUniFrac',
             Measure == 'bray-curtis' ~ 'Bray-Curtis',
             Measure == 'jaccard' ~ 'Jaccard'))
mrm_res
# Out:
#      Measure           coef         coef_pval variable   R2         pval
# 1    Weighted\nUniFrac 2.913877e+03 0.600     Int        0.01269628 0.455
# 2    Weighted\nUniFrac 7.048225e-02 0.234     m$host_phy 0.01269628 0.455
# ⋮    ⋮                 ⋮            ⋮         ⋮          ⋮          ⋮
# 2399 Jaccard           -0.006461511 0.91      m$geo      0.08058203 0.001
# 2400 Jaccard           -0.066450224 0.25      m$samp     0.08058203 0.001
#      F        rep
# 1    15.40317 1
# 2    15.40317 1
# ⋮    ⋮        ⋮
# 2399 104.9807 100
# 2400 104.9807 100

# %%
# formatting results
mlevs = c('Weighted\nUniFrac', 'Unweighted\nUniFrac', 'Bray-Curtis', 'Jaccard')
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep, -Measure) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value')) %>%
    mutate(Measure = factor(Measure, levels=mlevs),
           category = factor(category, levels=c('Coef.', 'Adj. P-value')))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value, color=Measure)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw() +
    theme(
        legend.text = element_text(margin = margin(t = 10))
    )

p.dims(6.5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# # Plotting associations

# %%
# converting distance matrix
x_y_df = function(rep, L, x_var){
    x = L[[rep]][[x_var]] %>% as.vector
    y = L[[rep]]$beta %>% as.vector
    df = data.frame(x=x,y=y)
    df$rep=rep
    df$point = 1:nrow(df)
    return(df)
}

# %% [markdown]
# ## w-unifrac

# %%
# creating multiple distance matrices
L = list(beta = beta_d$weighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x_sd x         y_sd       y
# 1    1     0    1         0.03604577 0.5496338
# 2    2     0    1         0.00000000 0.6129921
# ⋮    ⋮     ⋮    ⋮         ⋮          ⋮
# 5994 5994  0    0.1418210 0          0.5809307
# 5995 5995  0    0.7164867 0          1.5472121

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='w-unifrac') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Bray

# %%
# creating multiple distance matrices
L = list(beta = beta_d$bray,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x_sd x         y_sd       y
# 1    1     0    1         0.01406772 0.98572
# 2    2     0    1         0.00000000 1.00000
# ⋮    ⋮     ⋮    ⋮         ⋮          ⋮
# 5994 5994  0    0.1418210 0          0.968
# 5995 5995  0    0.7164867 0          0.756

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     0.6666667 0.98572
# 2    2     0.3333333 1.00000
# ⋮    ⋮     ⋮         ⋮
# 5994 5994  0.3333333 0.968
# 5995 5995  0.5000000 0.756

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='diet', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### digestive system

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='digest')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x    y
# 1    1     0.75 0.98572
# 2    2     0.50 1.00000
# ⋮    ⋮     ⋮    ⋮
# 5994 5994  0    0.968
# 5995 5995  0    0.756

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='digestive system', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Jaccard

# %%
# creating multiple distance matrices
L = list(beta = beta_d$jaccard,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     1         0.953
# 2    2     1         1.000
# ⋮    ⋮     ⋮         ⋮
# 5994 5994  0.1418210 0.7500000
# 5995 5995  0.7164867 0.7777778

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='jaccard') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     0.6666667 0.953
# 2    2     0.3333333 1.000
# ⋮    ⋮     ⋮         ⋮
# 5994 5994  0.3333333 0.7500000
# 5995 5995  0.5000000 0.7777778

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='Diet', y='jaccard') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.6 ape_5.3           tidytable_0.4.1   data.table_1.12.8
# [5] phyloseq_1.30.0   ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.46.0      jsonlite_1.6        splines_3.6.2
# ...
