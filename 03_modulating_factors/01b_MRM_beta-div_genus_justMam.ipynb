# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Functions</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checks</a></span></li></ul></li><li><span><a href="#Dist-matrices" data-toc-modified-id="Dist-matrices-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Dist matrices</a></span><ul class="toc-item"><li><span><a href="#Tree" data-toc-modified-id="Tree-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Tree</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#Digestive-tract" data-toc-modified-id="Digestive-tract-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Digestive tract</a></span></li><li><span><a href="#Habitat" data-toc-modified-id="Habitat-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Habitat</a></span></li><li><span><a href="#Geographic-distance" data-toc-modified-id="Geographic-distance-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Geographic distance</a></span></li><li><span><a href="#Sampling-details" data-toc-modified-id="Sampling-details-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Sampling details</a></span></li></ul></li><li><span><a href="#Ordering-matrices" data-toc-modified-id="Ordering-matrices-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Ordering matrices</a></span></li><li><span><a href="#MRM" data-toc-modified-id="MRM-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>MRM</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#One-per-species" data-toc-modified-id="One-per-species-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>One per species</a></span><ul class="toc-item"><li><span><a href="#w-unifrac" data-toc-modified-id="w-unifrac-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>w-unifrac</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.1.1"><span class="toc-item-num">7.2.1.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.1.2"><span class="toc-item-num">7.2.1.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#uw-unifrac" data-toc-modified-id="uw-unifrac-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>uw-unifrac</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.2.1"><span class="toc-item-num">7.2.2.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.2.2"><span class="toc-item-num">7.2.2.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#Bray-Curtis" data-toc-modified-id="Bray-Curtis-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Bray-Curtis</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.3.1"><span class="toc-item-num">7.2.3.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.3.2"><span class="toc-item-num">7.2.3.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#Jaccard" data-toc-modified-id="Jaccard-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>Jaccard</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.4.1"><span class="toc-item-num">7.2.4.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.4.2"><span class="toc-item-num">7.2.4.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Plotting-associations" data-toc-modified-id="Plotting-associations-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting associations</a></span><ul class="toc-item"><li><span><a href="#w-unifrac" data-toc-modified-id="w-unifrac-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>w-unifrac</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li></ul></li><li><span><a href="#Bray" data-toc-modified-id="Bray-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Bray</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#digestive-system" data-toc-modified-id="digestive-system-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>digestive system</a></span></li></ul></li><li><span><a href="#Jaccard" data-toc-modified-id="Jaccard-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Jaccard</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Diet</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Goal
#
# * Multiple regression on matrices for arch-16S dataset
# * Using beta-diversity calculated on OTUs aggregated at the genus level

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/'

# microbiome
## 16S-arch phyloseq object (one sample per species)
physeq_arch_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_SpecD.RDS'
## 16S-arch phyloseq object (one sample per individual)
physeq_arch_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_IndD.RDS'

# diversity
beta_div_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/diversity-qiime2/beta_div_genus.RDS'

# host tree
host_tree_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch.nwk'
host_tree_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch_IndD.nwk'

# params
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(phyloseq)
library(data.table)
library(tidytable)
library(ape)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt

# %%
df.dims()
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/

# %% [markdown]
# ## Functions

# %%
#' rescaling distance matrix
rescale_dist_mtx = function(m){
    m = m %>% as.matrix
    labs = m %>% colnames
    n_row = m %>% nrow
    n_col = m %>% ncol
    x = m %>% as.vector 
    x = scales::rescale(x) 
    m = matrix(x, nrow=n_row, ncol=n_col)
    colnames(m) = labs
    rownames(m) = labs
    m = m %>% as.dist
    return(m)
}

# %%
#' Ordering distance matrixes
#' d = distance matrix (dist class)
#' x = vector to order dist. obj. by
dist_mtx_order = function(d, x){
    m = d %>% as.matrix
    d = as.dist(m[x,x])
    return(d)
}

# %% [markdown]
# # Load

# %%
# phyloseq
physeq_arch_SpecD = readRDS(physeq_arch_SpecD_file) %>%
    subset_samples(class == 'Mammalia') %>%
    filter_taxa(function(x) sum(x) > 0, TRUE)
physeq_arch_SpecD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 798 taxa and 71 samples ]
# sample_data() Sample Data:       [ 71 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 798 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 798 tips and 797 internal nodes ]

# %%
# phyloseq
physeq_arch_IndD = readRDS(physeq_arch_IndD_file) %>%
    subset_samples(class == 'Mammalia') %>%
    filter_taxa(function(x) sum(x) > 0, TRUE)
physeq_arch_IndD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1438 taxa and 133 samples ]
# sample_data() Sample Data:       [ 133 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 1438 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1438 tips and 1435 internal nodes ]

# %%
# beta diversity
beta_d = readRDS(beta_div_file)
beta_d %>% length
# Out:
# [1] 4

# %%
# host tree
host_tree = read.tree(host_tree_IndD_file)
host_tree
# Out:
# Phylogenetic tree with 185 tips and 184 internal nodes.
#
# Tip labels:
# 	X60_European_Chub, X179_Roach, X330_Ide, X327_Silver_Bream, X326_Silver_Bream, F14_Common_Bream, ...
# Node labels:
# 	, @_20_@, @_17_@, @_14_@, @_9_@, @_15_@, ...
#
# Rooted; includes branch lengths.

# %%
# metadata (IndD)
meta = physeq_arch_IndD %>% sample_data %>% as.matrix %>% as.data.table
meta
# Out:
#     SampleID         host_subject_id host_german_name host_common_name
# 1   F35_Red_Deer     F35             Rothirsch        Red.Deer
# 2   F36_Red_Deer     F36             Rothirsch        Red.Deer
# ⋮   ⋮                ⋮               ⋮                ⋮
# 132 X431_Quagga      431             Steppenzebra     Quagga
# 133 X67_European_Roe 67              Reh              European.Roe
#     scientific_name     scientific_name_subspecies host_taxid class
# 1   Cervus_elaphus      NA                            9860    Mammalia
# 2   Cervus_elaphus      NA                            9860    Mammalia
# ⋮   ⋮                   ⋮                          ⋮          ⋮
# 132 Equus_quagga        NA                           89252    Mammalia
# 133 Capreolus_capreolus NA                            9858    Mammalia
#     order          family   ⋯ CH4_kJ.d_mean CH4_kJ.d_sd i.CH4_L.d_mean
# 1   Artiodactyla   Cervidae ⋯  2066.94152   1075.50477   52.2413228
# 2   Artiodactyla   Cervidae ⋯  2066.94152   1075.50477   52.2413228
# ⋮   ⋮              ⋮        ⋱ ⋮             ⋮           ⋮
# 132 Perissodactyla Equidae  ⋯ NA            NA          NA
# 133 Artiodactyla   Cervidae ⋯ NA            NA          NA
#     i.CH4_L.d_sd i.CH4_L.kgBM_mean i.CH4_L.kgBM_sd i.CH4_g.d_mean i.CH4_g.d_sd
# 1   27.1830584   0.4858472         0.16869553       38.6711742    21.3016201
# 2   27.1830584   0.4858472         0.16869553       38.6711742    21.3016201
# ⋮   ⋮            ⋮                 ⋮               ⋮              ⋮
# 132 NA           NA                NA              NA             NA
# 133 NA           NA                NA              NA             NA
#     i.CH4_kJ.d_mean i.CH4_kJ.d_sd
# 1    2066.94152     1075.50477
# 2    2066.94152     1075.50477
# ⋮   ⋮               ⋮
# 132 NA              NA
# 133 NA              NA

# %% [markdown]
# ## Checks

# %%
# overlap of sampleIDs
overlap(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
# Out:
# intersect(x,y): 133
# setdiff(x,y): 52
# setdiff(y,x): 0
# union(x,y): 185

# %%
# filtering host tree
to_rm = setdiff(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
to_rm %>% length
host_tree = ape::drop.tip(host_tree, to_rm)
host_tree
# Out:
# [1] 52
# Phylogenetic tree with 133 tips and 132 internal nodes.
#
# Tip labels:
# 	X369_Koala, X283_Koala, X281_Tammar_Wallaby, X290_Eastern_Grey_Kangaroo, X289_Eastern_Grey_Kangaroo, X280_Western_Grey_Kangaroo, ...
# Node labels:
# 	@_195_@, @_194_@, @_98_@, NA, @_97_@, @_96_@, ...
#
# Rooted; includes branch lengths.

# %% [markdown]
# # Dist matrices
#
# * Creating distance matrices

# %% [markdown]
# ## Tree

# %%
host_tree_d = host_tree %>% cophenetic %>% as.dist %>% rescale_dist_mtx 
p.dims(12,4)
plot(hclust(host_tree_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Diet

# %%
dietD = meta %>%
    dt_select(SampleID, diet_vertebrate, diet_invertebrate, diet_fruit,
              diet_flowers_nectar_pollen, diet_leaves_branches_bark_buds, diet_seeds,
             diet_grass_waterplants, diet_roots_tubers) %>%
    dt_mutate(diet_invertebrate = gsub(' .+', '', diet_invertebrate) %>% as.factor) %>%
    as.data.frame

rownames(dietD) = dietD$SampleID
dietD$SampleID = NULL

cn = colnames(dietD)
dietD = dietD %>% 
    apply(1, function(x) ifelse(x=='yes', 1, 0)) %>%
    t %>% as.data.frame
colnames(dietD) = cn

# status
dietD
# Out:
#                  diet_vertebrate diet_invertebrate diet_fruit
# F35_Red_Deer     0               0                 1
# F36_Red_Deer     0               0                 1
# ⋮                ⋮               ⋮                 ⋮
# X431_Quagga      0               0                 0
# X67_European_Roe 0               0                 1
#                  diet_flowers_nectar_pollen diet_leaves_branches_bark_buds
# F35_Red_Deer     0                          1
# F36_Red_Deer     0                          1
# ⋮                ⋮                          ⋮
# X431_Quagga      0                          0
# X67_European_Roe 0                          1
#                  diet_seeds diet_grass_waterplants diet_roots_tubers
# F35_Red_Deer     1          1                      1
# F36_Red_Deer     1          1                      1
# ⋮                ⋮          ⋮                      ⋮
# X431_Quagga      1          1                      0
# X67_European_Roe 1          1                      0

# %%
# distance
dietD_d = vegan::vegdist(dietD, metric='jaccard')

p.dims(12,5)
plot(hclust(dietD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Digestive tract

# %%
dtD = meta %>%
    dt_select(SampleID, 
              digestive_system, digestive_system_detail, 
              ruminant, pseudoruminants) %>%
    dt_mutate(digestive_system = gsub('_', ' ', digestive_system),
              digestive_system = gsub('fermentation activity foregut', 'forgut', digestive_system),
              digestive_system_detail = gsub('^_', '', digestive_system_detail),
              digestive_system_detail = gsub('_', ' ', digestive_system_detail),
              digestive_system_detail = gsub(' +', ' ', digestive_system_detail)) %>%
    dt_mutate(digestive_system = digestive_system %>% as.factor,
              digestive_system_detail = digestive_system_detail %>% as.factor,
              ruminant = ruminant %>% as.factor,
              pseudoruminants = pseudoruminants %>% as.factor) %>%
    as.data.frame

rownames(dtD) = dtD$SampleID
dtD$SampleID = NULL

dtD %>% summary
dtD
# Out:
#        digestive_system                  digestive_system_detail ruminant
#  foregut       :55      caecum                       :20         no :92
#  forgut        : 1      colocecal fermentation       : 2         yes:41
#  hindgut       :28      colon                        :18
#  simple        :37      fermentation activity foregut: 3
#  simple foregut: 2      foregut                      :55
#  simple hindgut:10      hindgut                      : 4
#                         simple                       :31
#       pseudoruminants
#  no           :118
#  ruminant_like: 10
#  yes          :  5
#                  digestive_system digestive_system_detail ruminant
# F35_Red_Deer     foregut          foregut                 yes
# F36_Red_Deer     foregut          foregut                 yes
# ⋮                ⋮                ⋮                       ⋮
# X431_Quagga      hindgut          colon                   no
# X67_European_Roe foregut          foregut                 yes
#                  pseudoruminants
# F35_Red_Deer     no
# F36_Red_Deer     no
# ⋮                ⋮
# X431_Quagga      no
# X67_European_Roe no

# %%
dtD_d = cluster::daisy(dtD, metric='gower')

p.dims(12,5)
plot(hclust(dtD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Habitat

# %%
habitatD = meta %>%
    dt_select(SampleID, habitat, habitat_detail, habitat_detail_1, habitat_detail_2) %>%
    dt_mutate_across(everything.(), function(x) as.factor(gsub(' habitat$', '', x))) %>%
    as.data.frame

rownames(habitatD) = habitatD$SampleID
habitatD$SampleID = NULL

habitatD %>% summary
habitatD
# Out:
#           habitat          habitat_detail      habitat_detail_1
#  anthropogenic:  5   anthropogenic: 5     terrestrial  :58
#  aquatic      :  4   cultivated   : 3     forest       :34
#  terrestrial  :124   grassland    :29     meadow       :13
#                      saline water : 4     steppe       : 8
#                      terrestrial  :58     pasture      : 7
#                      woodland     :34     anthropogenic: 5
#                                           (Other)      : 8
#       habitat_detail_2
#  terrestrial  :58
#  forest       :34
#  flood meadow :13
#  steppe       : 8
#  pasture      : 7
#  anthropogenic: 5
#  (Other)      : 8
#                  habitat     habitat_detail habitat_detail_1 habitat_detail_2
# F35_Red_Deer     terrestrial grassland      meadow           flood meadow
# F36_Red_Deer     terrestrial grassland      meadow           flood meadow
# ⋮                ⋮           ⋮              ⋮                ⋮
# X431_Quagga      terrestrial terrestrial    terrestrial      terrestrial
# X67_European_Roe terrestrial woodland       forest           forest

# %%
habitatD_d = cluster::daisy(habitatD, metric='gower') 

p.dims(12,5)
plot(hclust(habitatD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Geographic distance

# %%
geo = meta %>% 
    dt_select(SampleID, latitude, longitude) %>%
    dt_mutate(latitude = latitude %>% as.Num,
           longitude = longitude %>% as.Num) %>%
    as.data.frame

rownames(geo) = geo$SampleID

geo$latitude %>% summary %>% print
geo$longitude %>% summary %>% print
geo
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -35.833   9.749  47.224  27.983  48.208  55.290
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -84.10   15.81   16.37   32.53   34.65  138.68
#                  SampleID         latitude longitude
# F35_Red_Deer     F35_Red_Deer     48.20833 16.37306
# F36_Red_Deer     F36_Red_Deer     48.20833 16.37306
# ⋮                ⋮                ⋮        ⋮
# X431_Quagga      X431_Quagga      47.22400 15.81200
# X67_European_Roe X67_European_Roe 48.20833 16.37306

# %%
.pairwise_distGeo = function(x, y){
    d = geosphere::distGeo(x[c('longitude', 'latitude')],
                           y[,c('longitude', 'latitude')])
    return(d)
}

pairwise_distGeo = function(df){
    x = df[,c('longitude', 'latitude')]
    geo_d = apply(x, 1, .pairwise_distGeo, y=x)
    rescale_dist_mtx(as.dist(geo_d))
}

geo_d = pairwise_distGeo(geo)

p.dims(12,5)
plot(hclust(geo_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Sampling details

# %%
samp = meta %>% 
    dt_select(SampleID, sampling_method, captive_wild, wild_domesticated) %>%
    dt_mutate_across(everything.(), as.factor) %>%
    as.data.frame

rownames(samp) = samp$SampleID
samp$SampleID = NULL

samp %>% summary
samp
# Out:
#              sampling_method  captive_wild    wild_domesticated
#  dried feces sampling:  8    captive:39    domesticated: 12
#  feces sampling      :119    wild   :94    wild        :121
#  gut section         :  3
#  swab                :  3
#                  sampling_method captive_wild wild_domesticated
# F35_Red_Deer     feces sampling  wild         wild
# F36_Red_Deer     feces sampling  wild         wild
# ⋮                ⋮               ⋮            ⋮
# X431_Quagga      feces sampling  captive      wild
# X67_European_Roe feces sampling  wild         wild

# %%
# distance matrix
samp_d = cluster::daisy(samp, metric='gower') 

p.dims(12, 5)
plot(hclust(samp_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# # Ordering matrices

# %%
# checking overlap 
X = labels(beta_d$weighted_unifrac)
overlap(X, labels(host_tree_d))
# Out:
# intersect(x,y): 133
# setdiff(x,y): 52
# setdiff(y,x): 0
# union(x,y): 185

# %%
# ordering by host tree labels
X = labels(host_tree_d)

beta_d = lapply(beta_d, dist_mtx_order, x=X)

host_tree_d_o = dist_mtx_order(host_tree_d, X)
dietD_d_o = dist_mtx_order(dietD_d, X)
habitatD_d_o = dist_mtx_order(habitatD_d, X)
geo_d_o = dist_mtx_order(geo_d, X)
samp_d_o = dist_mtx_order(samp_d, X)
dtD_d_o = dist_mtx_order(dtD_d, X)

# %%
# checking sizes of beta-div matrices
beta_d %>% lapply(function(x) x %>% as.matrix %>% dim)
# Out:
# $bray_curtis
# [1] 133 133
#
# $jaccard
# [1] 133 133
#
# $unweighted_unifrac
# [1] 133 133
#
# $weighted_unifrac
# [1] 133 133

# %% [markdown]
# # MRM

# %%
# number of permutated SpecD datasetst
nperm_datasets = 100
# number of permutations per MRM analysis
nperm = 1000

# %% [markdown]
# ## Functions

# %%
#' randomly selecting one per group
#' L : list of distance matrixes used for MRM
#' df_grps : data.frame (sample, group)
one_per_group = function(L, df_grps, ...){
    # get subsample
    colnames(df_grps) = c('Sample', 'Group')
    df_grps = df_grps %>%
        group_by(Group) %>%
        sample_n(1)
    # subsetting all matrices
    lapply(L, function(x) dist_mtx_order(x, df_grps$Sample))
}

# %%
#' MRM on one subsample rep
#' i : rep number
#' L : list of list of distance matrices generated by `one_per_group()`
# nperm : nperm function for MRM
# f : MRM fomulat
mrm_each = function(i, L, f, nperm=99){
    m = L[[i]]
    f = as.formula(f)
    x = ecodist::MRM(f, nperm=nperm, mrank=TRUE)
    # coefficients
    df = x$coef %>% as.data.frame
    colnames(df) = c('coef', 'coef_pval')
    df$variable = rownames(df)
    df$R2 = x$r.squared[1]
    df$pval = x$r.squared[2]
    df$F = x$F.test[1]
    df$rep = i
    return(df)
}

# %%
# renaming output
rename_df = data.frame(old_name = c('m$diet', 'm$digest', 'm$geo', 'm$habitat', 'm$host_phy', 'm$samp'),
                       new_name = c('Diet', 'Digestive\nsystem', 'Geography', 'Habitat', 'Phylogeny', 'Technical'))
rename_df
# Out:
#   old_name   new_name
# 1 m$diet     Diet
# 2 m$digest   Digestive\nsystem
# ⋮ ⋮          ⋮
# 5 m$host_phy Phylogeny
# 6 m$samp     Technical

# %% [markdown]
# ## One per species

# %%
# grouping samples by species
df_grps = meta %>% 
    dt_filter(SampleID %in% labels(dietD_d_o)) %>%
    dt_select(SampleID, scientific_name)
df_grps
# Out:
#     SampleID         scientific_name
# 1   F35_Red_Deer     Cervus_elaphus
# 2   F36_Red_Deer     Cervus_elaphus
# ⋮   ⋮                ⋮
# 132 X431_Quagga      Equus_quagga
# 133 X67_European_Roe Capreolus_capreolus

# %% [markdown]
# ### w-unifrac

# %%
# creating subsample permutations of the distance matrices
L = list(beta = beta_d$weighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        1214.1555736 0.556     Int        0.03036146 0.288 12.93191 1
# m$host_phy    0.1477816 0.055     m$host_phy 0.03036146 0.288 12.93191 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.05733617  0.416     m$geo      0.02242906 0.43  9.475735 100
# m$samp99    0.06608472  0.414     m$samp     0.02242906 0.43  9.475735 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.120124   Min.   :0.0020   Min.   :0.01574   Min.   :0.0160
#  1st Qu.:-0.051661   1st Qu.:0.2452   1st Qu.:0.02690   1st Qu.:0.1633
#  Median :-0.008740   Median :0.5205   Median :0.03125   Median :0.2320
#  Mean   : 0.007531   Mean   :0.4993   Mean   :0.03427   Mean   :0.2513
#  3rd Qu.: 0.030355   3rd Qu.:0.7562   3rd Qu.:0.03842   3rd Qu.:0.3415
#  Max.   : 0.278679   Max.   :0.9990   Max.   :0.07569   Max.   :0.6250
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.49
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        1246.4983271 0.507     Int        0.02902074 0.319 14.81853 1
# m$host_phy    0.1540023 0.042     m$host_phy 0.02902074 0.319 14.81853 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.05810383  0.381     m$geo      0.02233086 0.345 11.32453 100
# m$samp99    0.06583272  0.422     m$samp     0.02233086 0.345 11.32453 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.121351   Min.   :0.0010   Min.   :0.01511   Min.   :0.0100
#  1st Qu.:-0.061459   1st Qu.:0.2032   1st Qu.:0.02642   1st Qu.:0.1435
#  Median :-0.016957   Median :0.4250   Median :0.03101   Median :0.1920
#  Mean   : 0.007791   Mean   :0.4505   Mean   :0.03390   Mean   :0.2228
#  3rd Qu.: 0.041719   3rd Qu.:0.7083   3rd Qu.:0.03825   3rd Qu.:0.3028
#  Max.   : 0.277102   Max.   :0.9950   Max.   :0.07562   Max.   :0.6080
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.32
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### uw-unifrac

# %%
# creating multiple distance matrices
m = list(beta = beta_d$unweighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(m, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2          pval  F        rep
# Int        1.182847e+03 0.794     Int        0.004678692 0.401 1.941383 1
# m$host_phy 4.211998e-02 0.197     m$host_phy 0.004678692 0.401 1.941383 1
# ⋮          ⋮            ⋮         ⋮          ⋮           ⋮     ⋮        ⋮
# m$geo99     0.01547512  0.665     m$geo      0.01367703  0.065 5.726941 100
# m$samp99   -0.02236992  0.587     m$samp     0.01367703  0.065 5.726941 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2                pval
#  Min.   :-0.07207   Min.   :0.0010   Min.   :0.001574   Min.   :0.00200
#  1st Qu.:-0.02458   1st Qu.:0.0980   1st Qu.:0.009745   1st Qu.:0.03325
#  Median : 0.01513   Median :0.3165   Median :0.013547   Median :0.07900
#  Mean   : 0.01818   Mean   :0.3667   Mean   :0.015751   Mean   :0.16445
#  3rd Qu.: 0.05250   3rd Qu.:0.5875   3rd Qu.:0.021562   3rd Qu.:0.22725
#  Max.   : 0.16964   Max.   :0.9960   Max.   :0.042441   Max.   :0.93600
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.67
# 2 m$digest   0.99
# 3 m$geo      1.00
# 4 m$habitat  0.96
# 5 m$host_phy 0.42
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2          pval  F        rep
# Int        1.167255e+03 0.842     Int        0.004375147 0.361 2.17873  1
# m$host_phy 3.932756e-02 0.216     m$host_phy 0.004375147 0.361 2.17873  1
# ⋮          ⋮            ⋮         ⋮          ⋮           ⋮     ⋮        ⋮
# m$geo99     0.01677017  0.613     m$geo      0.01210687  0.084 6.076148 100
# m$samp99   -0.02155110  0.584     m$samp     0.01210687  0.084 6.076148 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, R2, pval, rep) %>%
    summary
# Out:
#       coef                 R2                pval              rep
#  Min.   :-0.070120   Min.   :0.001017   Min.   :0.00200   Min.   :  1.00
#  1st Qu.:-0.005832   1st Qu.:0.008657   1st Qu.:0.03025   1st Qu.: 25.75
#  Median : 0.026188   Median :0.012290   Median :0.08050   Median : 50.50
#  Mean   : 0.026609   Mean   :0.014537   Mean   :0.16595   Mean   : 50.50
#  3rd Qu.: 0.052302   3rd Qu.:0.020049   3rd Qu.:0.24325   3rd Qu.: 75.25
#  Max.   : 0.161592   Max.   :0.040954   Max.   :0.96300   Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.77
# 2 m$geo      1.00
# 3 m$habitat  0.96
# 4 m$host_phy 0.48
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### Bray-Curtis

# %%
# creating multiple distance matrices
L = list(beta = beta_d$bray_curtis,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef        coef_pval variable   R2         pval  F        rep
# Int        949.0896805 0.958     Int        0.07273174 0.006 32.3943  1
# m$host_phy   0.2401376 0.002     m$host_phy 0.07273174 0.006 32.3943  1
# ⋮          ⋮           ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.13738652 0.03      m$geo      0.06551457 0.005 28.95446 100
# m$samp99    0.04203565 0.53      m$samp     0.06551457 0.005 28.95446 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.16940   Min.   :0.0010   Min.   :0.03428   Min.   :0.00100
#  1st Qu.:-0.01414   1st Qu.:0.0210   1st Qu.:0.04818   1st Qu.:0.00500
#  Median : 0.04000   Median :0.1270   Median :0.05434   Median :0.00900
#  Mean   : 0.03702   Mean   :0.2984   Mean   :0.05501   Mean   :0.01471
#  3rd Qu.: 0.10449   3rd Qu.:0.5720   3rd Qu.:0.06114   3rd Qu.:0.02000
#  Max.   : 0.25460   Max.   :0.9990   Max.   :0.08339   Max.   :0.06700
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.29
# 2 m$digest   0.96
# 3 m$geo      0.31
# 4 m$habitat  1.00
# 5 m$host_phy 0.09
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef        coef_pval variable   R2         pval  F        rep
# Int        950.9298548 0.940     Int        0.07272731 0.004 38.88629 1
# m$host_phy   0.2404835 0.002     m$host_phy 0.07272731 0.004 38.88629 1
# ⋮          ⋮           ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.13875197 0.028     m$geo      0.06251164 0.005 33.0599  100
# m$samp99    0.04191065 0.494     m$samp     0.06251164 0.005 33.0599  100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.17117   Min.   :0.0010   Min.   :0.03183   Min.   :0.00100
#  1st Qu.:-0.03529   1st Qu.:0.0060   1st Qu.:0.04679   1st Qu.:0.00500
#  Median : 0.03766   Median :0.0405   Median :0.05223   Median :0.01000
#  Mean   : 0.03915   Mean   :0.2707   Mean   :0.05325   Mean   :0.01474
#  3rd Qu.: 0.12826   3rd Qu.:0.5685   3rd Qu.:0.05878   3rd Qu.:0.01800
#  Max.   : 0.25979   Max.   :0.9960   Max.   :0.08309   Max.   :0.07000
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.05
# 2 m$geo      0.24
# 3 m$habitat  1.00
# 4 m$host_phy 0.08
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### Jaccard

# %%
# creating multiple distance matrices
L = list(beta = beta_d$jaccard,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        1058.5640926 0.884     Int        0.04512635 0.016 19.51796 1
# m$host_phy    0.1399923 0.018     m$host_phy 0.04512635 0.016 19.51796 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.02082686  0.737     m$geo      0.07820398 0.003 35.03839 100
# m$samp99   -0.04285705  0.526     m$samp     0.07820398 0.003 35.03839 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.14834   Min.   :0.0010   Min.   :0.02320   Min.   :0.00100
#  1st Qu.:-0.02262   1st Qu.:0.1087   1st Qu.:0.03683   1st Qu.:0.01275
#  Median : 0.01996   Median :0.3670   Median :0.04360   Median :0.03050
#  Mean   : 0.02745   Mean   :0.4107   Mean   :0.04609   Mean   :0.04356
#  3rd Qu.: 0.06801   3rd Qu.:0.7043   3rd Qu.:0.05461   3rd Qu.:0.05400
#  Max.   : 0.25640   Max.   :1.0000   Max.   :0.08071   Max.   :0.29500
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.97
# 2 m$digest   0.93
# 3 m$geo      1.00
# 4 m$habitat  0.97
# 5 m$host_phy 0.13
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$beta ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        1160.1941855 0.698     Int        0.03328236 0.045 17.06951 1
# m$host_phy    0.1606944 0.013     m$host_phy 0.03328236 0.045 17.06951 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.02225170  0.724     m$geo      0.07780196 0.003 41.82856 100
# m$samp99   -0.04333489  0.555     m$samp     0.07780196 0.003 41.82856 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval             R2               pval
#  Min.   :-0.14807   Min.   :0.00100   Min.   :0.02121   Min.   :0.00100
#  1st Qu.:-0.04004   1st Qu.:0.06775   1st Qu.:0.03324   1st Qu.:0.01200
#  Median : 0.01994   Median :0.33400   Median :0.04175   Median :0.02900
#  Mean   : 0.02793   Mean   :0.37953   Mean   :0.04414   Mean   :0.04526
#  3rd Qu.: 0.07427   3rd Qu.:0.65550   3rd Qu.:0.05384   3rd Qu.:0.06025
#  Max.   : 0.26000   Max.   :0.99800   Max.   :0.08071   Max.   :0.23700
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.87
# 2 m$geo      1.00
# 3 m$habitat  0.99
# 4 m$host_phy 0.03
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.35) %>%
    .[1:2,]
df_c[2,'value'] = -0.15
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# # Plotting associations

# %%
# converting distance matrix
x_y_df = function(rep, L, x_var){
    x = L[[rep]][[x_var]] %>% as.vector
    y = L[[rep]]$beta %>% as.vector
    df = data.frame(x=x,y=y)
    df$rep=rep
    df$point = 1:nrow(df)
    return(df)
}

# %% [markdown]
# ## w-unifrac

# %%
# creating multiple distance matrices
L = list(beta = beta_d$weighted_unifrac,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x_sd x         y_sd       y
# 1    1     0    0.3162869 0.01059828 1.2539357
# 2    2     0    0.1390400 0.01061976 0.0538608
# ⋮    ⋮     ⋮    ⋮         ⋮          ⋮
# 2484 2484  0    0.8963987 0.06780961 1.814384
# 2485 2485  0    0.5452086 0.00000000 0.544775

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='w-unifrac') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Bray

# %%
# creating multiple distance matrices
L = list(beta = beta_d$bray,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x_sd x         y_sd       y
# 1    1     0    0.3162869 0.01205804 0.72376
# 2    2     0    0.1390400 0.02797040 0.10140
# ⋮    ⋮     ⋮    ⋮         ⋮          ⋮
# 2484 2484  0    0.8963987 0.03617412 0.96328
# 2485 2485  0    0.5452086 0.00000000 0.26000

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     1.0000000 0.72376
# 2    2     0.3333333 0.10140
# ⋮    ⋮     ⋮         ⋮
# 2484 2484  0.5       0.96328
# 2485 2485  0.0       0.26000

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='diet', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### digestive system

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='digest')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x    y
# 1    1     0.75 0.72376
# 2    2     0.00 0.10140
# ⋮    ⋮     ⋮    ⋮
# 2484 2484  0.5  0.96328
# 2485 2485  0.0  0.26000

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='digestive system', y='bray-curtis') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Jaccard

# %%
# creating multiple distance matrices
L = list(beta = beta_d$jaccard,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     0.3162869 0.4766667
# 2    2     0.1390400 0.5136667
# ⋮    ⋮     ⋮         ⋮
# 2484 2484  0.8963987 0.7700000
# 2485 2485  0.5452086 0.5714286

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='host patristic distance', y='jaccard') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     1.0000000 0.4766667
# 2    2     0.3333333 0.5136667
# ⋮    ⋮     ⋮         ⋮
# 2484 2484  0.5       0.7700000
# 2485 2485  0.0       0.5714286

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    labs(x='Diet', y='jaccard') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.6 ape_5.3           tidytable_0.4.1   data.table_1.12.8
# [5] phyloseq_1.30.0   ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.46.0      jsonlite_1.6        splines_3.6.2
#  [4] foreach_1.4.7       assertthat_0.2.1    sp_1.4-2
#  [7] stats4_3.6.2        pillar_1.4.3        lattice_0.20-38
# [10] glue_1.3.1          uuid_0.1-2          digest_0.6.23
# [13] XVector_0.26.0      colorspace_1.4-1    htmltools_0.4.0
# [16] Matrix_1.2-18       plyr_1.8.5          pkgconfig_2.0.3
# [19] zlibbioc_1.32.0     purrr_0.3.3         scales_1.1.1
# [22] tibble_2.1.3        mgcv_1.8-31         farver_2.0.3
# [25] IRanges_2.20.0      ellipsis_0.3.0      withr_2.1.2
# [28] repr_1.0.2          BiocGenerics_0.32.0 lazyeval_0.2.2
# [31] survival_3.1-8      magrittr_1.5        crayon_1.3.4
# [34] evaluate_0.14       doParallel_1.0.15   nlme_3.1-143
# [37] MASS_7.3-51.5       vegan_2.5-6         tools_3.6.2
# [40] geosphere_1.5-10    lifecycle_0.1.0     stringr_1.4.0
# [43] Rhdf5lib_1.8.0      S4Vectors_0.24.0    munsell_0.5.0
# [46] cluster_2.1.0       Biostrings_2.54.0   ade4_1.7-13
# [49] compiler_3.6.2      rlang_0.4.6         rhdf5_2.30.0
# [52] grid_3.6.2          pbdZMQ_0.3-3        iterators_1.0.12
# [55] IRkernel_1.1        biomformat_1.14.0   igraph_1.2.4.2
# [58] base64enc_0.1-3     labeling_0.3        gtable_0.3.0
# [61] codetools_0.2-16    multtest_2.42.0     reshape2_1.4.3
# [64] R6_2.4.1            knitr_1.26          permute_0.9-5
# [67] stringi_1.4.5       parallel_3.6.2      IRdisplay_0.7.0
# [70] Rcpp_1.0.3          vctrs_0.3.1         tidyselect_1.1.0
# [73] xfun_0.12
