# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Functions</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checks</a></span></li></ul></li><li><span><a href="#Dist-matrices" data-toc-modified-id="Dist-matrices-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Dist matrices</a></span><ul class="toc-item"><li><span><a href="#Alpha-diversity" data-toc-modified-id="Alpha-diversity-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Alpha diversity</a></span></li><li><span><a href="#Tree" data-toc-modified-id="Tree-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Tree</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#Digestive-tract" data-toc-modified-id="Digestive-tract-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Digestive tract</a></span></li><li><span><a href="#Habitat" data-toc-modified-id="Habitat-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Habitat</a></span></li><li><span><a href="#Geographic-distance" data-toc-modified-id="Geographic-distance-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Geographic distance</a></span></li><li><span><a href="#Sampling-details" data-toc-modified-id="Sampling-details-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Sampling details</a></span></li></ul></li><li><span><a href="#Ordering-matrices" data-toc-modified-id="Ordering-matrices-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Ordering matrices</a></span></li><li><span><a href="#MRM" data-toc-modified-id="MRM-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>MRM</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#One-per-species" data-toc-modified-id="One-per-species-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>One per species</a></span><ul class="toc-item"><li><span><a href="#faiths-PD" data-toc-modified-id="faiths-PD-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>faiths PD</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.1.1"><span class="toc-item-num">7.2.1.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.1.2"><span class="toc-item-num">7.2.1.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#shannon" data-toc-modified-id="shannon-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>shannon</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.2.1"><span class="toc-item-num">7.2.2.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.2.2"><span class="toc-item-num">7.2.2.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#observed-OTUs" data-toc-modified-id="observed-OTUs-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>observed OTUs</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.3.1"><span class="toc-item-num">7.2.3.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.3.2"><span class="toc-item-num">7.2.3.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li><li><span><a href="#shannon-(iNEXT:-hill)" data-toc-modified-id="shannon-(iNEXT:-hill)-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>shannon (iNEXT: hill)</a></span><ul class="toc-item"><li><span><a href="#Model1" data-toc-modified-id="Model1-7.2.4.1"><span class="toc-item-num">7.2.4.1&nbsp;&nbsp;</span>Model1</a></span></li><li><span><a href="#Model2" data-toc-modified-id="Model2-7.2.4.2"><span class="toc-item-num">7.2.4.2&nbsp;&nbsp;</span>Model2</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Plotting-associations" data-toc-modified-id="Plotting-associations-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting associations</a></span><ul class="toc-item"><li><span><a href="#faiths-PD" data-toc-modified-id="faiths-PD-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>faiths PD</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li></ul></li><li><span><a href="#Bray" data-toc-modified-id="Bray-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Bray</a></span><ul class="toc-item"><li><span><a href="#Host-phylogeny" data-toc-modified-id="Host-phylogeny-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Host phylogeny</a></span></li><li><span><a href="#Diet" data-toc-modified-id="Diet-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Diet</a></span></li><li><span><a href="#digestive-system" data-toc-modified-id="digestive-system-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>digestive system</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Goal
#
# * Multiple regression on matrices for arch-16S dataset

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/'

# microbiome
## 16S-arch phyloseq object (one sample per species)
physeq_arch_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_SpecD.RDS'
## 16S-arch phyloseq object (one sample per individual)
physeq_arch_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_IndD.RDS'

# diversity
alpha_div_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/diversity-qiime2/alpha_div_genus.RDS'
alpha_div_hill_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S/LLA/diversity//alpha_div_iNEXT.RDS'

# host tree
host_tree_SpecD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch.nwk'
host_tree_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch_IndD.nwk'

# params
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(phyloseq)
library(data.table)
library(tidytable)
library(ape)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
#
# Attaching package: ‘tidytable’
#
#
# The following object is masked from ‘package:stats’:
#
#     dt

# %%
df.dims()
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/modulating/

# %% [markdown]
# ## Functions

# %%
#' rescaling distance matrix
rescale_dist_mtx = function(m){
    m = m %>% as.matrix
    labs = m %>% colnames
    n_row = m %>% nrow
    n_col = m %>% ncol
    x = m %>% as.vector 
    x = scales::rescale(x) 
    m = matrix(x, nrow=n_row, ncol=n_col)
    colnames(m) = labs
    rownames(m) = labs
    m = m %>% as.dist
    return(m)
}

# %%
#' Ordering distance matrixes
#' d = distance matrix (dist class)
#' x = vector to order dist. obj. by
dist_mtx_order = function(d, x){
    m = d %>% as.matrix
    d = as.dist(m[x,x])
    return(d)
}

# %% [markdown]
# # Load

# %%
# phyloseq
physeq_arch_SpecD = readRDS(physeq_arch_SpecD_file)
physeq_arch_SpecD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1151 taxa and 110 samples ]
# sample_data() Sample Data:       [ 110 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 1151 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1151 tips and 1150 internal nodes ]

# %%
# phyloseq
physeq_arch_IndD = readRDS(physeq_arch_IndD_file)
physeq_arch_IndD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1891 taxa and 185 samples ]
# sample_data() Sample Data:       [ 185 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 1891 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1891 tips and 1888 internal nodes ]

# %%
# alpha diversity calculated by QIIME2 (rarefaction)
alpha_div = readRDS(alpha_div_file) %>%
    do.call(cbind, .) %>%
    mutate(Sample = rownames(.))
alpha_div
# Out:
#     pielou_e   observed_otus shannon    faith_pd Sample
# 1   0.4255973  7             1.194803   2.629572 F14_Common_Bream
# 2   0.7088848  5             1.645979   3.286218 F35_Red_Deer
# ⋮   ⋮          ⋮             ⋮          ⋮        ⋮
# 184 0.43631269 4             0.87262539 2.754449 X431_Quagga
# 185 0.03762236 2             0.03762236 1.109893 X67_European_Roe

# %%
# alpha diversity estimated by iNEXT
alpha_div_hill = readRDS(alpha_div_hill_file)
alpha_div_hill %>% names

alpha_div_hill = alpha_div_hill$AsyEst
alpha_div_hill
# Out:
# [1] "DataInfo" "iNextEst" "AsyEst"
#     Site             Diversity         Observed Estimator s.e.  LCL    UCL
# 1   F14_Common_Bream Species richness  36.000   36.000    0.581 36.000 37.535
# 2   F14_Common_Bream Shannon diversity  8.514    8.558    0.232  8.514  9.012
# ⋮   ⋮                ⋮                 ⋮        ⋮         ⋮     ⋮      ⋮
# 554 X67_European_Roe Shannon diversity 3.510    3.525     0.084 3.510  3.690
# 555 X67_European_Roe Simpson diversity 3.201    3.211     0.049 3.201  3.308

# %%
# joining alpha div
overlap(alpha_div$Sample, alpha_div_hill$Site)

alpha_div = alpha_div %>%
    inner_join(alpha_div_hill %>% 
                   filter(Diversity == 'Shannon diversity') %>%
                   dplyr::select(Site, Estimator) %>%
                   rename('shannon_hill' = Estimator),
               c('Sample'='Site')) %>%
    as.data.frame

rownames(alpha_div) = alpha_div$Sample
alpha_div$Sample = NULL
alpha_div
# Out:
# intersect(x,y): 185
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 185
# Warning message:
# “Column `Sample`/`Site` joining character vector and factor, coercing into character vector”
#                  pielou_e   observed_otus shannon    faith_pd shannon_hill
# F14_Common_Bream 0.4255973  7             1.194803   2.629572  8.558
# F35_Red_Deer     0.7088848  5             1.645979   3.286218 12.742
# ⋮                ⋮          ⋮             ⋮          ⋮        ⋮
# X431_Quagga      0.43631269 4             0.87262539 2.754449 8.585
# X67_European_Roe 0.03762236 2             0.03762236 1.109893 3.525

# %%
# host tree
host_tree = read.tree(host_tree_IndD_file)
host_tree
# Out:
# Phylogenetic tree with 185 tips and 184 internal nodes.
#
# Tip labels:
# 	X60_European_Chub, X179_Roach, X330_Ide, X327_Silver_Bream, X326_Silver_Bream, F14_Common_Bream, ...
# Node labels:
# 	, @_20_@, @_17_@, @_14_@, @_9_@, @_15_@, ...
#
# Rooted; includes branch lengths.

# %%
# metadata (IndD)
meta = physeq_arch_IndD %>% sample_data %>% as.matrix %>% as.data.table
meta
# Out:
#     SampleID         host_subject_id host_german_name host_common_name
# 1   F14_Common_Bream F14             Brachse          Common.Bream
# 2   F35_Red_Deer     F35             Rothirsch        Red.Deer
# ⋮   ⋮                ⋮               ⋮                ⋮
# 184 X431_Quagga      431             Steppenzebra     Quagga
# 185 X67_European_Roe 67              Reh              European.Roe
#     scientific_name     scientific_name_subspecies host_taxid class
# 1   Abramis_brama       NA                           38527    Actinopterygii
# 2   Cervus_elaphus      NA                            9860    Mammalia
# ⋮   ⋮                   ⋮                          ⋮          ⋮
# 184 Equus_quagga        NA                           89252    Mammalia
# 185 Capreolus_capreolus NA                            9858    Mammalia
#     order          family     ⋯ CH4_kJ.d_mean CH4_kJ.d_sd i.CH4_L.d_mean
# 1   Cypriniformes  Cyprinidae ⋯ NA            NA          NA
# 2   Artiodactyla   Cervidae   ⋯  2066.94152   1075.50477   52.2413228
# ⋮   ⋮              ⋮          ⋱ ⋮             ⋮           ⋮
# 184 Perissodactyla Equidae    ⋯ NA            NA          NA
# 185 Artiodactyla   Cervidae   ⋯ NA            NA          NA
#     i.CH4_L.d_sd i.CH4_L.kgBM_mean i.CH4_L.kgBM_sd i.CH4_g.d_mean i.CH4_g.d_sd
# 1   NA           NA                NA              NA             NA
# 2   27.1830584   0.4858472         0.16869553       38.6711742    21.3016201
# ⋮   ⋮            ⋮                 ⋮               ⋮              ⋮
# 184 NA           NA                NA              NA             NA
# 185 NA           NA                NA              NA             NA
#     i.CH4_kJ.d_mean i.CH4_kJ.d_sd
# 1   NA              NA
# 2    2066.94152     1075.50477
# ⋮   ⋮               ⋮
# 184 NA              NA
# 185 NA              NA

# %%
# metadata (IndD)
meta = physeq_arch_IndD %>% sample_data %>% as.matrix %>% as.data.table
meta
# Out:
#     SampleID         host_subject_id host_german_name host_common_name
# 1   F14_Common_Bream F14             Brachse          Common.Bream
# 2   F35_Red_Deer     F35             Rothirsch        Red.Deer
# ⋮   ⋮                ⋮               ⋮                ⋮
# 184 X431_Quagga      431             Steppenzebra     Quagga
# 185 X67_European_Roe 67              Reh              European.Roe
#     scientific_name     scientific_name_subspecies host_taxid class
# 1   Abramis_brama       NA                           38527    Actinopterygii
# 2   Cervus_elaphus      NA                            9860    Mammalia
# ⋮   ⋮                   ⋮                          ⋮          ⋮
# 184 Equus_quagga        NA                           89252    Mammalia
# 185 Capreolus_capreolus NA                            9858    Mammalia
#     order          family     ⋯ CH4_kJ.d_mean CH4_kJ.d_sd i.CH4_L.d_mean
# 1   Cypriniformes  Cyprinidae ⋯ NA            NA          NA
# 2   Artiodactyla   Cervidae   ⋯  2066.94152   1075.50477   52.2413228
# ⋮   ⋮              ⋮          ⋱ ⋮             ⋮           ⋮
# 184 Perissodactyla Equidae    ⋯ NA            NA          NA
# 185 Artiodactyla   Cervidae   ⋯ NA            NA          NA
#     i.CH4_L.d_sd i.CH4_L.kgBM_mean i.CH4_L.kgBM_sd i.CH4_g.d_mean i.CH4_g.d_sd
# 1   NA           NA                NA              NA             NA
# 2   27.1830584   0.4858472         0.16869553       38.6711742    21.3016201
# ⋮   ⋮            ⋮                 ⋮               ⋮              ⋮
# 184 NA           NA                NA              NA             NA
# 185 NA           NA                NA              NA             NA
#     i.CH4_kJ.d_mean i.CH4_kJ.d_sd
# 1   NA              NA
# 2    2066.94152     1075.50477
# ⋮   ⋮               ⋮
# 184 NA              NA
# 185 NA              NA

# %% [markdown]
# ## Checks

# %%
# overlap of sampleIDs
overlap(host_tree$tip.label, physeq_arch_IndD %>% sample_names)
# Out:
# intersect(x,y): 185
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 185

# %% [markdown]
# # Dist matrices
#
# * Creating distance matrices

# %% [markdown]
# ## Alpha diversity

# %%
# convert to distance matrices
alpha_div_mtx = list()
n = ncol(alpha_div) -1 
cols = c('observed_otus', 'shannon', 'faith_pd', 'shannon_hill')
for(x in cols){
    y = as.data.frame(alpha_div[,x])
    rownames(y) = rownames(alpha_div)
    alpha_div_mtx[[x]] = cluster::daisy(y, metric='gower')
}
alpha_div = alpha_div_mtx    

# status
lapply(alpha_div, function(x) x %>% as.vector %>% summary)
# Out:
# $observed_otus
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.00000 0.07143 0.14286 0.21032 0.28571 1.00000
#
# $shannon
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.00000 0.09842 0.21084 0.25002 0.36323 1.00000
#
# $faith_pd
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.00000 0.08249 0.21315 0.23926 0.37501 1.00000
#
# $shannon_hill
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# 0.0000254 0.0734516 0.1609631 0.1987984 0.2788633 1.0000000

# %%
# plotting
p.dims(12,5)
for(x in names(alpha_div)){
    y = plot(hclust(alpha_div[[x]]), cex=0.4, main=x)
}
# Out:
# Plot with title “observed_otus”
# Plot with title “shannon”
# Plot with title “faith_pd”
# Plot with title “shannon_hill”

# %% [markdown]
# ## Tree

# %%
host_tree_d = host_tree %>% cophenetic %>% as.dist %>% rescale_dist_mtx 
p.dims(12,5)
plot(hclust(host_tree_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Diet

# %%
dietD = meta %>%
    dt_select(SampleID, diet_vertebrate, diet_invertebrate, diet_fruit,
              diet_flowers_nectar_pollen, diet_leaves_branches_bark_buds, diet_seeds,
             diet_grass_waterplants, diet_roots_tubers) %>%
    dt_mutate(diet_invertebrate = gsub(' .+', '', diet_invertebrate) %>% as.factor) %>%
    as.data.frame

rownames(dietD) = dietD$SampleID
dietD$SampleID = NULL

cn = colnames(dietD)
dietD = dietD %>% 
    apply(1, function(x) ifelse(x=='yes', 1, 0)) %>%
    t %>% as.data.frame
colnames(dietD) = cn

# status
dietD
# Out:
#                  diet_vertebrate diet_invertebrate diet_fruit
# F14_Common_Bream 0               1                 0
# F35_Red_Deer     0               0                 1
# ⋮                ⋮               ⋮                 ⋮
# X431_Quagga      0               0                 0
# X67_European_Roe 0               0                 1
#                  diet_flowers_nectar_pollen diet_leaves_branches_bark_buds
# F14_Common_Bream 0                          0
# F35_Red_Deer     0                          1
# ⋮                ⋮                          ⋮
# X431_Quagga      0                          0
# X67_European_Roe 0                          1
#                  diet_seeds diet_grass_waterplants diet_roots_tubers
# F14_Common_Bream 0          1                      0
# F35_Red_Deer     1          1                      1
# ⋮                ⋮          ⋮                      ⋮
# X431_Quagga      1          1                      0
# X67_European_Roe 1          1                      0

# %%
# distance
dietD_d = vegan::vegdist(dietD, metric='jaccard')

p.dims(12,5)
plot(hclust(dietD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Digestive tract

# %%
dtD = meta %>%
    dt_select(SampleID, 
              digestive_system, digestive_system_detail, 
              ruminant, pseudoruminants) %>%
    dt_mutate(digestive_system = gsub('_', ' ', digestive_system),
              digestive_system = gsub('fermentation activity foregut', 'forgut', digestive_system),
              digestive_system_detail = gsub('^_', '', digestive_system_detail),
              digestive_system_detail = gsub('_', ' ', digestive_system_detail),
              digestive_system_detail = gsub(' +', ' ', digestive_system_detail)) %>%
    dt_mutate(digestive_system = digestive_system %>% as.factor,
              digestive_system_detail = digestive_system_detail %>% as.factor,
              ruminant = ruminant %>% as.factor,
              pseudoruminants = pseudoruminants %>% as.factor) %>%
    as.data.frame

rownames(dtD) = dtD$SampleID
dtD$SampleID = NULL

dtD %>% summary
dtD
# Out:
#        digestive_system                  digestive_system_detail ruminant
#  foregut       :55      caecum                       :35         no :144
#  forgut        : 1      colocecal fermentation       : 2         yes: 41
#  hindgut       :29      colon                        :18
#  simple        :72      fermentation activity foregut: 3
#  simple foregut: 2      foregut                      :55
#  simple hindgut:26      hindgut                      : 6
#                         simple                       :66
#       pseudoruminants
#  no           :170
#  ruminant_like: 10
#  yes          :  5
#                  digestive_system digestive_system_detail ruminant
# F14_Common_Bream simple           simple                  no
# F35_Red_Deer     foregut          foregut                 yes
# ⋮                ⋮                ⋮                       ⋮
# X431_Quagga      hindgut          colon                   no
# X67_European_Roe foregut          foregut                 yes
#                  pseudoruminants
# F14_Common_Bream no
# F35_Red_Deer     no
# ⋮                ⋮
# X431_Quagga      no
# X67_European_Roe no

# %%
dtD_d = cluster::daisy(dtD, metric='gower')

p.dims(12,5)
plot(hclust(dtD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Habitat

# %%
habitatD = meta %>%
    dt_select(SampleID, habitat, habitat_detail, habitat_detail_1, habitat_detail_2) %>%
    dt_mutate_across(everything.(), function(x) as.factor(gsub(' habitat$', '', x))) %>%
    as.data.frame

rownames(habitatD) = habitatD$SampleID
habitatD$SampleID = NULL

habitatD %>% summary
habitatD
# Out:
#           habitat          habitat_detail      habitat_detail_1
#  anthropogenic:  7   anthropogenic: 7     terrestrial  :87
#  aquatic      : 12   cultivated   : 3     forest       :40
#  terrestrial  :166   freshwater   : 8     meadow       :14
#                      grassland    :36     steppe       :14
#                      saline water : 4     freshwater   : 8
#                      terrestrial  :87     anthropogenic: 7
#                      woodland     :40     (Other)      :15
#       habitat_detail_2
#  terrestrial  :87
#  forest       :40
#  flood meadow :14
#  steppe       :14
#  freshwater   : 8
#  anthropogenic: 7
#  (Other)      :15
#                  habitat     habitat_detail habitat_detail_1 habitat_detail_2
# F14_Common_Bream aquatic     freshwater     freshwater       freshwater
# F35_Red_Deer     terrestrial grassland      meadow           flood meadow
# ⋮                ⋮           ⋮              ⋮                ⋮
# X431_Quagga      terrestrial terrestrial    terrestrial      terrestrial
# X67_European_Roe terrestrial woodland       forest           forest

# %%
habitatD_d = cluster::daisy(habitatD, metric='gower') 

p.dims(12,5)
plot(hclust(habitatD_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Geographic distance

# %%
geo = meta %>% 
    dt_select(SampleID, latitude, longitude) %>%
    dt_mutate(latitude = latitude %>% as.Num,
           longitude = longitude %>% as.Num) %>%
    as.data.frame

rownames(geo) = geo$SampleID

geo$latitude %>% summary %>% print
geo$longitude %>% summary %>% print
geo
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -35.83   20.32   47.50   32.81   48.21   55.29
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -84.10   15.75   16.37   28.69   30.49  138.68
#                  SampleID         latitude longitude
# F14_Common_Bream F14_Common_Bream 48.20833 16.37306
# F35_Red_Deer     F35_Red_Deer     48.20833 16.37306
# ⋮                ⋮                ⋮        ⋮
# X431_Quagga      X431_Quagga      47.22400 15.81200
# X67_European_Roe X67_European_Roe 48.20833 16.37306

# %%
.pairwise_distGeo = function(x, y){
    d = geosphere::distGeo(x[c('longitude', 'latitude')],
                           y[,c('longitude', 'latitude')])
    return(d)
}

pairwise_distGeo = function(df){
    x = df[,c('longitude', 'latitude')]
    geo_d = apply(x, 1, .pairwise_distGeo, y=x)
    rescale_dist_mtx(as.dist(geo_d))
}

geo_d = pairwise_distGeo(geo)

p.dims(12,5)
plot(hclust(geo_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Sampling details

# %%
samp = meta %>% 
    dt_select(SampleID, sampling_method, captive_wild, wild_domesticated) %>%
    dt_mutate_across(everything.(), as.factor) %>%
    as.data.frame

rownames(samp) = samp$SampleID
samp$SampleID = NULL

samp %>% summary
samp
# Out:
#              sampling_method  captive_wild    wild_domesticated
#  dried feces sampling:  8    captive: 44   domesticated: 13
#  feces sampling      :154    wild   :141   wild        :172
#  gut section         : 14
#  swab                :  9
#                  sampling_method captive_wild wild_domesticated
# F14_Common_Bream feces sampling  wild         wild
# F35_Red_Deer     feces sampling  wild         wild
# ⋮                ⋮               ⋮            ⋮
# X431_Quagga      feces sampling  captive      wild
# X67_European_Roe feces sampling  wild         wild

# %%
# distance matrix
samp_d = cluster::daisy(samp, metric='gower') 

p.dims(12, 5)
plot(hclust(samp_d), cex=0.4)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# # Ordering matrices

# %%
# checking overlap 
X = labels(alpha_div$faith_pd)
overlap(X, labels(host_tree_d))
# Out:
# intersect(x,y): 185
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 185

# %%
# ordering by host tree labels
X = labels(host_tree_d)

alpha_div = lapply(alpha_div, dist_mtx_order, x=X)

host_tree_d_o = dist_mtx_order(host_tree_d, X)
dietD_d_o = dist_mtx_order(dietD_d, X)
habitatD_d_o = dist_mtx_order(habitatD_d, X)
geo_d_o = dist_mtx_order(geo_d, X)
samp_d_o = dist_mtx_order(samp_d, X)
dtD_d_o = dist_mtx_order(dtD_d, X)

# %%
# checking sizes of beta-div matrices
alpha_div %>% lapply(function(x) x %>% as.matrix %>% dim)
# Out:
# $observed_otus
# [1] 185 185
#
# $shannon
# [1] 185 185
#
# $faith_pd
# [1] 185 185
#
# $shannon_hill
# [1] 185 185

# %% [markdown]
# # MRM

# %%
# number of permutated SpecD datasetst
nperm_datasets = 100
# number of permutations per MRM analysis
nperm = 1000

# %% [markdown]
# ## Functions

# %%
#' randomly selecting one per group
#' L : list of distance matrixes used for MRM
#' df_grps : data.frame (sample, group)
one_per_group = function(L, df_grps, ...){
    # get subsample
    colnames(df_grps) = c('Sample', 'Group')
    df_grps = df_grps %>%
        group_by(Group) %>%
        sample_n(1)
    # subsetting all matrices
    lapply(L, function(x) dist_mtx_order(x, df_grps$Sample))
}

# %%
#' MRM on one subsample rep
#' i : rep number
#' L : list of list of distance matrices generated by `one_per_group()`
# nperm : nperm function for MRM
# f : MRM fomulat
mrm_each = function(i, L, f, nperm=99){
    m = L[[i]]
    f = as.formula(f)
    x = ecodist::MRM(f, nperm=nperm, mrank=TRUE)
    # coefficients
    df = x$coef %>% as.data.frame
    colnames(df) = c('coef', 'coef_pval')
    df$variable = rownames(df)
    df$R2 = x$r.squared[1]
    df$pval = x$r.squared[2]
    df$F = x$F.test[1]
    df$rep = i
    return(df)
}

# %%
# renaming output
rename_df = data.frame(old_name = c('m$diet', 'm$digest', 'm$geo', 'm$habitat', 'm$host_phy', 'm$samp'),
                       new_name = c('Diet', 'Digestive\nsystem', 'Geography', 'Habitat', 'Phylogeny', 'Technical'))
rename_df
# Out:
#   old_name   new_name
# 1 m$diet     Diet
# 2 m$digest   Digestive\nsystem
# ⋮ ⋮          ⋮
# 5 m$host_phy Phylogeny
# 6 m$samp     Technical

# %% [markdown]
# ## One per species

# %%
# grouping samples by species
df_grps = meta %>% 
    dt_filter(SampleID %in% labels(dietD_d_o)) %>%
    dt_select(SampleID, scientific_name)
df_grps
# Out:
#     SampleID         scientific_name
# 1   F14_Common_Bream Abramis_brama
# 2   F35_Red_Deer     Cervus_elaphus
# ⋮   ⋮                ⋮
# 184 X431_Quagga      Equus_quagga
# 185 X67_European_Roe Capreolus_capreolus

# %% [markdown]
# ### faiths PD

# %%
# creating subsample permutations of the distance matrices
L = list(alpha = alpha_div$faith_pd,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2          pval  F        rep
# Int        2.855535e+03 0.752     Int        0.008369497 0.321 8.423257 1
# m$host_phy 5.784273e-02 0.128     m$host_phy 0.008369497 0.321 8.423257 1
# ⋮          ⋮            ⋮         ⋮          ⋮           ⋮     ⋮        ⋮
# m$geo99    -0.00538783  0.901     m$geo      0.00732265  0.41  7.361913 100
# m$samp99   -0.07180658  0.099     m$samp     0.00732265  0.41  7.361913 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2                pval
#  Min.   :-0.082632   Min.   :0.0380   Min.   :0.004725   Min.   :0.0770
#  1st Qu.:-0.029485   1st Qu.:0.1867   1st Qu.:0.007511   1st Qu.:0.2005
#  Median : 0.013715   Median :0.3200   Median :0.008844   Median :0.2700
#  Mean   : 0.004683   Mean   :0.3827   Mean   :0.009180   Mean   :0.2923
#  3rd Qu.: 0.039419   3rd Qu.:0.5292   3rd Qu.:0.010614   3rd Qu.:0.3715
#  Max.   : 0.080353   Max.   :0.9960   Max.   :0.016166   Max.   :0.6350
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.98
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  0.99
# 5 m$host_phy 0.99
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2          pval  F       rep
# Int        2.779613e+03 0.832     Int        0.007236597 0.349 8.73118 1
# m$host_phy 6.124701e-02 0.136     m$host_phy 0.007236597 0.349 8.73118 1
# ⋮          ⋮            ⋮         ⋮          ⋮           ⋮     ⋮       ⋮
# m$geo99    -0.00686881  0.866     m$geo      0.007113397 0.346 8.58147 100
# m$samp99   -0.07229596  0.092     m$samp     0.007113397 0.346 8.58147 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2                pval
#  Min.   :-0.082832   Min.   :0.0390   Min.   :0.004171   Min.   :0.0720
#  1st Qu.:-0.022761   1st Qu.:0.1817   1st Qu.:0.006962   1st Qu.:0.1690
#  Median : 0.018946   Median :0.3030   Median :0.008425   Median :0.2525
#  Mean   : 0.009205   Mean   :0.3754   Mean   :0.008440   Mean   :0.2593
#  3rd Qu.: 0.042083   3rd Qu.:0.5290   3rd Qu.:0.009598   3rd Qu.:0.3305
#  Max.   : 0.082803   Max.   :0.9980   Max.   :0.014700   Max.   :0.6120
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.99
# 2 m$geo      1.00
# 3 m$habitat  0.98
# 4 m$host_phy 0.98
# 5 m$samp     0.99

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.2) %>%
    .[1:2,]
df_c[2,'value'] = -0.1
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### shannon

# %%
# creating multiple distance matrices
m = list(alpha = alpha_div$shannon,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)

m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(m, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2666.4186884 0.884     Int        0.01287308 0.262 13.01487 1
# m$host_phy    0.1071238 0.019     m$host_phy 0.01287308 0.262 13.01487 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99     0.013721515 0.774     m$geo      0.01275764 0.264 12.89666 100
# m$samp99   -0.003177303 0.952     m$samp     0.01275764 0.264 12.89666 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2                pval
#  Min.   :-0.052326   Min.   :0.0010   Min.   :0.007236   Min.   :0.0290
#  1st Qu.:-0.012631   1st Qu.:0.4422   1st Qu.:0.012122   1st Qu.:0.0990
#  Median : 0.006825   Median :0.6505   Median :0.014728   Median :0.1910
#  Mean   : 0.018310   Mean   :0.5857   Mean   :0.015705   Mean   :0.2084
#  3rd Qu.: 0.026907   3rd Qu.:0.8220   3rd Qu.:0.018859   3rd Qu.:0.3040
#  Max.   : 0.151322   Max.   :1.0000   Max.   :0.026435   Max.   :0.5310
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.05
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2604.086721  0.939     Int        0.01211608 0.213 14.69064 1
# m$host_phy    0.109977  0.015     m$host_phy 0.01211608 0.213 14.69064 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99     0.011190841 0.830     m$geo      0.01225885 0.208 14.86589 100
# m$samp99   -0.003673329 0.935     m$samp     0.01225885 0.208 14.86589 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2                pval
#  Min.   :-0.047132   Min.   :0.0010   Min.   :0.007036   Min.   :0.0260
#  1st Qu.:-0.006357   1st Qu.:0.4035   1st Qu.:0.011744   1st Qu.:0.0760
#  Median : 0.006682   Median :0.6875   Median :0.014269   Median :0.1515
#  Mean   : 0.024489   Mean   :0.5897   Mean   :0.015286   Mean   :0.1680
#  3rd Qu.: 0.035390   3rd Qu.:0.8555   3rd Qu.:0.018480   3rd Qu.:0.2495
#  Max.   : 0.153694   Max.   :0.9990   Max.   :0.025599   Max.   :0.4850
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.08
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# changing coef scale
df_c = mrm_res_s %>%
    filter(category == 'Coef.') %>%
    mutate(value = 0.2) %>%
    .[1:2,]
df_c[2,'value'] = -0.1
# changing p-value scale
df_p = mrm_res_s %>%
    filter(category == 'Adj. P-value') %>%
    mutate(value = 1) %>%
    .[1:2,]
df_c[2,'value'] = 0

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_point(data=df_c, alpha=0) +
    geom_point(data=df_p, alpha=0) +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### observed OTUs

# %%
# creating multiple distance matrices
L = list(alpha = alpha_div$observed_otus,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2559.9314102 0.892     Int        0.06179177 0.002 65.72975 1
# m$host_phy    0.2120545 0.001     m$host_phy 0.06179177 0.002 65.72975 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.01871495  0.742     m$geo      0.0569629  0.001 60.28286 100
# m$samp99   -0.03846274  0.462     m$samp     0.0569629  0.001 60.28286 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.10703   Min.   :0.0010   Min.   :0.05442   Min.   :0.00100
#  1st Qu.:-0.04913   1st Qu.:0.1485   1st Qu.:0.06632   1st Qu.:0.00100
#  Median : 0.02211   Median :0.2610   Median :0.07873   Median :0.00100
#  Mean   : 0.03335   Mean   :0.3071   Mean   :0.07712   Mean   :0.00121
#  3rd Qu.: 0.05937   3rd Qu.:0.4205   3rd Qu.:0.08514   3rd Qu.:0.00100
#  Max.   : 0.27233   Max.   :0.9950   Max.   :0.10413   Max.   :0.00300
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$digest   1.00
# 3 m$geo      1.00
# 4 m$habitat  1.00
# 5 m$host_phy 0.00
# 6 m$samp     0.99

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2475.5924817 0.934     Int        0.06045824 0.001 77.07681 1
# m$host_phy    0.2158394 0.001     m$host_phy 0.06045824 0.001 77.07681 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    -0.02251997  0.657     m$geo      0.05536318 0.001 70.20055 100
# m$samp99   -0.03927729  0.454     m$samp     0.05536318 0.001 70.20055 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.10752   Min.   :0.0010   Min.   :0.05270   Min.   :0.00100
#  1st Qu.:-0.03258   1st Qu.:0.1497   1st Qu.:0.06443   1st Qu.:0.00100
#  Median : 0.01408   Median :0.3465   Median :0.07582   Median :0.00100
#  Mean   : 0.04755   Mean   :0.3678   Mean   :0.07439   Mean   :0.00114
#  3rd Qu.: 0.07243   3rd Qu.:0.5805   3rd Qu.:0.08230   3rd Qu.:0.00100
#  Max.   : 0.27975   Max.   :1.0000   Max.   :0.09920   Max.   :0.00300
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     1.00
# 2 m$geo      1.00
# 3 m$habitat  1.00
# 4 m$host_phy 0.00
# 5 m$samp     0.99

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)           

# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# ### shannon (iNEXT: hill)

# %%
# creating multiple distance matrices
L = list(alpha = alpha_div$shannon_hill,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# #### Model1

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$digest + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2.628752e+03 0.906     Int        0.02781338 0.051 28.55187 1
# m$host_phy 3.298293e-02 0.515     m$host_phy 0.02781338 0.051 28.55187 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    0.072596157  0.187     m$geo      0.01545231 0.294 15.66344 100
# m$samp99   0.007083084  0.902     m$samp     0.01545231 0.294 15.66344 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef            coef_pval            R2               pval
#  Min.   :-0.10001   Min.   :0.0010   Min.   :0.01440   Min.   :0.00100
#  1st Qu.:-0.01589   1st Qu.:0.0610   1st Qu.:0.02323   1st Qu.:0.01600
#  Median : 0.01981   Median :0.3790   Median :0.02853   Median :0.03850
#  Mean   : 0.03333   Mean   :0.4006   Mean   :0.02896   Mean   :0.05586
#  3rd Qu.: 0.09140   3rd Qu.:0.6950   3rd Qu.:0.03470   3rd Qu.:0.06850
#  Max.   : 0.19973   Max.   :1.0000   Max.   :0.05278   Max.   :0.29400
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.99
# 2 m$digest   0.18
# 3 m$geo      0.48
# 4 m$habitat  1.00
# 5 m$host_phy 1.00
# 6 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

# %%
mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”

# %%
# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# #### Model2

# %%
# MRM on each permutation (in parallel)
doParallel::registerDoParallel(threads)
x = as.list(1:length(m_perm))
f = 'm$alpha ~ m$host_phy + m$diet + m$habitat + m$geo + m$samp'
mrm_res = plyr::llply(x, mrm_each, L=m_perm, f=f, nperm=nperm, .parallel=TRUE)
mrm_res = do.call(rbind, mrm_res)
mrm_res
# Out:
#            coef         coef_pval variable   R2         pval  F        rep
# Int        2.834153e+03 0.719     Int        0.01930881 0.115 23.58346 1
# m$host_phy 2.304258e-02 0.670     m$host_phy 0.01930881 0.115 23.58346 1
# ⋮          ⋮            ⋮         ⋮          ⋮          ⋮     ⋮        ⋮
# m$geo99    0.08310595   0.124     m$geo      0.00826819 0.55  9.986206 100
# m$samp99   0.01288854   0.809     m$samp     0.00826819 0.55  9.986206 100

# %%
# summary of overall model
mrm_res %>%
    filter(variable != 'Int') %>% 
    distinct(coef, coef_pval, R2, pval, rep) %>%
    summary
# Out:
#       coef             coef_pval            R2               pval
#  Min.   :-0.093553   Min.   :0.0020   Min.   :0.00766   Min.   :0.01400
#  1st Qu.:-0.007324   1st Qu.:0.1900   1st Qu.:0.01318   1st Qu.:0.09325
#  Median : 0.014767   Median :0.5530   Median :0.01712   Median :0.14450
#  Mean   : 0.024146   Mean   :0.5063   Mean   :0.01704   Mean   :0.19262
#  3rd Qu.: 0.038132   3rd Qu.:0.7970   3rd Qu.:0.02047   3rd Qu.:0.24950
#  Max.   : 0.165784   Max.   :0.9980   Max.   :0.03152   Max.   :0.63500
#       rep
#  Min.   :  1.00
#  1st Qu.: 25.75
#  Median : 50.50
#  Mean   : 50.50
#  3rd Qu.: 75.25
#  Max.   :100.00

# %%
# significant?
df.dims(10)
mrm_res %>%
    filter(variable != 'Int') %>%
    mutate(pval = pval %>% as.Num) %>%
    group_by(variable) %>%
    summarize(overall_pval = 1 - (sum(coef_pval < 0.05) / length(coef_pval))) %>%
    ungroup()
df.dims()
# Out:
#   variable   overall_pval
# 1 m$diet     0.96
# 2 m$geo      0.30
# 3 m$habitat  1.00
# 4 m$host_phy 1.00
# 5 m$samp     1.00

# %%
# formatting results
mrm_res_s = mrm_res %>% 
    filter(variable != 'Int') %>%
    gather(category, value, -variable, -R2, -pval, -F, -rep) %>%
    mutate(category = ifelse(category == 'coef', 'Coef.', 'Adj. P-value'))

mrm_res_s = mrm_res_s %>%
    inner_join(rename_df, c('variable'='old_name')) %>%
    dplyr::select(-variable) %>%
    rename('variable' = new_name)
# Out:
# Warning message:
# “Column `variable`/`old_name` joining character vector and factor, coercing into character vector”

# %%
# plotting
X = data.frame(yint=c(0.05, NA), category=c('Adj. P-value', 'Coef.'))
p = ggplot(mrm_res_s, aes(variable, value)) +
    geom_boxplot() +
    geom_hline(aes(yintercept=yint), linetype='dashed', alpha=0.3, data=X) +
    labs(x='Variable', y='Intra-species variance') +
    facet_grid(category ~ ., scales='free_y') +
    theme_bw()

p.dims(5,3)
plot(p)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_hline).”
# plot without title

# %% [markdown]
# # Plotting associations

# %%
# converting distance matrix
x_y_df = function(rep, L, x_var){
    x = L[[rep]][[x_var]] %>% as.vector
    y = L[[rep]]$alpha %>% as.vector
    df = data.frame(x=x,y=y)
    df$rep=rep
    df$point = 1:nrow(df)
    return(df)
}

# %% [markdown]
# ## faiths PD

# %%
# creating multiple distance matrices
L = list(alpha = alpha_div$faith_pd,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x_sd x         y_sd      y
# 1    1     0    1         0.1561892 0.2119878
# 2    2     0    1         0.0000000 0.3641973
# ⋮    ⋮     ⋮    ⋮         ⋮         ⋮
# 5994 5994  0    0.1418210 0         0.1025403
# 5995 5995  0    0.7164867 0         0.1197550

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    geom_smooth(method='lm') +
    labs(x='host patristic distance', y='Faith\'s PD dist') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Bray

# %%
# creating multiple distance matrices
L = list(alpha = alpha_div$shannon,
         host_phy = host_tree_d_o,
         diet = dietD_d_o,
         digest = dtD_d_o, 
         habitat = habitatD_d_o,
         geo = geo_d_o,
         samp = samp_d_o)
m_perm = lapply(as.list(1:nperm_datasets), function(x) one_per_group(L, df_grps, x))
m_perm %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Host phylogeny

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='host_phy')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x_sd = sd(x),
              x = mean(x),
              y_sd = sd(y),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x_sd x         y_sd       y
# 1    1     0    1         0.03353201 0.2184882
# 2    2     0    1         0.00000000 0.2386600
# ⋮    ⋮     ⋮    ⋮         ⋮          ⋮
# 5994 5994  0    0.1418210 0          0.3303910
# 5995 5995  0    0.7164867 0          0.3202461

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    geom_smooth(method='lm') +
    labs(x='host patristic distance', y='Shannon index dist') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### Diet

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='diet')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x         y
# 1    1     0.6666667 0.2184882
# 2    2     0.3333333 0.2386600
# ⋮    ⋮     ⋮         ⋮
# 5994 5994  0.3333333 0.3303910
# 5995 5995  0.5000000 0.3202461

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    geom_smooth(method='lm') +
    labs(x='diet', y='shannon index dist') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### digestive system

# %%
m_perm_df = lapply(as.list(1:length(m_perm)), x_y_df, L=m_perm, x_var='digest')
m_perm_df = do.call(rbind, m_perm_df) %>%
    group_by(point) %>%
    summarize(x = mean(x),
              y = mean(y)) %>%
    ungroup()
m_perm_df
# Out:
#      point x    y
# 1    1     0.75 0.2184882
# 2    2     0.50 0.2386600
# ⋮    ⋮     ⋮    ⋮
# 5994 5994  0    0.3303910
# 5995 5995  0    0.3202461

# %%
p = ggplot(m_perm_df, aes(x, y)) +
    geom_point(alpha=0.3, shape='O') +
    geom_smooth(method='lm') +
    labs(x='digestive system', y='shannon index dist') +
    theme_bw()

p.dims(4,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.6 ape_5.3           tidytable_0.4.1   data.table_1.12.8
# [5] phyloseq_1.30.0   ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Biobase_2.46.0      jsonlite_1.6        splines_3.6.2
#  [4] foreach_1.4.7       assertthat_0.2.1    sp_1.4-2
#  [7] stats4_3.6.2        pillar_1.4.3        lattice_0.20-38
# [10] glue_1.3.1          uuid_0.1-2          digest_0.6.23
# [13] XVector_0.26.0      colorspace_1.4-1    htmltools_0.4.0
# [16] Matrix_1.2-18       plyr_1.8.5          pkgconfig_2.0.3
# [19] zlibbioc_1.32.0     purrr_0.3.3         scales_1.1.1
# [22] tibble_2.1.3        mgcv_1.8-31         farver_2.0.3
# [25] IRanges_2.20.0      ellipsis_0.3.0      withr_2.1.2
# [28] repr_1.0.2          BiocGenerics_0.32.0 lazyeval_0.2.2
# [31] survival_3.1-8      magrittr_1.5        crayon_1.3.4
# [34] evaluate_0.14       doParallel_1.0.15   nlme_3.1-143
# [37] MASS_7.3-51.5       vegan_2.5-6         tools_3.6.2
# [40] geosphere_1.5-10    lifecycle_0.1.0     stringr_1.4.0
# [43] Rhdf5lib_1.8.0      S4Vectors_0.24.0    munsell_0.5.0
# [46] cluster_2.1.0       Biostrings_2.54.0   ade4_1.7-13
# [49] compiler_3.6.2      rlang_0.4.6         rhdf5_2.30.0
# [52] grid_3.6.2          pbdZMQ_0.3-3        iterators_1.0.12
# [55] IRkernel_1.1        biomformat_1.14.0   igraph_1.2.4.2
# [58] base64enc_0.1-3     labeling_0.3        gtable_0.3.0
# [61] codetools_0.2-16    multtest_2.42.0     reshape2_1.4.3
# [64] R6_2.4.1            knitr_1.26          permute_0.9-5
# [67] stringi_1.4.5       parallel_3.6.2      IRdisplay_0.7.0
# [70] Rcpp_1.0.3          vctrs_0.3.1         tidyselect_1.1.0
# [73] xfun_0.12
