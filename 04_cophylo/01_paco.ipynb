# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Functions</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Rarefy" data-toc-modified-id="Rarefy-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Rarefy</a></span></li><li><span><a href="#Filtering-dataset" data-toc-modified-id="Filtering-dataset-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Filtering dataset</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Checks</a></span></li></ul></li><li><span><a href="#Subsampling-tree" data-toc-modified-id="Subsampling-tree-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Subsampling tree</a></span></li><li><span><a href="#paco:-diffused-model" data-toc-modified-id="paco:-diffused-model-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>paco: diffused model</a></span><ul class="toc-item"><li><span><a href="#Running-paco" data-toc-modified-id="Running-paco-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Running paco</a></span><ul class="toc-item"><li><span><a href="#Saving-results" data-toc-modified-id="Saving-results-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Saving results</a></span></li><li><span><a href="#Formatting-output" data-toc-modified-id="Formatting-output-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Formatting output</a></span></li></ul></li><li><span><a href="#Individual-contributions" data-toc-modified-id="Individual-contributions-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Individual contributions</a></span><ul class="toc-item"><li><span><a href="#Saving-results" data-toc-modified-id="Saving-results-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Saving results</a></span></li><li><span><a href="#Formatting-output" data-toc-modified-id="Formatting-output-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Formatting output</a></span></li><li><span><a href="#Summarizing-residuals" data-toc-modified-id="Summarizing-residuals-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>Summarizing residuals</a></span></li><li><span><a href="#Adding-taxonomy" data-toc-modified-id="Adding-taxonomy-8.2.4"><span class="toc-item-num">8.2.4&nbsp;&nbsp;</span>Adding taxonomy</a></span></li><li><span><a href="#Summarizing-results" data-toc-modified-id="Summarizing-results-8.2.5"><span class="toc-item-num">8.2.5&nbsp;&nbsp;</span>Summarizing results</a></span><ul class="toc-item"><li><span><a href="#Intra-species-variance" data-toc-modified-id="Intra-species-variance-8.2.5.1"><span class="toc-item-num">8.2.5.1&nbsp;&nbsp;</span>Intra-species variance</a></span></li></ul></li><li><span><a href="#Summarizing-residuals" data-toc-modified-id="Summarizing-residuals-8.2.6"><span class="toc-item-num">8.2.6&nbsp;&nbsp;</span>Summarizing residuals</a></span><ul class="toc-item"><li><span><a href="#Just-mammalia" data-toc-modified-id="Just-mammalia-8.2.6.1"><span class="toc-item-num">8.2.6.1&nbsp;&nbsp;</span>Just mammalia</a></span></li><li><span><a href="#stats" data-toc-modified-id="stats-8.2.6.2"><span class="toc-item-num">8.2.6.2&nbsp;&nbsp;</span>stats</a></span></li></ul></li><li><span><a href="#Adjusting-for-digestive-system" data-toc-modified-id="Adjusting-for-digestive-system-8.2.7"><span class="toc-item-num">8.2.7&nbsp;&nbsp;</span>Adjusting for digestive system</a></span><ul class="toc-item"><li><span><a href="#Formatting-for-iTOL" data-toc-modified-id="Formatting-for-iTOL-8.2.7.1"><span class="toc-item-num">8.2.7.1&nbsp;&nbsp;</span>Formatting for iTOL</a></span></li><li><span><a href="#iTOL:-distribution-of-residuals-per-host-species" data-toc-modified-id="iTOL:-distribution-of-residuals-per-host-species-8.2.7.2"><span class="toc-item-num">8.2.7.2&nbsp;&nbsp;</span>iTOL: distribution of residuals per host species</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * cophylogeny analysis of archaea + host via `paco`

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo/'

# microbiome
## 16S-arch phyloseq object (one sample per individual)
physeq_arch_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/merged/phyloseq/physeq_arch_IndD_rare250.RDS'

# host tree
host_tree_IndD_file = '/ebio/abt3_projects/Georg_animal_feces/data/animal/phylogeny/TT/unified_metadata_complete_200429_16S-arch_IndD.nwk'

# misc
threads = 12
my_seed = 8394

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(tidytable)
library(ggpubr)

library(phyloseq)
library(ape)
library(paco)

library(future)
library(future.batchtools)
library(future.apply)

library(LeyLabRMisc)

# %%
df.dims()
make_dir(work_dir)
set.seed(my_seed)
RhpcBLASctl::blas_set_num_threads(1)
# Out:
# Directory already exists: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo/

# %% [markdown]
# ## Functions

# %%
rescale_dist_mtx = function(m){
    m = m %>% as.matrix
    labs = m %>% colnames
    n_row = m %>% nrow
    n_col = m %>% ncol
    x = m %>% as.vector 
    x = scales::rescale(x) 
    m = matrix(x, nrow=n_row, ncol=n_col)
    colnames(m) = labs
    rownames(m) = labs
    m = m %>% as.dist
    return(m)
}

# %% [markdown]
# # Load

# %%
# phyloseq
physeq_arch_IndD = readRDS(physeq_arch_IndD_file)
physeq_arch_IndD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1345 taxa and 185 samples ]
# sample_data() Sample Data:       [ 185 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 1345 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1345 tips and 1342 internal nodes ]

# %%
# host tree
host_tree_IndD = read.tree(host_tree_IndD_file)
host_tree_IndD
# Out:
# Phylogenetic tree with 185 tips and 184 internal nodes.
#
# Tip labels:
# 	X60_European_Chub, X179_Roach, X330_Ide, X327_Silver_Bream, X326_Silver_Bream, F14_Common_Bream, ...
# Node labels:
# 	, @_20_@, @_17_@, @_14_@, @_9_@, @_15_@, ...
#
# Rooted; includes branch lengths.

# %% [markdown]
# # Rarefy

# %%
# physeq_arch_IndD = rarefy_even_depth(physeq_arch_IndD, sample.size=250, replace=FALSE, rngseed=my_seed)
# physeq_arch_IndD

# %% [markdown]
# # Filtering dataset

# %%
# filtering
physeq_arch_IndD = physeq_arch_IndD %>%
    filter_taxa(function(x) sum(x > 0) >= 2, TRUE) %>%
    prune_samples(sample_sums(.)>0, .)
physeq_arch_IndD
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 355 taxa and 185 samples ]
# sample_data() Sample Data:       [ 185 samples by 88 sample variables ]
# tax_table()   Taxonomy Table:    [ 355 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 355 tips and 354 internal nodes ]

# %%
# metadata
metadata = physeq_arch_IndD %>%
    sample_data %>%
    dplyr::select(scientific_name) %>%
    mutate(SampleID = rownames(.)) %>%
    as.data.frame

rownames(metadata) = metadata$SampleID
metadata[sample_names(physeq_arch_IndD),]
metadata
# Out:
# Warning message in class(x) <- c(subclass, tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”
#                  scientific_name     SampleID
# F14_Common_Bream Abramis_brama       F14_Common_Bream
# F35_Red_Deer     Cervus_elaphus      F35_Red_Deer
# ⋮                ⋮                   ⋮
# X431_Quagga      Equus_quagga        X431_Quagga
# X67_European_Roe Capreolus_capreolus X67_European_Roe
#                  scientific_name     SampleID
# F14_Common_Bream Abramis_brama       F14_Common_Bream
# F35_Red_Deer     Cervus_elaphus      F35_Red_Deer
# ⋮                ⋮                   ⋮
# X431_Quagga      Equus_quagga        X431_Quagga
# X67_European_Roe Capreolus_capreolus X67_European_Roe

# %% [markdown]
# ## Checks

# %%
overlap(sample_names(physeq_arch_IndD), host_tree_IndD$tip.label)
# Out:
# intersect(x,y): 185
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 185

# %% [markdown]
# # Subsampling tree
#
# * multiple subsamples: one sample per species

# %%
# number of subsampled trees
ntrees = 100

# %%
#' randomly selecting one per group
tree_subsample = function(L, df, tree){
    # get subsample (note: subsampling within each species)
    to_keep = df %>% 
        group_by(scientific_name) %>% 
        sample_n(1) %>%
        .$sample
    # subsampling tree
    to_rm = setdiff(tree$tip.label, to_keep)
    tree = drop.tip(tree, to_rm)
    return(tree)
}

# %%
# subsampling trees
df = metadata %>%
    mutate(sample = rownames(.)) %>%
    dplyr::select(sample, scientific_name) 

doParallel::registerDoParallel(threads)
host_tree_l = plyr::llply(as.list(1:ntrees), 
                          function(x) tree_subsample(x, df, host_tree_IndD),
                          .parallel=TRUE)

# tree lengths
host_tree_l %>% length %>% print
lapply(host_tree_l, function(x) x$tip.label %>% length) %>% unlist %>% summary
# Out:
# [1] 100
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     110     110     110     110     110     110

# %%
# checking overlap of labels
setdiff(host_tree_l[[1]]$tip.label, rownames(metadata)) %>% length %>% print
# Out:
# [1] 0

# %% [markdown]
# # paco: diffused model
#
# * on each subsample

# %%
make_paco_input = function(host_tree, physeq){
    # subsampled phyloseq object
    physeq_f = prune_samples(sample_names(physeq) %in% host_tree$tip.label, 
                             physeq) 

    # microbial distance matrix
    micro_D = physeq_f %>%
        phy_tree %>% cophenetic %>% 
        rescale_dist_mtx %>% as.matrix
    # host distance matrix
    host_D = host_tree %>% cophenetic %>% 
             rescale_dist_mtx %>% as.matrix
    
    # otu pres/abs matrix
    otu = physeq_f %>% 
        otu_table %>%
        as.data.frame %>%
        as.matrix %>%
        t %>%
        apply(2, function(x) ifelse(x > 0, 1, 0)) %>% as.matrix                       
              
    # checking overlap
    x = length(intersect(rownames(otu), rownames(host_D)))
    y = length(union(rownames(otu), rownames(host_D)))
    stopifnot(x == y)
              
    # preparing paco data
    D = prepare_paco_data(H=host_D, P=micro_D, HP=otu)
    D = add_pcoord(D, correction='cailliez')
    return(D)
}

# %%
# creating list of paco objects
doParallel::registerDoParallel(threads)
paco_l = plyr::llply(host_tree_l, make_paco_input, physeq=physeq_arch_IndD, .parallel=TRUE)
paco_l %>% length
# Out:
# [1] 100

# %%
# dimensions of final object
paco_l[[1]] %>% .$H %>% dim
paco_l[[1]] %>% .$P %>% dim
paco_l[[1]] %>% .$HP %>% dim
# Out:
# [1] 110 110
# [1] 354 354
# [1] 110 354

# %% [markdown]
# ## Running paco

# %%
# cluster resources
resources = list(h_rt = '24:00:00',
                 h_vmem = '20G',
                 threads = '1',
                 conda.env = '/ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy', 
                 conda.path = '/ebio/abt3_projects/software/miniconda3_gt4.4/bin')
plan(batchtools_sge, resources=resources)

# %%
# Running paco on each subsample
## WARNING: SLOW!
paco_each = function(D, nperm=999, paco_seed=3843){
    PACo(D, nperm=nperm, seed=paco_seed, method='quasiswap', symmetric=TRUE)
}

paco_res_l = paco_l %>%
    future_lapply(paco_each, nperm=9, 
                  future.packages=c('paco'), 
                  future.seed=my_seed)
paco_res_l %>% length

# %%
paco_res_l %>% length

# %%
send_email('http://127.0.0.1:9705/notebooks/notebooks/16S_arch/MiSeq-Runs116-122-126-189-190/04_cophylo/01a_paco_rarefy.ipynb')

# %%
#getStatus()
#findErrors()

# %% [markdown]
# ### Saving results

# %%
# for loading results instead of re-running
PACo_file = file.path(work_dir, 'physeq_IndD-sens_rarefy_PACo.RDS')
PACo_file
# Out:
# [1] "/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo//physeq_IndD-sens_rarefy_PACo.RDS"

# %%
# save results (WARNING!)
saveRDS(paco_res_l, PACo_file)
cat('File written:', PACo_file, '\n')

# %%
# load results
paco_res_l = readRDS(PACo_file)
paco_res_l %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Formatting output

# %%
# goodness of fit
gof = lapply(paco_res_l, function(x) as.vector(x$gof)) %>% 
        do.call(rbind, .) %>%
        as.data.frame
             
gof$p %>% as.Num %>% summary %>% print
gof$ss %>% as.Num %>% summary %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.9666  0.9710  0.9732  0.9731  0.9758  0.9781

# %% [markdown]
# ## Individual contributions

# %%
# cluster resources
resources = list(h_rt = '36:00:00',
                 h_vmem = '18G',
                 threads = '1',
                 conda.env = '/ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy', 
                 conda.path = '/ebio/abt3_projects/software/miniconda3_gt4.4/bin')
#plan(batchtools_sge, resources=resources)
plan(batchtools_multicore, workers=6)

# %%
# running
#-- WARNING: SLOW --#
D_links_l = future_lapply(paco_res_l, paco_links, 
                          future.packages=c('paco'),
                          future.seed=my_seed)
D_links_l %>% length
# Out:
# Error : BatchtoolsExpiration: Future ('future_lapply-12') expired (registry path /ebio/abt3_projects/Georg_animal_feces/notebooks/16S_arch/MiSeq-Runs116-122-126-189-190/04_cophylo/.future/20200611_114100-onHCjO/future_lapply-12_1870815664).. The last few lines of the logged output:
# ### [bt]: This is batchtools v0.9.12
# ### [bt]: Starting calculation of 1 jobs
# ### [bt]: Setting working directory to '/ebio/abt3_projects/Georg_animal_feces/notebooks/16S_arch/MiSeq-Runs116-122-126-189-190/04_cophylo'
# ### [bt]: Memory measurement disabled
# ### [bt]: Starting job [batchtools job.id=1]
# ### [bt]: Setting seed to 15188 ...
# Error : BatchtoolsExpiration: Future ('future_lapply-11') expired (registry path /ebio/abt3_projects/Georg_animal_feces/notebooks/16S_arch/MiSeq-Runs116-122-126-189-190/04_cophylo/.future/20200611_114100-onHCjO/future_lapply-11_1686388661).. The last few lines of the logged output:
# ### [bt]: This is batchtools v0.9.12
# ...

# %%
D_links_l %>% length
# Out:
# [1] 100

# %% [markdown]
# ### Saving results

# %%
# for loading results instead of re-running
PACo_links_file = file.path(work_dir, 'physeq_IndD-sens_rarefy_PACo-links.RDS')
PACo_links_file
# Out:
# [1] "/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo//physeq_IndD-sens_rarefy_PACo-links.RDS"

# %%
# saving object (WARNIGN!)
saveRDS(D_links_l, PACo_links_file)
cat('File written:', PACo_links_file, '\n')
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo//physeq_IndD-sens_rarefy_PACo-links.RDS

# %%
# re-loading object
D_links_l = readRDS(PACo_links_file)
D_links_l %>% length
# Out:
# [1] 100

# %%
send_email('http://127.0.0.1:9705/notebooks/notebooks/16S_arch/MiSeq-Runs116-122-126-189-190/04_cophylo/01a_paco_rarefy.ipynb')
# Out:
# Sending email to: nyoungblut@tuebingen.mpg.de

# %% [markdown]
# ### Formatting output

# %%
# residuals
get_residuals = function(rep, D_links_l){
    # residuals
    res = residuals_paco(D_links_l[[rep]]$proc) %>% as.data.frame 
    colnames(res) = 'residuals'
    res = res %>%
        mutate(comparison = rownames(.),
               subsample_rep = rep) %>%
        separate(comparison, c('host', 'microbe'), sep='-') 
        
    # jackknife
    D_links_jk = do.call(rbind, D_links_l[[rep]]$jackknife) %>%
        t %>% as.data.frame %>%
        mutate(comparison = rownames(.)) %>%
        separate(comparison, c('host', 'microbe'), sep='-') %>%
        inner_join(res, c('host'='host', 'microbe'='microbe'))
    
    # return
    return(D_links_jk)
}

D_links_l = lapply(as.list(1:length(D_links_l)), get_residuals, D_links_l=D_links_l)
D_links_l = do.call(rbind, D_links_l)
D_links_l
# Out:
#        mean      upper     host
# 1      -148.5574 -148.5377 X43_European_Badger
# 2      -150.0782 -150.0591 X42_Goitered_Gazelle
# ⋮      ⋮         ⋮         ⋮
# 147055 -86.43796 -86.43115 X415_White_Rhinoceros
# 147056 -96.00273 -95.99626 X237_Red_shanked_Douc_Langur
#        microbe                          residuals  subsample_rep
# 1      6668cc03267d4f04b5a34d676c1db57a 0.01883543 1
# 2      cfd2bb81e97edddddf1a843a0d6999fa 0.01893163 1
# ⋮      ⋮                                ⋮          ⋮
# 147055 36fd5c55ad082f4d05194157da9d13da 0.01512578 100
# 147056 d7dd0bdd8184f8cb7189e1e09afa97d0 0.01594070 100

# %% [markdown]
# ### Summarizing residuals

# %%
D_links_l = D_links_l %>%
    group_by(host, microbe) %>%
    summarize(mean_resid = mean(residuals),
              median_resid = median(residuals),
              sd_resid = sd(residuals),
              CV_resid = sd_resid / mean_resid * 100) %>%
    ungroup()

D_links_l
# Out:
#      host              microbe                          mean_resid median_resid
# 1    F14_Common_Bream  371e6848ba78c69f4f85264020e6e3e8 0.05361554 0.05365713
# 2    F14_Common_Bream  669563302fb65e3b5f7097564fd8b880 0.04631820 0.04652080
# ⋮    ⋮                 ⋮                                ⋮          ⋮
# 2617 X96_European_Hare aad07f6c8bd901f5fd2a2e1a59e8a0dd 0.01538787 0.01539353
# 2618 X96_European_Hare f4c5b86cf1765317322d21fdb1dc2d4c 0.01601909 0.01599728
#      sd_resid     CV_resid
# 1    0.0002375400 0.4430432
# 2    0.0008436276 1.8213738
# ⋮    ⋮            ⋮
# 2617 0.0003126373 2.031712
# 2618 0.0003254186 2.031443

# %% [markdown]
# ### Adding taxonomy

# %%
# adding taxonomy
tax = physeq_arch_IndD %>% tax_table %>% 
    as.matrix %>% as.data.frame %>%
    mutate(microbe = rownames(.))

D_links_l = D_links_l %>%
    inner_join(tax, c('microbe'))

D_links_l
# Out:
#      host              microbe                          mean_resid median_resid
# 1    F14_Common_Bream  371e6848ba78c69f4f85264020e6e3e8 0.05361554 0.05365713
# 2    F14_Common_Bream  669563302fb65e3b5f7097564fd8b880 0.04631820 0.04652080
# ⋮    ⋮                 ⋮                                ⋮          ⋮
# 2588 X96_European_Hare aad07f6c8bd901f5fd2a2e1a59e8a0dd 0.01538787 0.01539353
# 2589 X96_European_Hare f4c5b86cf1765317322d21fdb1dc2d4c 0.01601909 0.01599728
#      sd_resid     CV_resid  Domain  Phylum        Class
# 1    0.0002375400 0.4430432 Archaea Euryarchaeota Methanobacteria
# 2    0.0008436276 1.8213738 Archaea Euryarchaeota Methanomicrobia
# ⋮    ⋮            ⋮         ⋮       ⋮             ⋮
# 2588 0.0003126373 2.031712  Archaea Euryarchaeota Methanobacteria
# 2589 0.0003254186 2.031443  Archaea Euryarchaeota Methanobacteria
#      Order              Family                   Genus
# 1    Methanobacteriales Methanobacteriaceae      Methanobacterium
# ...

# %%
# host taxonomy
host_tax = physeq_arch_IndD %>% sample_data %>% 
    as.matrix %>% as.data.frame %>%
    mutate(sample = rownames(.)) %>%
    dplyr::select(sample, class, order, family, genus, scientific_name, 
                  diet, digestive_system, habitat) %>%
    mutate(digestive_system = digestive_system %>% as.character,
           digestive_system = ifelse(digestive_system == 'fermentation activity foregut', 
                                     'foregut', digestive_system))

D_links_l = D_links_l %>%
    inner_join(host_tax, c('host'='sample')) 

D_links_l
# Out:
#      host              microbe                          mean_resid median_resid
# 1    F14_Common_Bream  371e6848ba78c69f4f85264020e6e3e8 0.05361554 0.05365713
# 2    F14_Common_Bream  669563302fb65e3b5f7097564fd8b880 0.04631820 0.04652080
# ⋮    ⋮                 ⋮                                ⋮          ⋮
# 2588 X96_European_Hare aad07f6c8bd901f5fd2a2e1a59e8a0dd 0.01538787 0.01539353
# 2589 X96_European_Hare f4c5b86cf1765317322d21fdb1dc2d4c 0.01601909 0.01599728
#      sd_resid     CV_resid  Domain  Phylum        Class
# 1    0.0002375400 0.4430432 Archaea Euryarchaeota Methanobacteria
# 2    0.0008436276 1.8213738 Archaea Euryarchaeota Methanomicrobia
# ⋮    ⋮            ⋮         ⋮       ⋮             ⋮
# 2588 0.0003126373 2.031712  Archaea Euryarchaeota Methanobacteria
# 2589 0.0003254186 2.031443  Archaea Euryarchaeota Methanobacteria
#      Order              ⋯ Genus               Species
# 1    Methanobacteriales ⋯ Methanobacterium    unclassified
# ...

# %% [markdown]
# ### Summarizing results

# %%
# by host class
p = ggplot(D_links_l, aes(mean_resid, sd_resid, color=class)) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.5, shape='O') +
    theme_bw() 

p.dims(6,4)
plot(p)
# Out:
# plot without title

# %%
# by host diet
p = ggplot(D_links_l, aes(mean_resid, sd_resid, color=diet)) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.5, shape='O') +
    theme_bw() 

p.dims(6,4)
plot(p)
# Out:
# plot without title

# %%
# by host dig-sys
p = ggplot(D_links_l, aes(mean_resid, sd_resid, color=digestive_system)) +
    geom_point(alpha=0.2) +
    geom_point(alpha=0.5, shape='O') +
    theme_bw() 

p.dims(7,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# #### Intra-species variance

# %%
# CV variance due to 
D_links_l$CV_resid %>% summary_x('residuals')

p = ggplot(D_links_l, aes(CV_resid)) +
    geom_histogram(binwidth=0.25) +
    labs(x='intra-species CV in PACo resimduals', y='# of host-microbe\ncomparisons') +
    theme_bw()

p.dims(5,3.5)
plot(p)
# Out:
#           Min.      1st Qu.  Median   Mean     3rd Qu.  Max.     sd
# residuals 0.3742202 1.631493 2.159714 2.236356 2.726101 6.929893 2.234
#           sd_err_of_mean
# residuals 0.912
# plot without title

# %%
# CV variance due to 
D_links_l$CV_resid %>% summary_x('residuals')

p = ggplot(D_links_l, aes(CV_resid)) +
    geom_histogram(binwidth=0.25) +
    labs(x='intra-species CV in PACo resimduals', 
         y='# of host-microbe\ncomparisons') +
    facet_wrap(~ class, scales='free_y') +
    theme_bw()

p.dims(6,3.5)
plot(p)
# Out:
#           Min.      1st Qu.  Median   Mean     3rd Qu.  Max.     sd
# residuals 0.3742202 1.631493 2.159714 2.236356 2.726101 6.929893 2.234
#           sd_err_of_mean
# residuals 0.912
# plot without title

# %%
# CV variance due to 
D_links_l$CV_resid %>% summary_x('residuals')

p = ggplot(D_links_l, aes(CV_resid)) +
    geom_histogram(binwidth=0.25) +
    labs(x='intra-species CV in PACo resimduals', 
         y='# of host-microbe\ncomparisons') +
    facet_wrap(~ diet, scales='free_y') +
    theme_bw()

p.dims(6.5,2.5)
plot(p)
# Out:
#           Min.      1st Qu.  Median   Mean     3rd Qu.  Max.     sd
# residuals 0.3742202 1.631493 2.159714 2.236356 2.726101 6.929893 2.234
#           sd_err_of_mean
# residuals 0.912
# plot without title

# %%
# CV variance due to 
D_links_l$CV_resid %>% summary_x('residuals')

p = ggplot(D_links_l, aes(CV_resid)) +
    geom_histogram(binwidth=0.25) +
    labs(x='intra-species CV in PACo resimduals', 
         y='# of host-microbe\ncomparisons') +
    facet_wrap(~ digestive_system, scales='free_y') +
    theme_bw()

p.dims(6,3.5)
plot(p)
# Out:
#           Min.      1st Qu.  Median   Mean     3rd Qu.  Max.     sd
# residuals 0.3742202 1.631493 2.159714 2.236356 2.726101 6.929893 2.234
#           sd_err_of_mean
# residuals 0.912
# plot without title

# %% [markdown]
# ### Summarizing residuals

# %%
# plotting by diet
## ordering
tmp = D_links_l %>% 
    group_by(diet) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(diet = diet %>% reorder(-median_resid))

p = ggplot(tmp, aes(diet, mean_resid)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Diet', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(3.5,2.5)
plot(p)
# Out:
# plot without title

# %%
# host diet & class
tmp = D_links_l %>%
    group_by(host, diet, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

# stats
df.dims(20)
compare_means(mean_resid ~ class, data=tmp, method = 'wilcox.test', p.adjust.method = 'BH')
df.dims()

## plotting
my_comparisons = combn(as.character(unique(tmp$class)), 2, simplify=FALSE) 
levs = c('Actinopterygii', 'Amphibia', 'Reptilia', 'Aves', 'Mammalia')
p = tmp %>% 
    mutate(class = factor(class, levels=levs)) %>%
    ggboxplot(x = "class", y = "mean_resid", palette = "jco") + 
    stat_compare_means(comparisons = my_comparisons, 
                       label = 'p.signif', 
                       hide.ns = TRUE, vjust=0.5) +
    labs(x='Class', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )
p.dims(3.5,2.5)
plot(p)
# Out:
#    .y.        group1         group2   p            p.adj   p.format p.signif
# 1  mean_resid Actinopterygii Amphibia 4.040404e-03 4.0e-03 0.00404  **
# 2  mean_resid Actinopterygii Aves     2.600622e-08 1.3e-07 2.6e-08  ****
# 3  mean_resid Actinopterygii Mammalia 2.171910e-06 5.4e-06 2.2e-06  ****
# 4  mean_resid Actinopterygii Reptilia 1.554002e-04 2.6e-04 0.00016  ***
# 5  mean_resid Amphibia       Aves     3.395298e-05 6.8e-05 3.4e-05  ****
# 6  mean_resid Amphibia       Mammalia 6.878549e-04 8.6e-04 0.00069  ***
# 7  mean_resid Amphibia       Reptilia 4.040404e-03 4.0e-03 0.00404  **
# 8  mean_resid Aves           Mammalia 1.817115e-18 1.8e-17 < 2e-16  ****
# 9  mean_resid Aves           Reptilia 3.959707e-04 5.7e-04 0.00040  ***
# 10 mean_resid Mammalia       Reptilia 2.171910e-06 5.4e-06 2.2e-06  ****
#    method
# 1  Wilcoxon
# 2  Wilcoxon
# 3  Wilcoxon
# 4  Wilcoxon
# 5  Wilcoxon
# 6  Wilcoxon
# 7  Wilcoxon
# 8  Wilcoxon
# 9  Wilcoxon
# 10 Wilcoxon
# plot without title

# %%
tmp = D_links_l %>%
    group_by(host, diet, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

# stats
compare_means(mean_resid ~ diet, data=tmp, method = 'wilcox.test', p.adjust.method = 'BH')

## plotting
my_comparisons = combn(as.character(unique(tmp$diet)), 2, simplify=FALSE) 
p = ggboxplot(tmp, x = "diet", y = "mean_resid", palette = "jco") + 
    stat_compare_means(comparisons = my_comparisons, 
                       label = 'p.signif', 
                       hide.ns = TRUE, vjust=0.5) +
    labs(x='Diet', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )
p.dims(3.5,2.5)
plot(p)
# Out:
#   .y.        group1    group2    p            p.adj   p.format p.signif
# 1 mean_resid carnivore herbivore 8.122152e-07 1.2e-06 8.1e-07  ****
# 2 mean_resid carnivore omnivore  8.259920e-01 8.3e-01 0.83     ns
# 3 mean_resid herbivore omnivore  2.266083e-07 6.8e-07 2.3e-07  ****
#   method
# 1 Wilcoxon
# 2 Wilcoxon
# 3 Wilcoxon
# plot without title

# %%
tmp = D_links_l %>%
    group_by(host, diet, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

# stats
#compare_means(mean_resid ~ class + diet, data=tmp, method = 'wilcox.test', p.adjust.method = 'BH')

## plotting
my_comparisons = combn(as.character(unique(tmp$class)), 2, simplify=FALSE) 
levs = c('Actinopterygii', 'Amphibia', 'Reptilia', 'Aves', 'Mammalia')
p = tmp %>% 
    mutate(class = factor(class, levels=levs)) %>%
    ggboxplot(x = "class", y = "mean_resid", palette = "jco",
              facet.by = 'diet') + 
    stat_compare_means(comparisons = my_comparisons, 
                       label = 'p.signif', 
                       hide.ns = TRUE, vjust=0.5) +
    labs(x='Host class', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )
p.dims(5.5,2.5)
plot(p)
# Out:
# Warning message:
# “Computation failed in `stat_signif()`:
# not enough 'y' observations”
# Warning message:
# “Computation failed in `stat_signif()`:
# not enough 'y' observations”
# plot without title

# %%
# plotting by diet & class
tmp = D_links_l %>% 
    group_by(diet, class) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(class = class %>% reorder(-median_resid))

p = ggplot(tmp, aes(class, mean_resid, color=diet)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('Diet') +
    labs(x='Class', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(5,2.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l %>%
    group_by(host, diet, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ diet * class, data=tmp), type=2)
aov_res
# Out:
# Note: model has aliased coefficients
#       sums of squares computed by model comparison
#            Sum Sq       Df  F value     Pr(>F)
# diet       1.620537e-05   2   2.1105692  1.242605e-01
# class      1.300756e-02   4 847.0454499 7.103498e-113
# diet:class 1.228924e-05   4   0.8002687  5.265256e-01
# Residuals  6.680031e-04 174          NA            NA

# %%
# plotting by digestive system
tmp = D_links_l %>% 
    group_by(digestive_system) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(digestive_system = digestive_system %>% reorder(-median_resid))

p = ggplot(tmp, aes(digestive_system, mean_resid)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Digestive system', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(3.5,2.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l %>%
    group_by(host, digestive_system, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup() 

aov_res = car::Anova(lm(mean_resid ~ digestive_system * class, data=tmp), type=2)
aov_res
# Out:
# Note: model has aliased coefficients
#       sums of squares computed by model comparison
#                        Sum Sq       Df  F value     Pr(>F)
# digestive_system       6.339853e-05   4   4.3691455  2.167004e-03
# class                  1.185286e-02   4 816.8462006 3.929567e-111
# digestive_system:class 5.519630e-06   3   0.5071846  6.778309e-01
# Residuals              6.275796e-04 173          NA            NA

# %%
# stats
df.dims(20)
compare_means(mean_resid ~ digestive_system, data=tmp, 
              method = 'wilcox.test', p.adjust.method = 'BH')
df.dims()

## plotting
my_comparisons = combn(as.character(unique(tmp$digestive_system)), 2, simplify=FALSE) 
p = ggboxplot(tmp, x = "digestive_system", y = "mean_resid") + 
    stat_compare_means(comparisons = my_comparisons, 
                       label = 'p.signif', 
                       hide.ns = TRUE, vjust=0.5) +
    labs(x='Digestive system', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )
p.dims(4,3)
plot(p)
# Out:
#    .y.        group1         group2         p            p.adj   p.format
# 1  mean_resid simple         foregut        1.416818e-12 1.4e-11 1.4e-12
# 2  mean_resid simple         hindgut        3.590445e-02 4.5e-02 0.03590
# 3  mean_resid simple         simple hindgut 8.123629e-01 8.1e-01 0.81236
# 4  mean_resid simple         simple foregut 3.428815e-02 4.5e-02 0.03429
# 5  mean_resid foregut        hindgut        2.667162e-06 8.9e-06 2.7e-06
# 6  mean_resid foregut        simple hindgut 1.175556e-09 5.9e-09 1.2e-09
# 7  mean_resid foregut        simple foregut 7.492659e-01 8.1e-01 0.74927
# 8  mean_resid hindgut        simple hindgut 6.406020e-04 1.6e-03 0.00064
# 9  mean_resid hindgut        simple foregut 4.301075e-03 8.6e-03 0.00430
# 10 mean_resid simple hindgut simple foregut 5.291005e-03 8.8e-03 0.00529
#    p.signif method
# 1  ****     Wilcoxon
# 2  *        Wilcoxon
# 3  ns       Wilcoxon
# 4  *        Wilcoxon
# 5  ****     Wilcoxon
# 6  ****     Wilcoxon
# ...

# %%
# plotting by digestive system & class
tmp = D_links_l %>% 
    group_by(class) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(class = class %>% reorder(-median_resid))

p = ggplot(tmp, aes(class, mean_resid, color=digestive_system)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('Digestive system') +
    labs(x='Class', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(5,2.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l %>%
    group_by(host, digestive_system, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ digestive_system * class, data=tmp), type=2)
aov_res
# Out:
# Note: model has aliased coefficients
#       sums of squares computed by model comparison
#                        Sum Sq       Df  F value     Pr(>F)
# digestive_system       6.339853e-05   4   4.3691455  2.167004e-03
# class                  1.185286e-02   4 816.8462006 3.929567e-111
# digestive_system:class 5.519630e-06   3   0.5071846  6.778309e-01
# Residuals              6.275796e-04 173          NA            NA

# %%
# plotting by digestive system & diet
tmp = D_links_l %>% 
    group_by(diet, digestive_system) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(digestive_system = digestive_system %>% reorder(-median_resid))

p = ggplot(tmp, aes(digestive_system, mean_resid, color=diet)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('Diet') +
    labs(x='Digestive system', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(5,2.5)
plot(p)
# Out:
# plot without title

# %%
# plotting by digestive system & diet
tmp = D_links_l %>% 
    group_by(class, diet, digestive_system) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(digestive_system = digestive_system %>% reorder(-median_resid))

p = ggplot(tmp, aes(digestive_system, mean_resid, color=diet)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('Diet') +
    labs(x='Digestive system', y='Residuals') +
    facet_wrap(~ class) +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(6,3.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l %>%
    group_by(host, digestive_system, diet) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ digestive_system * diet, data=tmp), type=2)
aov_res
# Out:
# Note: model has aliased coefficients
#       sums of squares computed by model comparison
#                       Sum Sq       Df  F value   Pr(>F)
# digestive_system      1.260661e-03   4 4.5425190 0.001626734
# diet                  5.875981e-05   2 0.4234565 0.655448779
# digestive_system:diet 2.854897e-04   3 1.3716003 0.253086146
# Residuals             1.214170e-02 175        NA          NA

# %%
# anova
tmp = D_links_l %>%
    group_by(host, digestive_system, diet, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ digestive_system * diet * class, data=tmp), type=2)
df.dims(10)
aov_res
df.dims()
# Out:
# Note: model has aliased coefficients
#       sums of squares computed by model comparison
#                             Sum Sq       Df  F value     Pr(>F)
# digestive_system            6.164396e-05   4   4.2770764  2.554200e-03
# diet                        1.322793e-05   2   1.8356009  1.627601e-01
# class                       1.153540e-02   4 800.3672650 7.090025e-107
# digestive_system:diet       8.205466e-06   2   1.1386486  3.227548e-01
# digestive_system:class      4.780589e-06   2   0.6633884  5.164714e-01
# diet:class                  1.036585e-05   4   0.7192196  5.799315e-01
# digestive_system:diet:class           NA   0          NA            NA
# Residuals                   5.945213e-04 165          NA            NA

# %%
# plotting by host family
tmp = D_links_l %>% 
    group_by(family) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    group_by(class) %>%
    mutate(median_resid_class = median(mean_resid)) %>%
    ungroup() %>%   
    mutate(class = gsub('Actinopterygii', 'Act', class),
           class = gsub('Amphibia', 'Amp', class),
           family = family %>% reorder(-median_resid),
           class = class %>% reorder(-median_resid_class))

p = ggplot(tmp, aes(family, mean_resid)) +
    geom_boxplot() +
    labs(x='Family', y='Residuals') +
    theme_bw() +
    facet_grid(. ~ class, scales='free_x', space='free_x')+
    theme(
        axis.text.x = element_text(angle=65, hjust=1)
    )

p.dims(9.5,3.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# #### Just mammalia

# %%
# plotting by diet system 
tmp = D_links_l %>% 
    filter(class == 'Mammalia') %>%
    group_by(diet) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(diet = diet %>% reorder(-median_resid))

p = ggplot(tmp, aes(diet, mean_resid)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Diet', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(3.5,2.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l %>%
    filter(class == 'Mammalia') %>%
    group_by(host, diet) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ diet, data=tmp), type=2)
aov_res
# Out:
#           Sum Sq       Df  F value   Pr(>F)
# diet      7.333819e-06   2 0.7661234 0.4668984
# Residuals 6.222211e-04 130        NA        NA

# %%
tmp = D_links_l %>%
    filter(class == 'Mammalia') %>%
    group_by(host, diet, class) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

# stats
compare_means(mean_resid ~ diet, data=tmp, method = 'wilcox.test', p.adjust.method = 'BH')

## plotting
my_comparisons = combn(as.character(unique(tmp$diet)), 2, simplify=FALSE) 
p = ggboxplot(tmp, x = "diet", y = "mean_resid", palette = "jco") + 
    stat_compare_means(comparisons = my_comparisons, 
                       label = 'p.signif', 
                       hide.ns = TRUE, vjust=0.5) +
    labs(x='Diet', y='paco residuals') +
    theme_bw()
p.dims(4,3)
plot(p)
# Out:
#   .y.        group1    group2    p          p.adj p.format p.signif method
# 1 mean_resid carnivore herbivore 0.46206057 0.46  0.462    ns       Wilcoxon
# 2 mean_resid carnivore omnivore  0.17507073 0.26  0.175    ns       Wilcoxon
# 3 mean_resid herbivore omnivore  0.07156934 0.21  0.072    ns       Wilcoxon
# plot without title

# %%
# plotting by digestive system 
tmp = D_links_l %>% 
    filter(class == 'Mammalia') %>%
    group_by(digestive_system) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(digestive_system = digestive_system %>% reorder(-median_resid))

p = ggplot(tmp, aes(digestive_system, mean_resid)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Digestive system', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(3.5,2.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# #### stats

# %%
# anova
tmp = D_links_l %>%
    filter(class == 'Mammalia') %>%
    group_by(host, digestive_system) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ digestive_system, data=tmp), type=2)
aov_res
# Out:
#                  Sum Sq       Df  F value  Pr(>F)
# digestive_system 6.606965e-05   4 3.752056 0.006393782
# Residuals        5.634853e-04 128       NA          NA

# %%
tmp = D_links_l %>%
    filter(class == 'Mammalia') %>%
    group_by(host, digestive_system) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

# stats
df.dims(20)
compare_means(mean_resid ~ digestive_system, data=tmp, 
              method = 'wilcox.test', p.adjust.method = 'BH')
df.dims()

## plotting
my_comparisons = combn(as.character(unique(tmp$digestive_system)), 2, simplify=FALSE) 
p = ggboxplot(tmp, x = "digestive_system", y = "mean_resid") + 
    stat_compare_means(comparisons = my_comparisons, 
                       label = 'p.signif', 
                       hide.ns = TRUE, vjust=0.5) +
    labs(x='Digestive system', y='paco residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )
p.dims(4,3)
plot(p)
# Out:
#    .y.        group1         group2         p            p.adj   p.format
# 1  mean_resid foregut        simple         1.038198e-04 5.2e-04 0.0001
# 2  mean_resid foregut        hindgut        5.615886e-06 5.6e-05 5.6e-06
# 3  mean_resid foregut        simple hindgut 3.659487e-03 1.1e-02 0.0037
# 4  mean_resid foregut        simple foregut 7.492659e-01 7.5e-01 0.7493
# 5  mean_resid simple         hindgut        9.692143e-03 1.9e-02 0.0097
# 6  mean_resid simple         simple hindgut 1.836163e-01 2.3e-01 0.1836
# 7  mean_resid simple         simple foregut 6.747638e-02 9.6e-02 0.0675
# 8  mean_resid hindgut        simple hindgut 5.028998e-01 5.6e-01 0.5029
# 9  mean_resid hindgut        simple foregut 4.597701e-03 1.1e-02 0.0046
# 10 mean_resid simple hindgut simple foregut 3.030303e-02 5.1e-02 0.0303
#    p.signif method
# 1  ***      Wilcoxon
# 2  ****     Wilcoxon
# 3  **       Wilcoxon
# 4  ns       Wilcoxon
# 5  **       Wilcoxon
# 6  ns       Wilcoxon
# 7  ns       Wilcoxon
# ...

# %%
# plotting by digestive system & diet
tmp = D_links_l %>% 
    filter(class == 'Mammalia') %>%
    group_by(diet, digestive_system) %>%
    mutate(median_resid = median(mean_resid)) %>%
    ungroup() %>%
    mutate(digestive_system = digestive_system %>% reorder(-median_resid))

p = ggplot(tmp, aes(digestive_system, mean_resid, color=diet)) +
    geom_boxplot(outlier.size = 0.5) +
    scale_color_discrete('Diet') +
    labs(x='Digestive system', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=55, hjust=1)
    )

p.dims(4,2.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l %>%
    filter(class == 'Mammalia') %>%
    group_by(host, diet, digestive_system) %>%
    summarize(mean_resid = mean(mean_resid)) %>%
    ungroup()

aov_res = car::Anova(lm(mean_resid ~ digestive_system * diet, data=tmp), type=2)
aov_res
# Out:
# Note: model has aliased coefficients
#       sums of squares computed by model comparison
#                       Sum Sq       Df  F value   Pr(>F)
# digestive_system      6.397543e-05   4 3.6056241 0.008129488
# diet                  5.239603e-06   2 0.5906030 0.555543854
# digestive_system:diet 8.205466e-06   2 0.9249121 0.399284519
# Residuals             5.500403e-04 124        NA          NA

# %% [markdown]
# ### Adjusting for digestive system

# %%
x = lm(mean_resid ~ digestive_system, data=D_links_l)
D_links_l$phy_resid = x$residuals %>% scales::rescale(to=c(0,1))
D_links_l
# Out:
#      host              microbe                          mean_resid median_resid
# 1    F14_Common_Bream  371e6848ba78c69f4f85264020e6e3e8 0.05361554 0.05365713
# 2    F14_Common_Bream  669563302fb65e3b5f7097564fd8b880 0.04631820 0.04652080
# ⋮    ⋮                 ⋮                                ⋮          ⋮
# 2617 X96_European_Hare aad07f6c8bd901f5fd2a2e1a59e8a0dd 0.01538787 0.01539353
# 2618 X96_European_Hare f4c5b86cf1765317322d21fdb1dc2d4c 0.01601909 0.01599728
#      sd_resid     CV_resid  Domain  Phylum        Class
# 1    0.0002375400 0.4430432 Archaea Euryarchaeota Methanobacteria
# 2    0.0008436276 1.8213738 Archaea Euryarchaeota Methanomicrobia
# ⋮    ⋮            ⋮         ⋮       ⋮             ⋮
# 2617 0.0003126373 2.031712  Archaea Euryarchaeota Methanobacteria
# 2618 0.0003254186 2.031443  Archaea Euryarchaeota Methanobacteria
#      Order              ⋯ Species                 class          order
# ...

# %%
tmp = D_links_l %>% 
    group_by(family) %>%
    mutate(median_resid = median(phy_resid)) %>%
    ungroup() %>%
    group_by(class) %>%
    mutate(median_resid_class = median(phy_resid)) %>%
    ungroup() %>%   
    mutate(class = gsub('Actinopterygii', 'Act', class),
           class = gsub('Amphibia', 'Amp', class),
           family = family %>% reorder(-median_resid),
           class = class %>% reorder(-median_resid_class))

p = ggplot(tmp, aes(family, phy_resid)) +
    geom_boxplot(outlier.size = 0.5) +
    labs(x='Family', y='Residuals') +
    theme_bw() +
    facet_grid(. ~ class, scales='free_x', space='free_x')+
    theme(
        axis.text.x = element_text(angle=65, hjust=1)
    )

p.dims(9.5,3.5)
plot(p)
# Out:
# plot without title

# %%
# formatting
D_links_l_s = D_links_l %>% 
    dplyr::select(host, microbe, phy_resid, digestive_system, class) %>%
    gather(category, value, -host, -microbe, -phy_resid, -class) 
D_links_l_s
# Out:
#      host              microbe                          phy_resid
# 1    F14_Common_Bream  371e6848ba78c69f4f85264020e6e3e8 0.9862171
# 2    F14_Common_Bream  669563302fb65e3b5f7097564fd8b880 0.8049617
# ⋮    ⋮                 ⋮                                ⋮
# 2617 X96_European_Hare aad07f6c8bd901f5fd2a2e1a59e8a0dd 0.2829113
# 2618 X96_European_Hare f4c5b86cf1765317322d21fdb1dc2d4c 0.2985898
#      class          category         value
# 1    Actinopterygii digestive_system simple
# 2    Actinopterygii digestive_system simple
# ⋮    ⋮              ⋮                ⋮
# 2617 Mammalia       digestive_system hindgut
# 2618 Mammalia       digestive_system hindgut

# %%
# plotting
tmp = D_links_l_s %>% 
    group_by(class) %>%
    mutate(median_resid = median(phy_resid)) %>%
    ungroup() %>%
    rename('digestive_system' = value) %>%
    mutate(class = class %>% reorder(-median_resid))

p = ggplot(tmp, aes(class, phy_resid)) +
    geom_boxplot() +
    labs(x='Class', y='Residuals') +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

p.dims(4,2.5)
plot(p)
# Out:
# plot without title

# %%
# anova
tmp = D_links_l_s %>%
    group_by(host, class, category, value) %>%
    summarize(mean_resid = mean(phy_resid)) %>%
    ungroup() %>%
    rename('diet' = value)

aov_res = car::Anova(lm(mean_resid ~ class, data=tmp), type=2)
aov_res
# Out:
#           Sum Sq   Df  F value  Pr(>F)
# class     4.977266   4 80.59274 4.480709e-39
# Residuals 2.779121 180       NA           NA

# %% [markdown]
# #### Formatting for iTOL

# %%
# filtering
D_links_l_f = D_links_l %>%
    group_by(microbe) %>%
    mutate(n_microbe = n()) %>%
    ungroup() %>%
    filter(n_microbe >= 5)

D_links_l_f %>% unique_n('microbes', microbe)
# Out:
# No. of unique microbes: 131

# %%
# dendrogram of OTUs
tmp = D_links_l_f %>%
    distinct(Domain, Phylum, Class, Order, Family, Genus, Species, microbe) %>%
    mutate(OTU_ID = gsub('^', 'OTU.', microbe %>% as.factor %>% as.numeric)) %>%
    mutate(OTU_ID = paste(Family, Genus, Species, OTU_ID, sep='-'),
           OTU_ID = gsub(' ', '_', OTU_ID)) %>%
    mutate(Domain = Domain %>% as.factor,
           Phylum = Phylum %>% as.factor,
           Class = Class %>% as.factor,
           Order = Order %>% as.factor,
           Family = Family %>% as.factor,
           Genus = Genus %>% as.factor,
           Species = Species %>% as.factor,
           OTU_ID = OTU_ID %>% as.factor) 

clado = as.phylo(~Domain/Phylum/Class/Order/Family/Genus/Species/OTU_ID, data=tmp)
clado = compute.brlen(clado, 1)
clado = chronos(clado)
p.dims(5,6)
plot(clado, cex=0.4)
# Out:
# Setting initial dates...
# Fitting in progress... get a first set of estimates
#          Penalised log-lik = -219.4438
# Optimising rates... dates... -219.4438
# Optimising rates... dates... -219.4437
#
# Done.
# plot without title

# %%
otu_m = D_links_l_f %>%
    mutate(host = gsub(' ', '_', scientific_name)) %>%
    mutate(OTU_ID = gsub('^', 'OTU.', microbe %>% as.factor %>% as.numeric)) %>%
    mutate(microbe = paste(Family, Genus, Species, OTU_ID, sep='-'),
           microbe = gsub(' ', '_', microbe)) %>%
    group_by(host, Genus, microbe) %>%
    summarize(mean_resid = mean(mean_resid, na.rm=TRUE)) %>%
    ungroup() %>%
    dplyr::select(host, microbe, mean_resid) %>%
    spread(microbe, mean_resid, fill=0) %>%
    as.data.frame

rownames(otu_m) = otu_m$host 
otu_m$host = NULL
rownames(otu_m) = gsub('^X', '', rownames(otu_m))
colnames(otu_m) = gsub(' ', '_', colnames(otu_m))

otu_m
# Out:
#                     Halococcaceae-uncultured-uncultured_archaeon-OTU.39
# Abramis_brama       0
# Aepyceros_melampus  0
# ⋮                   ⋮
# Vulpes_vulpes       0
# Zamenis_longissimus 0
#                     Haloferacaceae-unclassified-unclassified-OTU.105
# Abramis_brama       0
# Aepyceros_melampus  0
# ⋮                   ⋮
# Vulpes_vulpes       0
# Zamenis_longissimus 0
#                     Haloferacaceae-unclassified-unclassified-OTU.19
# Abramis_brama       0
# Aepyceros_melampus  0
# ⋮                   ⋮
# Vulpes_vulpes       0
# Zamenis_longissimus 0
#                     Haloferacaceae-unclassified-unclassified-OTU.51
# Abramis_brama       0
# Aepyceros_melampus  0
# ⋮                   ⋮
# Vulpes_vulpes       0
# Zamenis_longissimus 0
#                     Haloferacaceae-unclassified-unclassified-OTU.62
# Abramis_brama       0
# Aepyceros_melampus  0
# ⋮                   ⋮
# Vulpes_vulpes       0
# Zamenis_longissimus 0
# ...

# %%
# checking overlap
overlap(colnames(otu_m), clado$tip.label)
# Out:
# intersect(x,y): 131
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 131

# %%
# writing itol file
itol_htmp_file = file.path(work_dir, 'physeq_IndD-rarefy_PACo-Con-links_htmp.txt')
itol_heatmap(otu_m, 'paco_residuals', itol_htmp_file, tree = clado)
# Out:
# Warning message in if (color_scheme == "color") {:
# “the condition has length > 1 and only the first element will be used”
# File written: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo//physeq_IndD-rarefy_PACo-Con-links_htmp.txt

# %% [markdown]
# #### iTOL: distribution of residuals per host species

# %%
# summing residuals by host
#ID1,minimum,q1,median,q3,maximum,extreme_value1,extreme_value2
tmp = D_links_l %>%
    filter(!is.na(mean_resid)) %>%
    mutate(host = gsub(' ', '_', scientific_name)) %>%
    group_by(host, Genus, microbe) %>%
    summarize(mean_resid = mean(mean_resid, na.rm=TRUE)) %>%
    ungroup() %>%
    group_by(host) %>%
    summarize(minimum = min(mean_resid),
              q1 = quantile(mean_resid, 0.25),
              median = median(mean_resid),
              q3 = quantile(mean_resid, 0.75),
              maximum = max(mean_resid)) %>%
    ungroup() %>%
    as.data.frame
rownames(tmp) = tmp$host
tmp$host = NULL
tmp
# Out:
#                     minimum    q1         median     q3         maximum
# Abramis_brama       0.04631820 0.04708640 0.05195276 0.05357642 0.05372165
# Aepyceros_melampus  0.01326042 0.01331019 0.01340601 0.01383636 0.01442892
# ⋮                   ⋮          ⋮          ⋮          ⋮          ⋮
# Vulpes_vulpes       0.01433657 0.01498575 0.01500242 0.01501668 0.01507180
# Zamenis_longissimus 0.03021744 0.03045715 0.03317951 0.03582283 0.03595379

# %%
# writing itol boxplot
itol_boxplot_file = file.path(work_dir, 'physeq_IndD-rarefy_PACo-Con-links_box.txt')
itol_boxplot(tmp, 'paco_resid_species', itol_boxplot_file)
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/cophylo//physeq_IndD-rarefy_PACo-Con-links_box.txt

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.4 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/phyloseq-phy/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] LeyLabRMisc_0.1.5       future.apply_1.5.0      future.batchtools_0.9.0
#  [4] future_1.17.0           paco_0.4.1              ape_5.3
#  [7] phyloseq_1.30.0         tidytable_0.4.1         data.table_1.12.8
# [10] ggplot2_3.2.1           tidyr_1.0.0             dplyr_0.8.3
#
# ...
