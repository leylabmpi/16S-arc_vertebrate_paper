# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Samples-table" data-toc-modified-id="Samples-table-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Samples table</a></span><ul class="toc-item"><li><span><a href="#Labeling" data-toc-modified-id="Labeling-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Labeling</a></span></li></ul></li><li><span><a href="#LLA" data-toc-modified-id="LLA-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>LLA</a></span><ul class="toc-item"><li><span><a href="#Config" data-toc-modified-id="Config-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Config</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * LLA on MiSeq Run189

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189-190/LLA/Run0189/'

# metadata
metadata_file = '/ebio/abt3_projects/Georg_animal_feces/data/mapping/unified_metadata_complete_190529.tsv'

# params
pipeline_dir = '/ebio/abt3_projects/Georg_animal_feces/bin/lla'

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(LeyLabRMisc)

# %%
df.dims()

# %% [markdown]
# # Samples table
#
# * Created from [local SRA](http://readarchive.eb.local/sra/)
#   * MiSeq-run = 0189
# * converted to LLA input samples table with `convert_SRA_to_samples_table.py`

# %% [markdown]
# ## Labeling

# %%
# metadata
metadata = read.delim(metadata_file, sep='\t')
metadata
# Out:
#     SampleID                host_subject_id host_german_name  host_common_name
# 1   F14_Common_Bream        F14             Brachse           Common.Bream
# 2   F35_Red_Deer            F35             Rothirsch         Red.Deer
# ⋮   ⋮                       ⋮               ⋮                 ⋮
# 474 X189_fail_Rainbow_Trout 189.fail        Regenbogenforelle Rainbow.Trout
# 475 X232_fail_Brown_Trout   232.fail        Seeforelle        Brown.Trout
#     scientific_name     scientific_name_subspecies host_taxid class
# 1   Abramis_brama       NA                         38527      Actinopterygii
# 2   Cervus_elaphus      NA                          9860      Mammalia
# ⋮   ⋮                   ⋮                          ⋮          ⋮
# 474 Oncorhynchus_mykiss NA                         8022       Actinopterygii
# 475 Salmo_trutta        NA                         8032       Actinopterygii
#     order         family     ⋯ temp_regulation        collection_date season
# 1   Cypriniformes Cyprinidae ⋯ ectotherm/poikilotherm 2010-08-10      summer
# 2   Artiodactyla  Cervidae   ⋯ endotherm/homoiotherm  2010-09-29      autumn
# ⋮   ⋮             ⋮          ⋱ ⋮                      ⋮               ⋮
# 474 Salmoniformes Salmonidae ⋯ ectotherm/poikilotherm 2012-03-01      winter
# 475 Salmoniformes Salmonidae ⋯ ectotherm/poikilotherm 2012-03-15      winter
#     samp_store_days samp_collect_device                       sampling_method
# 1   317             Greiner Polypropylene Tube 50ml           feces sampling
# 2   229             Greiner Polystyrene 30ml Faeces Container feces sampling
# ⋮   ⋮               ⋮                                         ⋮
# 474 467             Eppendorf tube                            feces sampling
# 475 453             Polyethylene freezer bag                  gut section
#     diet      feeding_style     digestive_system digestive_system_detail
# 1   omnivore  NA                simple           simple
# 2   herbivore intermediate type foregut          foregut
# ⋮   ⋮         ⋮                 ⋮                ⋮
# 474 carnivore NA                simple           simple
# 475 carnivore NA                simple           simple

# %%
# samples
samp = read.delim(file.path(work_dir, 'samples.txt'), sep='\t')
samp
# Out:
#     Sample                      Run Lane
# 1   X108_Striped_Desert_Hamster 189 1
# 2   X109_Red_Fox                189 1
# ⋮   ⋮                           ⋮   ⋮
# 129 XF66_Wild_Boar              189 1
# 130 XF90_Domestic_Dog           189 1
#     Read1
# 1   /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdX108_Striped_Desert_Hamster_RunId0189_LaneId1/X108_Striped_Desert_Hamster_TACGCTGC-AGCCAACT_L001_R1_001.fastq.gz
# 2   /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdX109_Red_Fox_RunId0189_LaneId1/X109_Red_Fox_CGATCAGT-AGCCAACT_L001_R1_001.fastq.gz
# ⋮   ⋮
# 129 /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdXF66_Wild_Boar_RunId0189_LaneId1/XF66_Wild_Boar_GGAGCTAC-GAGAGATT_L001_R1_001.fastq.gz
# 130 /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdXF90_Domestic_Dog_RunId0189_LaneId1/XF90_Domestic_Dog_GTAGAGGA-CGCGGTTA_L001_R1_001.fastq.gz
#     Read2
# 1   /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdX108_Striped_Desert_Hamster_RunId0189_LaneId1/X108_Striped_Desert_Hamster_TACGCTGC-AGCCAACT_L001_R2_001.fastq.gz
# 2   /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdX109_Red_Fox_RunId0189_LaneId1/X109_Red_Fox_CGATCAGT-AGCCAACT_L001_R2_001.fastq.gz
# ⋮   ⋮
# 129 /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdXF66_Wild_Boar_RunId0189_LaneId1/XF66_Wild_Boar_GGAGCTAC-GAGAGATT_L001_R2_001.fastq.gz
# 130 /ebio/abt6_sra/years/2019/12_04/Georg_animal_gut_archaea_16S/illumina_M00333_flowcellA_SampleIdXF90_Domestic_Dog_RunId0189_LaneId1/XF90_Domestic_Dog_GTAGAGGA-CGCGGTTA_L001_R2_001.fastq.gz

# %%
# formatting
samp = samp %>%
    mutate(Sample = gsub('^XF', 'F', Sample))

# checking overlap with metadata
setdiff(samp$Sample, metadata$SampleID)
# Out:
# character(0)

# %%
# writing
out_file = file.path(work_dir, 'samples_rn.txt')
write.table(samp, file=out_file, sep='\t', quote=FALSE, row.names=FALSE)
cat('File written:', out_file, '\n')
# Out:
# File written: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt

# %% [markdown]
# # LLA

# %% [markdown]
# ## Config

# %%
cat_file(file.path(work_dir, 'config.yaml'))
# Out:
# # table with sample --> read_file information
# samples_file: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189/samples_rn.txt
#
# # output location
# output_dir: /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189/
#
#
# #---- You probably don't need to change anything below this line ----#
#
# # taxonomy classifier database (SILVA by default)
# classifier: /ebio/abt3_projects/databases/leylab16s/classifiers/scikit_0.21.2/silva-132-99-515-806-nb-classifier.qza
#
# # params (change as needed)
# params:
#   trimmomatic:
#     sample_size: 10000
#     window_size: 20
#     qlty_threshold: 25
#   feature_table_merge:
#     p_overlap_method: sum
#   classify_sklearn:
#     p_reads_per_batch: 1000
#   filter_table:
#     p_include:
#       - D_1__
#     p_exclude:
#       - D_0__Eukaryota,D_4__mitochondria,D_2__Chloroplast
#
#
# # snakemake pipeline
# pipeline:
#   snakemake_folder: ./
#   script_folder: ./bin/scripts/
#   temp_folder: /tmp/global2/nyoungblut/

# %% [markdown]
# ## Run

# %% [markdown]
# ```
# (snakemake_dev) @ rick:/ebio/abt3_projects/Georg_animal_feces/bin/lla
# $ screen -L -S LLA-run189 ./snakemake_sge.sh /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189/config.yaml cluster.json 30
# ```

# %% [markdown]
# # Summary

# %%
df.dims(20)
list.files(work_dir, full.names=TRUE) %>%
    as.list %>%
    lapply(file.info) %>%
    do.call(rbind, .)
df.dims()
# Out:
#                                                                                                                          size
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        2725053
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                      4096
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                     994
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv    88446
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                            4096
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 2566351
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    1063523
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    2209037
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         2528046
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                          216
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt                53240
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                   53248
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza        708274
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt        670142
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza             750181
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                1056374
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                4391040
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           1075571
#                                                                                                                          isdir
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                    TRUE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                          TRUE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                       TRUE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                FALSE
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           FALSE
#                                                                                                                          mode
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   2755
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         2755
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      2755
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                0644
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           0644
#                                                                                                                          mtime
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        2019-12-04 19:32:35
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   2019-12-04 19:56:59
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 2019-12-04 16:47:33
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  2019-12-04 16:22:05
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         2019-12-04 19:56:41
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 2019-12-04 19:39:02
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    2019-12-04 19:57:50
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    2019-12-04 19:23:59
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         2019-12-04 18:29:01
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      2019-12-04 18:26:50
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              2020-01-08 14:00:13
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 2019-12-04 16:27:14
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       2019-12-04 19:20:42
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       2019-12-04 19:22:15
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            2019-12-04 18:29:12
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                2019-12-04 19:19:21
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                2019-12-04 19:20:31
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           2019-12-04 19:56:17
#                                                                                                                          ctime
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        2019-12-04 19:32:35
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   2019-12-04 19:56:59
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 2019-12-04 16:47:33
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  2019-12-04 16:26:48
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         2019-12-04 19:56:41
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 2019-12-04 19:39:02
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    2019-12-04 19:57:50
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    2019-12-04 19:23:59
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         2019-12-04 18:29:01
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      2019-12-04 18:26:50
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              2020-01-08 14:00:13
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 2019-12-04 16:27:14
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       2019-12-04 19:20:42
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       2019-12-04 19:22:15
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            2019-12-04 18:29:12
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                2019-12-04 19:19:21
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                2019-12-04 19:20:31
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           2019-12-04 19:56:17
#                                                                                                                          atime
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        2019-12-04 19:32:35
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   2019-12-04 16:48:59
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 2019-12-04 16:26:58
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  2019-12-04 16:26:48
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         2019-12-04 16:48:48
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 2019-12-04 19:39:02
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    2019-12-04 19:57:50
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    2019-12-04 19:23:59
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         2019-12-04 18:29:01
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      2019-12-04 16:48:31
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              2019-12-04 16:46:44
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 2019-12-04 16:27:14
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       2019-12-04 19:20:42
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       2019-12-04 19:22:15
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            2019-12-04 18:29:12
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                2019-12-04 19:19:21
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                2019-12-04 19:20:31
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           2019-12-04 19:56:17
#                                                                                                                          uid
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                6354
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           6354
#                                                                                                                          gid
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza 353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                353
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           353
#                                                                                                                          uname
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                nyoungblut
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           nyoungblut
#                                                                                                                          grname
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//aligned-rep-seqs.qza        abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//benchmark                   abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//config.yaml                 abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//data_export_2019-12-04.csv  abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//log                         abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//masked-aligned-rep-seqs.qza abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//midpoint-rooted-tree.qza    abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged_filt.qza    abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//rep-seqs_merged.qza         abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//Run189                      abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples_rn.txt              abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//samples.txt                 abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.qza       abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged_filt.txt       abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//table_merged.qza            abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qza                abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//taxonomy.qzv                abt3
# /ebio/abt3_projects/Georg_animal_feces/data/16S_arch/MiSeq-Runs-116-122-126-189/LLA/Run0189//unrooted-tree.qza           abt3

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.6.2 (2019-12-12)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/tidyverse/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.0 ggplot2_3.2.1     tidyr_1.0.0       dplyr_0.8.3
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.3       magrittr_1.5     munsell_0.5.0    tidyselect_0.2.5
#  [5] uuid_0.1-2       colorspace_1.4-1 R6_2.4.1         rlang_0.4.2
#  [9] tools_3.6.2      grid_3.6.2       gtable_0.3.0     withr_2.1.2
# [13] htmltools_0.4.0  lazyeval_0.2.2   digest_0.6.23    assertthat_0.2.1
# [17] lifecycle_0.1.0  tibble_2.1.3     crayon_1.3.4     IRdisplay_0.7.0
# [21] purrr_0.3.3      repr_1.0.2       base64enc_0.1-3  vctrs_0.2.1
# [25] IRkernel_1.1     zeallot_0.1.0    glue_1.3.1       evaluate_0.14
# [29] pbdZMQ_0.3-3     compiler_3.6.2   pillar_1.4.3     scales_1.1.0
# [33] backports_1.1.5  jsonlite_1.6     pkgconfig_2.0.3

# %%
pipelineInfo(pipeline_dir)
# Out:
# LLA
# ===
#
# Ley Lab Amplicon pipeline (LLA)
#
# * Version: 0.2.6
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
#   * Guillermo Luque <guillermo.luque@tuebingen.mpg.de>
#   * Jacobo de la Cuesta <jacobo.delacuesta@tuebingen.mpg.de>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/Georg_animal_feces/bin/lla/bin/envs/qiime2.yaml <==
# channels:
# - qiime2/label/r2019.10
# - conda-forge
# - bioconda
# - defaults
# dependencies:
# - _libgcc_mutex=0.1
# - _r-mutex=1.0.1
# - alsa-lib=1.1.5
# - arb-bio-tools=6.0.6
# - asn1crypto=1.2.0
# - atomicwrites=1.3.0
# - attrs=19.3.0
# - backcall=0.1.0
# - bibtexparser=1.1.0
# - binutils_impl_linux-64=2.31.1
# - binutils_linux-64=2.31.1
# - bioconductor-biobase=2.42.0
# - bioconductor-biocgenerics=0.28.0
# - bioconductor-biocparallel=1.16.6
# - bioconductor-biostrings=2.50.2
# - bioconductor-dada2=1.10.0
# - bioconductor-delayedarray=0.8.0
# - bioconductor-genomeinfodb=1.18.1
# - bioconductor-genomeinfodbdata=1.2.1
# - bioconductor-genomicalignments=1.18.1
# - bioconductor-genomicranges=1.34.0
# - bioconductor-iranges=2.16.0
# - bioconductor-rsamtools=1.34.0
# - bioconductor-s4vectors=0.20.1
# - bioconductor-shortread=1.40.0
# - bioconductor-summarizedexperiment=1.12.0
# - bioconductor-xvector=0.22.0
# - bioconductor-zlibbioc=1.28.0
# - biom-format=2.1.7
# - blas=2.14
# - blast=2.9.0
# - bleach=3.1.0
# - bokeh=1.3.4
# - boost=1.68.0
# - boost-cpp=1.68.0
# - bwidget=1.9.13
# - bzip2=1.0.8
# - ca-certificates=2019.9.11
# - cachecontrol=0.12.5
# - cairo=1.16.0
# - certifi=2019.9.11
# - cffi=1.13.1
# - chardet=3.0.4
# - click=7.0
# - cryptography=2.7
# - curl=7.65.3
# - cutadapt=2.6
# - cycler=0.10.0
# - cython=0.29.13
# - dbus=1.13.6
# - deblur=1.1.0
# - decorator=4.4.1
# - defusedxml=0.6.0
# - dendropy=4.4.0
# - dnaio=0.4
# - emperor=1.0.0b20
# - entrypoints=0.3
# - expat=2.2.5
# - fastcluster=1.1.25
# - fasttree=2.1.10
# - fontconfig=2.13.1
# - freetype=2.10.0
# - future=0.18.2
# - gcc_impl_linux-64=7.3.0
# - gcc_linux-64=7.3.0
# - gettext=0.19.8.1
# - gfortran_impl_linux-64=7.3.0
# - gfortran_linux-64=7.3.0
# - giflib=5.1.7
# - glib=2.58.3
# - gmp=6.1.2
# - gneiss=0.4.6
# - gnutls=3.6.5
# - graphite2=1.3.13
# - gsl=2.5
# - gst-plugins-base=1.14.5
# - gstreamer=1.14.5
# - gxx_impl_linux-64=7.3.0
# - gxx_linux-64=7.3.0
# - h5py=2.10.0
# - harfbuzz=2.4.0
# - hdf5=1.10.5
# - hdmedians=0.13
# - hmmer=3.1b2
# - icu=58.2
# - idna=2.8
# - ijson=2.5
# - importlib_metadata=0.23
# - ipykernel=5.1.3
# - ipython=7.9.0
# - ipython_genutils=0.2.0
# - ipywidgets=7.5.1
# - iqtree=1.6.12
# - jedi=0.15.1
# - jinja2=2.10.3
# - joblib=0.14.0
# - jpeg=9c
# - jsonschema=3.1.1
# - jupyter_client=5.3.3
# - jupyter_core=4.5.0
# - kiwisolver=1.1.0
# - krb5=1.16.3
# - lcms2=2.9
# - libarbdb=6.0.6
# - libblas=3.8.0
# - libcblas=3.8.0
# - libcurl=7.65.3
# - libedit=3.1.20170329
# - libffi=3.2.1
# - libgcc=7.2.0
# - libgcc-ng=9.1.0
# - libgfortran-ng=7.3.0
# - libiconv=1.15
# - liblapack=3.8.0
# - liblapacke=3.8.0
# - libopenblas=0.3.7
# - libpng=1.6.37
# - libsodium=1.0.17
# - libssh2=1.8.2
# - libstdcxx-ng=9.1.0
# - libtiff=4.0.10
# - libuuid=2.32.1
# - libxcb=1.13
# - libxml2=2.9.9
# - lockfile=0.12.2
# - lz4-c=1.8.3
# - mafft=7.310
# - make=4.2.1
# - markupsafe=1.1.1
# - matplotlib=3.1.0
# - matplotlib-base=3.1.0
# - mistune=0.8.4
# - more-itertools=7.2.0
# - msgpack-python=0.6.2
# - natsort=6.0.0
# - nbconvert=5.6.1
# - nbformat=4.4.0
# - ncurses=6.1
# - nettle=3.4.1
# - networkx=2.4
# - nose=1.3.7
# - notebook=6.0.1
# - numpy=1.17.3
# - olefile=0.46
# - openjdk=11.0.1
# - openssl=1.1.1c
# - packaging=19.2
# - pandas=0.25.2
# - pandoc=2.7.3
# - pandocfilters=1.4.2
# - pango=1.40.14
# - parso=0.5.1
# - patsy=0.5.1
# - pcre=8.43
# - perl=5.26.2
# - perl-archive-tar=2.32
# - perl-carp=1.38
# - perl-common-sense=3.74
# - perl-compress-raw-bzip2=2.087
# - perl-compress-raw-zlib=2.087
# - perl-exporter=5.72
# - perl-exporter-tiny=1.002001
# - perl-extutils-makemaker=7.36
# - perl-io-compress=2.087
# - perl-io-zlib=1.10
# - perl-json=4.02
# - perl-json-xs=2.34
# - perl-list-moreutils=0.428
# - perl-list-moreutils-xs=0.428
# - perl-pathtools=3.75
# - perl-scalar-list-utils=1.52
# - perl-types-serialiser=1.0
# - perl-xsloader=0.24
# - pexpect=4.7.0
# - pickleshare=0.7.5
# - pigz=2.3.4
# - pillow=6.2.1
# - pip=19.3.1
# - pixman=0.38.0
# - pluggy=0.12.0
# - prometheus_client=0.7.1
# - prompt_toolkit=2.0.10
# - psutil=5.6.3
# - pthread-stubs=0.4
# - ptyprocess=0.6.0
# - py=1.8.0
# - pycparser=2.19
# - pygments=2.4.2
# - pyopenssl=19.0.0
# - pyparsing=2.4.2
# - pyqt=5.9.2
# - pyrsistent=0.15.5
# - pysocks=1.7.1
# - pytest=5.2.2
# - python=3.6.7
# - python-dateutil=2.8.0
# - pytz=2019.3
# - pyyaml=5.1.2
# - pyzmq=18.1.0
# - q2-alignment=2019.10.0
# - q2-composition=2019.10.0
# - q2-cutadapt=2019.10.0
# - q2-dada2=2019.10.0
# - q2-deblur=2019.10.0
# - q2-demux=2019.10.0
# - q2-diversity=2019.10.0
# - q2-emperor=2019.10.0
# - q2-feature-classifier=2019.10.0
# - q2-feature-table=2019.10.0
# - q2-fragment-insertion=2019.10.0
# - q2-gneiss=2019.10.0
# - q2-longitudinal=2019.10.0
# - q2-metadata=2019.10.0
# - q2-phylogeny=2019.10.0
# - q2-quality-control=2019.10.0
# - q2-quality-filter=2019.10.0
# - q2-sample-classifier=2019.10.0
# - q2-taxa=2019.10.0
# - q2-types=2019.10.0
# - q2-vsearch=2019.10.0
# - q2cli=2019.10.0
# - q2templates=2019.10.0
# - qiime2=2019.10.0
# - qt=5.9.7
# - r-assertthat=0.2.1
# - r-backports=1.1.5
# - r-base=3.5.1
# - r-bh=1.69.0_1
# - r-bitops=1.0_6
# - r-cli=1.1.0
# - r-cluster=2.1.0
# - r-colorspace=1.4_1
# - r-crayon=1.3.4
# - r-data.table=1.12.6
# - r-digest=0.6.22
# - r-ellipsis=0.3.0
# - r-fansi=0.4.0
# - r-formatr=1.7
# - r-futile.logger=1.4.3
# - r-futile.options=1.0.1
# - r-ggplot2=3.2.1
# - r-glue=1.3.1
# - r-gtable=0.3.0
# - r-hwriter=1.3.2
# - r-labeling=0.3
# - r-lambda.r=1.2.4
# - r-lattice=0.20_38
# - r-latticeextra=0.6_28
# - r-lazyeval=0.2.2
# - r-magrittr=1.5
# - r-mass=7.3_51.4
# - r-matrix=1.2_17
# - r-matrixstats=0.55.0
# - r-mgcv=1.8_29
# - r-munsell=0.5.0
# - r-nlme=3.1_141
# - r-permute=0.9_5
# - r-pillar=1.4.2
# - r-pkgconfig=2.0.3
# - r-plyr=1.8.4
# - r-r6=2.4.0
# - r-rcolorbrewer=1.1_2
# - r-rcpp=1.0.2
# - r-rcppparallel=4.4.4
# - r-rcurl=1.95_4.12
# - r-reshape2=1.4.3
# - r-rlang=0.4.1
# - r-scales=1.0.0
# - r-snow=0.4_3
# - r-stringi=1.4.3
# - r-stringr=1.4.0
# - r-tibble=2.1.3
# - r-utf8=1.1.4
# - r-vctrs=0.2.0
# - r-vegan=2.5_6
# - r-viridislite=0.3.0
# - r-withr=2.1.2
# - r-zeallot=0.1.0
# - raxml=8.2.12
# - readline=8.0
# - requests=2.22.0
# - scikit-bio=0.5.5
# - scikit-learn=0.21.2
# - scipy=1.3.1
# - seaborn=0.9.0
# - send2trash=1.5.0
# - sepp=4.3.10
# - setuptools=41.6.0
# - sina=1.6.0
# - sip=4.19.8
# - six=1.12.0
# - sortmerna=2.0
# - sqlite=3.30.1
# - statsmodels=0.10.1
# - tbb=2019.9
# - terminado=0.8.2
# - testpath=0.4.2
# - tk=8.6.9
# - tktable=2.10
# - tornado=6.0.3
# - traitlets=4.3.3
# - tzlocal=2.0.0
# - unifrac=0.10.0
# - urllib3=1.25.6
# - vsearch=2.7.0
# - wcwidth=0.1.7
# - webencodings=0.5.1
# - wheel=0.33.6
# - widgetsnbextension=3.5.1
# - xopen=0.8.4
# - xorg-fixesproto=5.0
# - xorg-inputproto=2.3.2
# - xorg-kbproto=1.0.7
# - xorg-libice=1.0.10
# - xorg-libsm=1.2.3
# - xorg-libx11=1.6.9
# - xorg-libxau=1.0.9
# - xorg-libxdmcp=1.1.3
# - xorg-libxext=1.3.4
# - xorg-libxfixes=5.0.3
# - xorg-libxi=1.7.10
# - xorg-libxrender=0.9.10
# - xorg-libxtst=1.2.3
# - xorg-recordproto=1.14.2
# - xorg-renderproto=0.11.1
# - xorg-xextproto=7.3.0
# - xorg-xproto=7.0.31
# - xz=5.2.4
# - yaml=0.1.7
# - zeromq=4.3.2
# - zipp=0.6.0
# - zlib=1.2.11
# - zstd=1.4.3
#
# ==> /ebio/abt3_projects/Georg_animal_feces/bin/lla/bin/envs/trimmomatic.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::seqtk
# - bioconda::trimmomatic
